# %%
import json
from copy import copy
import numpy as np

# %%
with open('data/matches_weather.json') as f:
    matches = json.loads(f.read())

# %%
weather = [{
            'weather' : m['match_weather'],
            'away_team' : m['away_team'],
            'home_team' : m['home_team'],
            'datetime' : m['datetime'],
            'winner' : m['away_team']['code'] if m['away_team']['country'] == m['winner'] else m['home_team']['code'],
            'lat' : m['lat'],
            'lng' : m['lng'],
            'match_number' : m['match_number'],
            'location' : m['location']
            } for m in matches]
weather
# Out:
# [{'away_team': {u'code': u'CRO', u'country': u'Croatia', u'goals': 1},
#   'datetime': u'2014-06-12T17:00:00.000-03:00',
#   'home_team': {u'code': u'BRA', u'country': u'Brazil', u'goals': 3},
#   'lat': -23.545333,
#   'lng': -46.473702,
#   'location': u'Arena de Sao Paulo',
#   'match_number': 1,
#   'weather': {u'apparentTemperature': 74.8,
#    u'dewPoint': 62.7,
#    u'humidity': 0.66,
#    u'icon': u'clear-day',
#    u'precipType': u'rain',
#    u'summary': u'Clear',
#    u'temperature': 74.8,
#    u'time': 1402603200,
#    u'visibility': 6.2,
#    u'windBearing': 82,
#    u'windSpeed': 8.26},
#   'winner': u'BRA'},
#  {'away_team': {u'code': u'CMR', u'country': u'Cameroon', u'goals': 0},
#   'datetime': u'2014-06-13T13:00:00.000-03:00',
#   'home_team': {u'code': u'MEX', u'country': u'Mexico', u'goals': 1},
#   'lat': -5.826827,
#   'lng': -35.21243,
#   'location': u'Estadio das Dunas',
#   'match_number': 2,
#   'weather': {u'apparentTemperature': 73.92,
#    u'dewPoint': 72.01,
#    u'humidity': 0.94,
#    u'icon': u'clear-day',
#    u'precipType': u'rain',
#    u'summary': u'Humid',
#    u'temperature': 73.92,
#    u'time': 1402675200,
#    u'visibility': 3.47,
#    u'windBearing': 87,
#    u'windSpeed': 5.08},
#   'winner': u'MEX'},
#  {'away_team': {u'code': u'NED', u'country': u'Netherlands', u'goals': 5},
#   'datetime': u'2014-06-13T16:00:00.000-03:00',
#   'home_team': {u'code': u'ESP', u'country': u'Spain', u'goals': 1},
#   'lat': -12.97883,
#   'lng': -38.504371,
#   'location': u'Arena Fonte Nova',
#   'match_number': 3,
#   'weather': {u'apparentTemperature': 79,
#    u'dewPoint': 71.91,
#    u'humidity': 0.79,
#    u'icon': u'clear-day',
#    u'precipType': u'rain',
#    u'summary': u'Clear',
#    u'temperature': 79,
#    u'time': 1402686000,
#    u'visibility': 6.2,
#    u'windBearing': 150,
#    u'windSpeed': 8},
#   'winner': u'NED'},
#  {'away_team': {u'code': u'AUS', u'country': u'Australia', u'goals': 1},
#   'datetime': u'2014-06-13T19:00:00.000-03:00',
#   'home_team': {u'code': u'CHI', u'country': u'Chile', u'goals': 3},
#   'lat': -15.604017,
#   'lng': -56.121632,
#   'location': u'Arena Pantanal',
#   'match_number': 4,
#   'weather': {u'apparentTemperature': 75,
#    u'dewPoint': 66.14,
#    u'humidity': 0.74,
#    u'icon': u'clear-night',
#    u'precipType': u'rain',
#    u'summary': u'Clear',
#    u'temperature': 75,
#    u'time': 1402700400,
#    u'windBearing': 0,
#    u'windSpeed': 3},
#   'winner': u'CHI'},
#  {'away_team': {u'code': u'GRE', u'country': u'Greece', u'goals': 0},
#   'datetime': u'2014-06-14T13:00:00.000-03:00',
#   'home_team': {u'code': u'COL', u'country': u'Colombia', u'goals': 3},
#   'lat': -19.865867,
#   'lng': -43.971132,
#   'location': u'Estadio Mineirao',
#   'match_number': 5,
#   'weather': {u'apparentTemperature': 72.26,
#    u'cloudCover': 0.7,
#    u'dewPoint': 55.19,
#    u'humidity': 0.55,
#    u'icon': u'partly-cloudy-day',
#    u'ozone': 255.8,
#    u'precipIntensity': 0.0002,
#    u'precipProbability': 0.8,
#    u'precipType': u'rain',
#    u'pressure': 1020.92,
#    u'summary': u'Mostly Cloudy',
#    u'temperature': 72.26,
#    u'time': 1402761600,
#    u'visibility': 6.2,
#    u'windBearing': 84,
#    u'windSpeed': 7.13},
#   'winner': u'COL'},
#  {'away_team': {u'code': u'JPN', u'country': u'Japan', u'goals': 1},
#   'datetime': u'2014-06-14T22:00:00.000-03:00',
#   'home_team': {u'code': u'CIV', u'country': u'Ivory Coast', u'goals': 2},
#   'lat': -8.04065,
#   'lng': -35.008205,
#   'location': u'Arena Pernambuco',
#   'match_number': 6,
#   'weather': {u'apparentTemperature': 74.82,
#    u'cloudCover': 0.05,
#    u'dewPoint': 71.3,
#    u'humidity': 0.89,
#    u'icon': u'clear-night',
#    u'ozone': 251.46,
#    u'precipIntensity': 0.0219,
#    u'precipProbability': 0.12,
#    u'precipType': u'rain',
#    u'pressure': 1015.85,
#    u'summary': u'Clear',
#    u'temperature': 74.82,
#    u'time': 1402794000,
#    u'visibility': 5.34,
#    u'windBearing': 141,
#    u'windSpeed': 9.43},
#   'winner': u'CIV'},
#  {'away_team': {u'code': u'CRC', u'country': u'Costa Rica', u'goals': 3},
#   'datetime': u'2014-06-14T16:00:00.000-03:00',
#   'home_team': {u'code': u'URU', u'country': u'Uruguay', u'goals': 1},
#   'lat': -3.807231,
#   'lng': -38.522434,
#   'location': u'Estadio Castelao',
#   'match_number': 7,
#   'weather': {u'apparentTemperature': 87.58,
#    u'cloudCover': 0.22,
#    u'dewPoint': 67.53,
#    u'humidity': 0.57,
#    u'icon': u'rain',
#    u'ozone': 247.92,
#    u'precipIntensity': 0.0046,
#    u'precipProbability': 0.61,
#    u'precipType': u'rain',
#    u'pressure': 1011.52,
#    u'summary': u'Drizzle',
#    u'temperature': 84.56,
#    u'time': 1402772400,
#    u'visibility': 6.2,
#    u'windBearing': 94,
#    u'windSpeed': 10.27},
#   'winner': u'CRC'},
#  {'away_team': {u'code': u'ITA', u'country': u'Italy', u'goals': 2},
#   'datetime': u'2014-06-14T19:00:00.000-03:00',
#   'home_team': {u'code': u'ENG', u'country': u'England', u'goals': 1},
#   'lat': -3.083142,
#   'lng': -60.028108,
#   'location': u'Arena Amazonia',
#   'match_number': 8,
#   'weather': {u'apparentTemperature': 79.76,
#    u'cloudCover': 0.01,
#    u'dewPoint': 68.11,
#    u'humidity': 0.68,
#    u'icon': u'clear-night',
#    u'ozone': 251.99,
#    u'precipIntensity': 0.0003,
#    u'precipProbability': 0.8,
#    u'precipType': u'rain',
#    u'pressure': 1010.8,
#    u'summary': u'Clear',
#    u'temperature': 79.76,
#    u'time': 1402786800,
#    u'windBearing': 119,
#    u'windSpeed': 3},
#   'winner': u'ITA'},
#  {'away_team': {u'code': u'ECU', u'country': u'Ecuador', u'goals': 1},
#   'datetime': u'2014-06-15T13:00:00.000-03:00',
#   'home_team': {u'code': u'SUI', u'country': u'Switzerland', u'goals': 2},
#   'lat': -15.783519,
#   'lng': -47.899211,
#   'location': u'Estadio Nacional',
#   'match_number': 9,
#   'weather': {u'apparentTemperature': 73.4,
#    u'cloudCover': 0.97,
#    u'dewPoint': 59.17,
#    u'humidity': 0.61,
#    u'icon': u'cloudy',
#    u'ozone': 254.22,
#    u'precipIntensity': 0.0009,
#    u'precipProbability': 0.8,
#    u'precipType': u'rain',
#    u'pressure': 1017.56,
#    u'summary': u'Overcast',
#    u'temperature': 73.4,
#    u'time': 1402848000,
#    u'visibility': 6.2,
#    u'windBearing': 92,
#    u'windSpeed': 9.32},
#   'winner': u'SUI'},
#  {'away_team': {u'code': u'HON', u'country': u'Honduras', u'goals': 0},
#   'datetime': u'2014-06-15T16:00:00.000-03:00',
#   'home_team': {u'code': u'FRA', u'country': u'France', u'goals': 3},
#   'lat': -30.065384,
#   'lng': -51.235822,
#   'location': u'Estadio Beira-Rio',
#   'match_number': 10,
#   'weather': {u'apparentTemperature': 66.1,
#    u'cloudCover': 0.13,
#    u'dewPoint': 60.19,
#    u'humidity': 0.81,
#    u'icon': u'clear-day',
#    u'ozone': 265.66,
#    u'precipIntensity': 0.0002,
#    u'precipProbability': 0.83,
#    u'precipType': u'rain',
#    u'pressure': 1022.29,
#    u'summary': u'Clear',
#    u'temperature': 66.1,
#    u'time': 1402858800,
#    u'visibility': 6.1,
#    u'windBearing': 97,
#    u'windSpeed': 12},
#   'winner': u'FRA'},
#  {'away_team': {u'code': u'BIH',
#    u'country': u'Bosnia and Herzegovina',
#    u'goals': 1},
#   'datetime': u'2014-06-15T19:00:00.000-03:00',
#   'home_team': {u'code': u'ARG', u'country': u'Argentina', u'goals': 2},
#   'lat': -22.912109,
#   'lng': -43.230156,
#   'location': u'Estadio do Maracana',
#   'match_number': 11,
#   'weather': {u'apparentTemperature': 71.96,
#    u'cloudCover': 0,
#    u'dewPoint': 67.26,
#    u'humidity': 0.85,
#    u'icon': u'rain',
#    u'ozone': 249.87,
#    u'precipIntensity': 0.0033,
#    u'precipProbability': 0.67,
#    u'precipType': u'rain',
#    u'pressure': 1021.92,
#    u'summary': u'Drizzle',
#    u'temperature': 71.96,
#    u'time': 1402869600,
#    u'visibility': 6.2,
#    u'windBearing': 215,
#    u'windSpeed': 5.58},
#   'winner': u'ARG'},
#  {'away_team': {u'code': u'NGA', u'country': u'Nigeria', u'goals': 0},
#   'datetime': u'2014-06-16T16:00:00.000-03:00',
#   'home_team': {u'code': u'IRN', u'country': u'Iran', u'goals': 0},
#   'lat': -25.4482121,
#   'lng': -49.276987,
#   'location': u'Arena da Baixada',
#   'match_number': 12,
#   'weather': {u'apparentTemperature': 70.21,
#    u'cloudCover': 0.51,
#    u'dewPoint': 62.3,
#    u'humidity': 0.76,
#    u'icon': u'rain',
#    u'ozone': 253.94,
#    u'precipIntensity': 0.0032,
#    u'precipProbability': 0.7,
#    u'precipType': u'rain',
#    u'pressure': 1019.68,
#    u'summary': u'Drizzle',
#    u'temperature': 70.21,
#    u'time': 1402945200,
#    u'visibility': 6.2,
#    u'windBearing': 259,
#    u'windSpeed': 5.21},
#   'winner': u'IRN'},
#  {'away_team': {u'code': u'POR', u'country': u'Portugal', u'goals': 0},
#   'datetime': u'2014-06-16T13:00:00.000-03:00',
#   'home_team': {u'code': u'GER', u'country': u'Germany', u'goals': 4},
#   'lat': -12.97883,
#   'lng': -38.504371,
#   'location': u'Arena Fonte Nova',
#   'match_number': 13,
#   'weather': {u'apparentTemperature': 79.86,
#    u'cloudCover': 0.17,
#    u'dewPoint': 70.52,
#    u'humidity': 0.73,
#    u'icon': u'clear-day',
#    u'ozone': 255.43,
#    u'precipIntensity': 0.0127,
#    u'precipProbability': 0.24,
#    u'precipType': u'rain',
#    u'pressure': 1017.5,
#    u'summary': u'Clear',
#    u'temperature': 79.86,
#    u'time': 1402934400,
#    u'visibility': 6.2,
#    u'windBearing': 130,
#    u'windSpeed': 11.61},
#   'winner': u'GER'},
#  {'away_team': {u'code': u'USA', u'country': u'USA', u'goals': 2},
#   'datetime': u'2014-06-16T19:00:00.000-03:00',
#   'home_team': {u'code': u'GHA', u'country': u'Ghana', u'goals': 1},
#   'lat': -5.826827,
#   'lng': -35.21243,
#   'location': u'Estadio das Dunas',
#   'match_number': 14,
#   'weather': {u'apparentTemperature': 79.27,
#    u'cloudCover': 0.22,
#    u'dewPoint': 71.3,
#    u'humidity': 0.77,
#    u'icon': u'rain',
#    u'ozone': 252.42,
#    u'precipIntensity': 0.0101,
#    u'precipProbability': 0.49,
#    u'precipType': u'rain',
#    u'pressure': 1014.88,
#    u'summary': u'Drizzle',
#    u'temperature': 79.27,
#    u'time': 1402956000,
#    u'visibility': 6.2,
#    u'windBearing': 144,
#    u'windSpeed': 14.24},
#   'winner': u'USA'},
#  {'away_team': {u'code': u'ALG', u'country': u'Algeria', u'goals': 1},
#   'datetime': u'2014-06-17T13:00:00.000-03:00',
#   'home_team': {u'code': u'BEL', u'country': u'Belgium', u'goals': 2},
#   'lat': -19.865867,
#   'lng': -43.971132,
#   'location': u'Estadio Mineirao',
#   'match_number': 15,
#   'weather': {u'apparentTemperature': 75.65,
#    u'cloudCover': 0.72,
#    u'dewPoint': 54.55,
#    u'humidity': 0.48,
#    u'icon': u'partly-cloudy-day',
#    u'ozone': 252.39,
#    u'precipIntensity': 0.0002,
#    u'precipProbability': 0.87,
#    u'precipType': u'rain',
#    u'pressure': 1019.34,
#    u'summary': u'Mostly Cloudy',
#    u'temperature': 75.65,
#    u'time': 1403020800,
#    u'windBearing': 90,
#    u'windSpeed': 4.39},
#   'winner': u'BEL'},
#  {'away_team': {u'code': u'KOR', u'country': u'Korea Republic', u'goals': 1},
#   'datetime': u'2014-06-17T19:00:00.000-03:00',
#   'home_team': {u'code': u'RUS', u'country': u'Russia', u'goals': 1},
#   'lat': -15.604017,
#   'lng': -56.121632,
#   'location': u'Arena Pantanal',
#   'match_number': 16,
#   'weather': {u'apparentTemperature': 74.51,
#    u'cloudCover': 0.96,
#    u'dewPoint': 65.67,
#    u'humidity': 0.74,
#    u'icon': u'cloudy',
#    u'ozone': 260.83,
#    u'precipIntensity': 0.0001,
#    u'precipProbability': 0.88,
#    u'precipType': u'rain',
#    u'pressure': 1015.31,
#    u'summary': u'Overcast',
#    u'temperature': 74.51,
#    u'time': 1403046000,
#    u'visibility': 6.2,
#    u'windBearing': 168,
#    u'windSpeed': 3.05},
#   'winner': u'RUS'},
#  {'away_team': {u'code': u'MEX', u'country': u'Mexico', u'goals': 0},
#   'datetime': u'2014-06-17T16:00:00.000-03:00',
#   'home_team': {u'code': u'BRA', u'country': u'Brazil', u'goals': 0},
#   'lat': -3.807231,
#   'lng': -38.522434,
#   'location': u'Estadio Castelao',
#   'match_number': 17,
#   'weather': {u'apparentTemperature': 87.93,
#    u'cloudCover': 0.43,
#    u'dewPoint': 70.16,
#    u'humidity': 0.64,
#    u'icon': u'rain',
#    u'ozone': 257.01,
#    u'precipIntensity': 0.0046,
#    u'precipProbability': 0.62,
#    u'precipType': u'rain',
#    u'pressure': 1012.35,
#    u'summary': u'Drizzle',
#    u'temperature': 83.59,
#    u'time': 1403031600,
#    u'visibility': 6.2,
#    u'windBearing': 92,
#    u'windSpeed': 14.24},
#   'winner': u'BRA'},
#  {'away_team': {u'code': u'CRO', u'country': u'Croatia', u'goals': 4},
#   'datetime': u'2014-06-18T19:00:00.000-03:00',
#   'home_team': {u'code': u'CMR', u'country': u'Cameroon', u'goals': 0},
#   'lat': -3.083142,
#   'lng': -60.028108,
#   'location': u'Arena Amazonia',
#   'match_number': 18,
#   'weather': {u'apparentTemperature': 77.22,
#    u'cloudCover': 0.81,
#    u'dewPoint': 73.32,
#    u'humidity': 0.88,
#    u'icon': u'rain',
#    u'ozone': 249.45,
#    u'precipIntensity': 0.0115,
#    u'precipProbability': 0.4,
#    u'precipType': u'rain',
#    u'pressure': 1014.23,
#    u'summary': u'Drizzle',
#    u'temperature': 77.22,
#    u'time': 1403132400,
#    u'visibility': 6.2,
#    u'windBearing': 57,
#    u'windSpeed': 1.45},
#   'winner': u'CRO'},
#  {'away_team': {u'code': u'CHI', u'country': u'Chile', u'goals': 2},
#   'datetime': u'2014-06-18T16:00:00.000-03:00',
#   'home_team': {u'code': u'ESP', u'country': u'Spain', u'goals': 0},
#   'lat': -22.912109,
#   'lng': -43.230156,
#   'location': u'Estadio do Maracana',
#   'match_number': 19,
#   'weather': {u'apparentTemperature': 73.6,
#    u'cloudCover': 0.25,
#    u'dewPoint': 67.93,
#    u'humidity': 0.83,
#    u'icon': u'partly-cloudy-day',
#    u'ozone': 263.01,
#    u'precipIntensity': 0.0006,
#    u'precipProbability': 0.88,
#    u'precipType': u'rain',
#    u'pressure': 1019.46,
#    u'summary': u'Partly Cloudy',
#    u'temperature': 73.6,
#    u'time': 1403118000,
#    u'visibility': 3.53,
#    u'windBearing': 202,
#    u'windSpeed': 9.2},
#   'winner': u'CHI'},
#  {'away_team': {u'code': u'NED', u'country': u'Netherlands', u'goals': 3},
#   'datetime': u'2014-06-18T13:00:00.000-03:00',
#   'home_team': {u'code': u'AUS', u'country': u'Australia', u'goals': 2},
#   'lat': -30.065384,
#   'lng': -51.235822,
#   'location': u'Estadio Beira-Rio',
#   'match_number': 20,
#   'weather': {u'apparentTemperature': 58.43,
#    u'cloudCover': 0.02,
#    u'dewPoint': 45.08,
#    u'humidity': 0.61,
#    u'icon': u'clear-day',
#    u'ozone': 312.67,
#    u'precipIntensity': 0.0005,
#    u'precipProbability': 0.88,
#    u'precipType': u'rain',
#    u'pressure': 1027.65,
#    u'summary': u'Clear',
#    u'temperature': 58.43,
#    u'time': 1403107200,
#    u'visibility': 6.2,
#    u'windBearing': 217,
#    u'windSpeed': 7.18},
#   'winner': u'NED'},
#  {'away_team': {u'code': u'CIV', u'country': u'Ivory Coast', u'goals': 1},
#   'datetime': u'2014-06-19T13:00:00.000-03:00',
#   'home_team': {u'code': u'COL', u'country': u'Colombia', u'goals': 2},
#   'lat': -15.783519,
#   'lng': -47.899211,
#   'location': u'Estadio Nacional',
#   'match_number': 21,
#   'weather': {u'apparentTemperature': 77.98,
#    u'cloudCover': 0.98,
#    u'dewPoint': 56.53,
#    u'humidity': 0.48,
#    u'icon': u'cloudy',
#    u'ozone': 259.05,
#    u'precipIntensity': 0.0003,
#    u'precipProbability': 0.92,
#    u'precipType': u'rain',
#    u'pressure': 1018.22,
#    u'summary': u'Overcast',
#    u'temperature': 77.98,
#    u'time': 1403193600,
#    u'visibility': 6.2,
#    u'windBearing': 152,
#    u'windSpeed': 6.07},
#   'winner': u'COL'},
#  {'away_team': {u'code': u'GRE', u'country': u'Greece', u'goals': 0},
#   'datetime': u'2014-06-19T19:00:00.000-03:00',
#   'home_team': {u'code': u'JPN', u'country': u'Japan', u'goals': 0},
#   'lat': -5.826827,
#   'lng': -35.21243,
#   'location': u'Estadio das Dunas',
#   'match_number': 22,
#   'weather': {u'apparentTemperature': 78.78,
#    u'cloudCover': 0.61,
#    u'dewPoint': 73.38,
#    u'humidity': 0.84,
#    u'icon': u'rain',
#    u'ozone': 256.26,
#    u'precipIntensity': 0.0086,
#    u'precipProbability': 0.69,
#    u'precipType': u'rain',
#    u'pressure': 1015.07,
#    u'summary': u'Drizzle',
#    u'temperature': 78.78,
#    u'time': 1403215200,
#    u'visibility': 6.2,
#    u'windBearing': 143,
#    u'windSpeed': 16.3},
#   'winner': u'JPN'},
#  {'away_team': {u'code': u'ENG', u'country': u'England', u'goals': 1},
#   'datetime': u'2014-06-19T16:00:00.000-03:00',
#   'home_team': {u'code': u'URU', u'country': u'Uruguay', u'goals': 2},
#   'lat': -23.545333,
#   'lng': -46.473702,
#   'location': u'Arena de Sao Paulo',
#   'match_number': 23,
#   'weather': {u'apparentTemperature': 61.03,
#    u'cloudCover': 0.91,
#    u'dewPoint': 56.8,
#    u'humidity': 0.86,
#    u'icon': u'rain',
#    u'ozone': 286.33,
#    u'precipIntensity': 0.0081,
#    u'precipProbability': 0.42,
#    u'precipType': u'rain',
#    u'pressure': 1024.34,
#    u'summary': u'Drizzle',
#    u'temperature': 61.03,
#    u'time': 1403204400,
#    u'visibility': 5.84,
#    u'windBearing': 166,
#    u'windSpeed': 9.02},
#   'winner': u'URU'},
#  {'away_team': {u'code': u'CRC', u'country': u'Costa Rica', u'goals': 1},
#   'datetime': u'2014-06-20T13:00:00.000-03:00',
#   'home_team': {u'code': u'ITA', u'country': u'Italy', u'goals': 0},
#   'lat': -8.04065,
#   'lng': -35.008205,
#   'location': u'Arena Pernambuco',
#   'match_number': 24,
#   'weather': {u'apparentTemperature': 86.1,
#    u'cloudCover': 0.23,
#    u'dewPoint': 70.47,
#    u'humidity': 0.68,
#    u'icon': u'rain',
#    u'ozone': 257.87,
#    u'precipIntensity': 0.0052,
#    u'precipProbability': 0.64,
#    u'precipType': u'rain',
#    u'pressure': 1015.33,
#    u'summary': u'Drizzle',
#    u'temperature': 82.04,
#    u'time': 1403280000,
#    u'visibility': 6.2,
#    u'windBearing': 149,
#    u'windSpeed': 14.06},
#   'winner': u'CRC'},
#  {'away_team': {u'code': u'FRA', u'country': u'France', u'goals': 5},
#   'datetime': u'2014-06-20T16:00:00.000-03:00',
#   'home_team': {u'code': u'SUI', u'country': u'Switzerland', u'goals': 2},
#   'lat': -12.97883,
#   'lng': -38.504371,
#   'location': u'Arena Fonte Nova',
#   'match_number': 25,
#   'weather': {u'apparentTemperature': 83.45,
#    u'cloudCover': 0.94,
#    u'dewPoint': 70.53,
#    u'humidity': 0.73,
#    u'icon': u'rain',
#    u'ozone': 254.07,
#    u'precipIntensity': 0.0092,
#    u'precipProbability': 0.42,
#    u'precipType': u'rain',
#    u'pressure': 1016.83,
#    u'summary': u'Drizzle',
#    u'temperature': 80.09,
#    u'time': 1403290800,
#    u'visibility': 6.2,
#    u'windBearing': 134,
#    u'windSpeed': 7.72},
#   'winner': u'FRA'},
#  {'away_team': {u'code': u'ECU', u'country': u'Ecuador', u'goals': 2},
#   'datetime': u'2014-06-20T19:00:00.000-03:00',
#   'home_team': {u'code': u'HON', u'country': u'Honduras', u'goals': 1},
#   'lat': -25.4482121,
#   'lng': -49.276987,
#   'location': u'Arena da Baixada',
#   'match_number': 26,
#   'weather': {u'apparentTemperature': 54.76,
#    u'cloudCover': 1,
#    u'dewPoint': 51.02,
#    u'humidity': 0.87,
#    u'icon': u'cloudy',
#    u'ozone': 291.34,
#    u'precipIntensity': 0.0003,
#    u'precipProbability': 0.95,
#    u'precipType': u'rain',
#    u'pressure': 1022.15,
#    u'summary': u'Overcast',
#    u'temperature': 54.76,
#    u'time': 1403301600,
#    u'visibility': 6.2,
#    u'windBearing': 108,
#    u'windSpeed': 2.72},
#   'winner': u'ECU'},
#  {'away_team': {u'code': u'IRN', u'country': u'Iran', u'goals': 0},
#   'datetime': u'2014-06-21T13:00:00.000-03:00',
#   'home_team': {u'code': u'ARG', u'country': u'Argentina', u'goals': 1},
#   'lat': -19.865867,
#   'lng': -43.971132,
#   'location': u'Estadio Mineirao',
#   'match_number': 27,
#   'weather': {u'apparentTemperature': 72.39,
#    u'cloudCover': 0.54,
#    u'dewPoint': 57.64,
#    u'humidity': 0.6,
#    u'icon': u'partly-cloudy-day',
#    u'ozone': 266.23,
#    u'precipIntensity': 0.0016,
#    u'precipProbability': 0.93,
#    u'precipType': u'rain',
#    u'pressure': 1019.94,
#    u'summary': u'Partly Cloudy',
#    u'temperature': 72.39,
#    u'time': 1403366400,
#    u'visibility': 6.2,
#    u'windBearing': 84,
#    u'windSpeed': 5.45},
#   'winner': u'ARG'},
#  {'away_team': {u'code': u'BIH',
#    u'country': u'Bosnia and Herzegovina',
#    u'goals': 0},
#   'datetime': u'2014-06-21T19:00:00.000-03:00',
#   'home_team': {u'code': u'NGA', u'country': u'Nigeria', u'goals': 1},
#   'lat': -15.604017,
#   'lng': -56.121632,
#   'location': u'Arena Pantanal',
#   'match_number': 28,
#   'weather': {u'apparentTemperature': 76.62,
#    u'cloudCover': 0.32,
#    u'dewPoint': 68.24,
#    u'humidity': 0.75,
#    u'icon': u'partly-cloudy-night',
#    u'ozone': 254.45,
#    u'precipIntensity': 0.0001,
#    u'precipProbability': 0.98,
#    u'precipType': u'rain',
#    u'pressure': 1013.16,
#    u'summary': u'Partly Cloudy',
#    u'temperature': 76.62,
#    u'time': 1403391600,
#    u'windBearing': 144,
#    u'windSpeed': 0.95},
#   'winner': u'NGA'},
#  {'away_team': {u'code': u'GHA', u'country': u'Ghana', u'goals': 2},
#   'datetime': u'2014-06-21T16:00:00.000-03:00',
#   'home_team': {u'code': u'GER', u'country': u'Germany', u'goals': 2},
#   'lat': -3.807231,
#   'lng': -38.522434,
#   'location': u'Estadio Castelao',
#   'match_number': 29,
#   'weather': {u'apparentTemperature': 86.49,
#    u'cloudCover': 0.24,
#    u'dewPoint': 64.4,
#    u'humidity': 0.5,
#    u'icon': u'clear-day',
#    u'ozone': 255.14,
#    u'precipIntensity': 0,
#    u'precipProbability': 0,
#    u'pressure': 1011.81,
#    u'summary': u'Clear',
#    u'temperature': 84.97,
#    u'time': 1403377200,
#    u'windBearing': 96,
#    u'windSpeed': 10.58},
#   'winner': u'GER'},
#  {'away_team': {u'code': u'POR', u'country': u'Portugal', u'goals': 2},
#   'datetime': u'2014-06-22T19:00:00.000-03:00',
#   'home_team': {u'code': u'USA', u'country': u'USA', u'goals': 2},
#   'lat': -3.083142,
#   'lng': -60.028108,
#   'location': u'Arena Amazonia',
#   'match_number': 30,
#   'weather': {u'apparentTemperature': 86.94,
#    u'cloudCover': 0.96,
#    u'dewPoint': 74.86,
#    u'humidity': 0.81,
#    u'icon': u'rain',
#    u'ozone': 255.76,
#    u'precipIntensity': 0.0055,
#    u'precipProbability': 0.63,
#    u'precipType': u'rain',
#    u'pressure': 1011.72,
#    u'summary': u'Drizzle',
#    u'temperature': 81.1,
#    u'time': 1403478000,
#    u'windBearing': 85,
#    u'windSpeed': 1.58},
#   'winner': u'USA'},
#  {'away_team': {u'code': u'RUS', u'country': u'Russia', u'goals': 0},
#   'datetime': u'2014-06-22T13:00:00.000-03:00',
#   'home_team': {u'code': u'BEL', u'country': u'Belgium', u'goals': 1},
#   'lat': -22.912109,
#   'lng': -43.230156,
#   'location': u'Estadio do Maracana',
#   'match_number': 31,
#   'weather': {u'apparentTemperature': 76.48,
#    u'cloudCover': 0.05,
#    u'dewPoint': 67.53,
#    u'humidity': 0.74,
#    u'icon': u'rain',
#    u'ozone': 270.16,
#    u'precipIntensity': 0.0031,
#    u'precipProbability': 0.81,
#    u'precipType': u'rain',
#    u'pressure': 1023.39,
#    u'summary': u'Drizzle',
#    u'temperature': 76.48,
#    u'time': 1403452800,
#    u'windBearing': 84,
#    u'windSpeed': 10.35},
#   'winner': u'BEL'},
#  {'away_team': {u'code': u'ALG', u'country': u'Algeria', u'goals': 4},
#   'datetime': u'2014-06-22T16:00:00.000-03:00',
#   'home_team': {u'code': u'KOR', u'country': u'Korea Republic', u'goals': 2},
#   'lat': -30.065384,
#   'lng': -51.235822,
#   'location': u'Estadio Beira-Rio',
#   'match_number': 32,
#   'weather': {u'apparentTemperature': 67.47,
#    u'cloudCover': 0.3,
#    u'dewPoint': 57.65,
#    u'humidity': 0.71,
#    u'icon': u'partly-cloudy-day',
#    u'ozone': 264.33,
#    u'precipIntensity': 0,
#    u'precipProbability': 0,
#    u'pressure': 1019.13,
#    u'summary': u'Partly Cloudy',
#    u'temperature': 67.47,
#    u'time': 1403463600,
#    u'windBearing': 113,
#    u'windSpeed': 1.24},
#   'winner': u'ALG'},
#  {'away_team': {u'code': u'BRA', u'country': u'Brazil', u'goals': 4},
#   'datetime': u'2014-06-23T17:00:00.000-03:00',
#   'home_team': {u'code': u'CMR', u'country': u'Cameroon', u'goals': 1},
#   'lat': -15.783519,
#   'lng': -47.899211,
#   'location': u'Estadio Nacional',
#   'match_number': 33,
#   'weather': {u'apparentTemperature': 72.01,
#    u'cloudCover': 0.98,
#    u'dewPoint': 58.63,
#    u'humidity': 0.63,
#    u'icon': u'cloudy',
#    u'ozone': 251.39,
#    u'precipIntensity': 0.0004,
#    u'precipProbability': 1,
#    u'precipType': u'rain',
#    u'pressure': 1017.79,
#    u'summary': u'Overcast',
#    u'temperature': 72.01,
#    u'time': 1403553600,
#    u'windBearing': 76,
#    u'windSpeed': 7.63},
#   'winner': u'BRA'},
#  {'away_team': {u'code': u'MEX', u'country': u'Mexico', u'goals': 3},
#   'datetime': u'2014-06-23T17:00:00.000-03:00',
#   'home_team': {u'code': u'CRO', u'country': u'Croatia', u'goals': 1},
#   'lat': -8.04065,
#   'lng': -35.008205,
#   'location': u'Arena Pernambuco',
#   'match_number': 34,
#   'weather': {u'apparentTemperature': 76.35,
#    u'cloudCover': 0.94,
#    u'dewPoint': 72.02,
#    u'humidity': 0.87,
#    u'icon': u'cloudy',
#    u'ozone': 254.04,
#    u'precipIntensity': 0.0293,
#    u'precipProbability': 0.03,
#    u'precipType': u'rain',
#    u'pressure': 1016.7,
#    u'summary': u'Humid and Overcast',
#    u'temperature': 76.35,
#    u'time': 1403553600,
#    u'windBearing': 149,
#    u'windSpeed': 10.8},
#   'winner': u'MEX'},
#  {'away_team': {u'code': u'ESP', u'country': u'Spain', u'goals': 3},
#   'datetime': u'2014-06-23T13:00:00.000-03:00',
#   'home_team': {u'code': u'AUS', u'country': u'Australia', u'goals': 0},
#   'lat': -25.4482121,
#   'lng': -49.276987,
#   'location': u'Arena da Baixada',
#   'match_number': 35,
#   'weather': {u'apparentTemperature': 68.42,
#    u'cloudCover': 0.84,
#    u'dewPoint': 60.71,
#    u'humidity': 0.76,
#    u'icon': u'partly-cloudy-day',
#    u'ozone': 275.51,
#    u'precipIntensity': 0.0003,
#    u'precipProbability': 1,
#    u'precipType': u'rain',
#    u'pressure': 1019.55,
#    u'summary': u'Mostly Cloudy',
#    u'temperature': 68.42,
#    u'time': 1403539200,
#    u'windBearing': 346,
#    u'windSpeed': 3.5},
#   'winner': u'ESP'},
#  {'away_team': {u'code': u'CHI', u'country': u'Chile', u'goals': 0},
#   'datetime': u'2014-06-23T13:00:00.000-03:00',
#   'home_team': {u'code': u'NED', u'country': u'Netherlands', u'goals': 2},
#   'lat': -23.545333,
#   'lng': -46.473702,
#   'location': u'Arena de Sao Paulo',
#   'match_number': 36,
#   'weather': {u'apparentTemperature': 73.86,
#    u'cloudCover': 0.82,
#    u'dewPoint': 63.24,
#    u'humidity': 0.69,
#    u'icon': u'partly-cloudy-day',
#    u'ozone': 265.14,
#    u'precipIntensity': 0.0002,
#    u'precipProbability': 1,
#    u'precipType': u'rain',
#    u'pressure': 1020.67,
#    u'summary': u'Mostly Cloudy',
#    u'temperature': 73.86,
#    u'time': 1403539200,
#    u'windBearing': 337,
#    u'windSpeed': 3.68},
#   'winner': u'NED'},
#  {'away_team': {u'code': u'COL', u'country': u'Colombia', u'goals': 4},
#   'datetime': u'2014-06-24T17:00:00.000-03:00',
#   'home_team': {u'code': u'JPN', u'country': u'Japan', u'goals': 1},
#   'lat': -15.604017,
#   'lng': -56.121632,
#   'location': u'Arena Pantanal',
#   'match_number': 37,
#   'weather': {u'apparentTemperature': 81.38,
#    u'cloudCover': 0.35,
#    u'dewPoint': 56.86,
#    u'humidity': 0.43,
#    u'icon': u'partly-cloudy-day',
#    u'ozone': 252.9,
#    u'precipIntensity': 0,
#    u'precipProbability': 0,
#    u'pressure': 1013.16,
#    u'summary': u'Partly Cloudy',
#    u'temperature': 81.5,
#    u'time': 1403643600,
#    u'windBearing': 55,
#    u'windSpeed': 3.84},
#   'winner': u'COL'},
#  {'away_team': {u'code': u'CIV', u'country': u'Ivory Coast', u'goals': 1},
#   'datetime': u'2014-06-24T17:00:00.000-03:00',
#   'home_team': {u'code': u'GRE', u'country': u'Greece', u'goals': 2},
#   'lat': -3.807231,
#   'lng': -38.522434,
#   'location': u'Estadio Castelao',
#   'match_number': 38,
#   'weather': {u'apparentTemperature': 88.93,
#    u'cloudCover': 0.61,
#    u'dewPoint': 71.26,
#    u'humidity': 0.66,
#    u'icon': u'partly-cloudy-day',
#    u'ozone': 252.84,
#    u'precipIntensity': 0.0002,
#    u'precipProbability': 1,
#    u'precipType': u'rain',
#    u'pressure': 1012.02,
#    u'summary': u'Mostly Cloudy',
#    u'temperature': 83.84,
#    u'time': 1403640000,
#    u'windBearing': 65,
#    u'windSpeed': 16.09},
#   'winner': u'GRE'},
#  {'away_team': {u'code': u'URU', u'country': u'Uruguay', u'goals': 1},
#   'datetime': u'2014-06-24T13:00:00.000-03:00',
#   'home_team': {u'code': u'ITA', u'country': u'Italy', u'goals': 0},
#   'lat': -5.826827,
#   'lng': -35.21243,
#   'location': u'Estadio das Dunas',
#   'match_number': 39,
#   'weather': {u'apparentTemperature': 88.05,
#    u'cloudCover': 0.74,
#    u'dewPoint': 74.34,
#    u'humidity': 0.78,
#    u'icon': u'rain',
#    u'ozone': 251.98,
#    u'precipIntensity': 0.0144,
#    u'precipProbability': 0.25,
#    u'precipType': u'rain',
#    u'pressure': 1014.64,
#    u'summary': u'Drizzle',
#    u'temperature': 81.89,
#    u'time': 1403625600,
#    u'visibility': 6.21,
#    u'windBearing': 133,
#    u'windSpeed': 17.81},
#   'winner': u'URU'},
#  {'away_team': {u'code': u'ENG', u'country': u'England', u'goals': 0},
#   'datetime': u'2014-06-24T13:00:00.000-03:00',
#   'home_team': {u'code': u'CRC', u'country': u'Costa Rica', u'goals': 0},
#   'lat': -19.865867,
#   'lng': -43.971132,
#   'location': u'Estadio Mineirao',
#   'match_number': 40,
#   'weather': {u'apparentTemperature': 76.16,
#    u'cloudCover': 0.41,
#    u'dewPoint': 54.04,
#    u'humidity': 0.46,
#    u'icon': u'partly-cloudy-day',
#    u'ozone': 264.8,
#    u'precipIntensity': 0.0001,
#    u'precipProbability': 1,
#    u'precipType': u'rain',
#    u'pressure': 1019.44,
#    u'summary': u'Partly Cloudy',
#    u'temperature': 76.16,
#    u'time': 1403625600,
#    u'visibility': 6.21,
#    u'windBearing': 70,
#    u'windSpeed': 6.17},
#   'winner': u'CRC'},
#  {'away_team': {u'code': u'SUI', u'country': u'Switzerland', u'goals': 3},
#   'datetime': u'2014-06-25T17:00:00.000-03:00',
#   'home_team': {u'code': u'HON', u'country': u'Honduras', u'goals': 0},
#   'lat': -3.083142,
#   'lng': -60.028108,
#   'location': u'Arena Amazonia',
#   'match_number': 41,
#   'weather': {u'apparentTemperature': 103.39,
#    u'cloudCover': 0.25,
#    u'dewPoint': 82.28,
#    u'humidity': 0.91,
#    u'icon': u'partly-cloudy-day',
#    u'ozone': 252.9,
#    u'precipIntensity': 0.0077,
#    u'precipProbability': 0.26,
#    u'precipType': u'rain',
#    u'pressure': 1010.19,
#    u'summary': u'Humid and Partly Cloudy',
#    u'temperature': 85.36,
#    u'time': 1403730000,
#    u'visibility': 6.21,
#    u'windBearing': 7,
#    u'windSpeed': 1.88},
#   'winner': u'SUI'},
#  {'away_team': {u'code': u'FRA', u'country': u'France', u'goals': 0},
#   'datetime': u'2014-06-25T17:00:00.000-03:00',
#   'home_team': {u'code': u'ECU', u'country': u'Ecuador', u'goals': 0},
#   'lat': -22.912109,
#   'lng': -43.230156,
#   'location': u'Estadio do Maracana',
#   'match_number': 42,
#   'weather': {u'apparentTemperature': 76.07,
#    u'cloudCover': 0.17,
#    u'dewPoint': 65.35,
#    u'humidity': 0.69,
#    u'icon': u'clear-day',
#    u'ozone': 262.48,
#    u'precipIntensity': 0,
#    u'precipProbability': 0,
#    u'pressure': 1015.99,
#    u'summary': u'Clear',
#    u'temperature': 76.07,
#    u'time': 1403726400,
#    u'visibility': 4.35,
#    u'windBearing': 166,
#    u'windSpeed': 7.81},
#   'winner': u'ECU'},
#  {'away_team': {u'code': u'ARG', u'country': u'Argentina', u'goals': 3},
#   'datetime': u'2014-06-25T13:00:00.000-03:00',
#   'home_team': {u'code': u'NGA', u'country': u'Nigeria', u'goals': 2},
#   'lat': -30.065384,
#   'lng': -51.235822,
#   'location': u'Estadio Beira-Rio',
#   'match_number': 43,
#   'weather': {u'apparentTemperature': 69.82,
#    u'cloudCover': 0.75,
#    u'dewPoint': 64.27,
#    u'humidity': 0.83,
#    u'icon': u'rain',
#    u'ozone': 274.12,
#    u'precipIntensity': 0.018,
#    u'precipProbability': 0.66,
#    u'precipType': u'rain',
#    u'pressure': 1011.94,
#    u'summary': u'Light Rain',
#    u'temperature': 69.82,
#    u'time': 1403712000,
#    u'visibility': 3.82,
#    u'windBearing': 280,
#    u'windSpeed': 1.35},
#   'winner': u'ARG'},
#  {'away_team': {u'code': u'IRN', u'country': u'Iran', u'goals': 1},
#   'datetime': u'2014-06-25T13:00:00.000-03:00',
#   'home_team': {u'code': u'BIH',
#    u'country': u'Bosnia and Herzegovina',
#    u'goals': 3},
#   'lat': -12.97883,
#   'lng': -38.504371,
#   'location': u'Arena Fonte Nova',
#   'match_number': 44,
#   'weather': {u'apparentTemperature': 78.35,
#    u'cloudCover': 0.69,
#    u'dewPoint': 70.39,
#    u'humidity': 0.77,
#    u'icon': u'rain',
#    u'ozone': 253.89,
#    u'precipIntensity': 0.0097,
#    u'precipProbability': 0.32,
#    u'precipType': u'rain',
#    u'pressure': 1015.86,
#    u'summary': u'Drizzle',
#    u'temperature': 78.35,
#    u'time': 1403712000,
#    u'visibility': 10,
#    u'windBearing': 143,
#    u'windSpeed': 7.39},
#   'winner': u'BIH'},
#  {'away_team': {u'code': u'GER', u'country': u'Germany', u'goals': 1},
#   'datetime': u'2014-06-26T13:00:00.000-03:00',
#   'home_team': {u'code': u'USA', u'country': u'USA', u'goals': 0},
#   'lat': -8.04065,
#   'lng': -35.008205,
#   'location': u'Arena Pernambuco',
#   'match_number': 45,
#   'weather': {u'apparentTemperature': 79.15,
#    u'cloudCover': 0.76,
#    u'dewPoint': 74.67,
#    u'humidity': 0.86,
#    u'icon': u'partly-cloudy-day',
#    u'ozone': 249.56,
#    u'precipIntensity': 0,
#    u'precipProbability': 0,
#    u'pressure': 1014.18,
#    u'summary': u'Humid and Mostly Cloudy',
#    u'temperature': 79.15,
#    u'time': 1403798400,
#    u'windBearing': 102,
#    u'windSpeed': 7.37},
#   'winner': u'GER'},
#  {'away_team': {u'code': u'GHA', u'country': u'Ghana', u'goals': 1},
#   'datetime': u'2014-06-26T13:00:00.000-03:00',
#   'home_team': {u'code': u'POR', u'country': u'Portugal', u'goals': 2},
#   'lat': -15.783519,
#   'lng': -47.899211,
#   'location': u'Estadio Nacional',
#   'match_number': 46,
#   'weather': {u'apparentTemperature': 77.01,
#    u'cloudCover': 0.49,
#    u'dewPoint': 52.37,
#    u'humidity': 0.42,
#    u'icon': u'partly-cloudy-day',
#    u'ozone': 252.3,
#    u'precipIntensity': 0,
#    u'precipProbability': 0,
#    u'pressure': 1015.16,
#    u'summary': u'Partly Cloudy',
#    u'temperature': 77.01,
#    u'time': 1403798400,
#    u'windBearing': 71,
#    u'windSpeed': 6.56},
#   'winner': u'POR'},
#  {'away_team': {u'code': u'BEL', u'country': u'Belgium', u'goals': 1},
#   'datetime': u'2014-06-26T17:00:00.000-03:00',
#   'home_team': {u'code': u'KOR', u'country': u'Korea Republic', u'goals': 0},
#   'lat': -23.545333,
#   'lng': -46.473702,
#   'location': u'Arena de Sao Paulo',
#   'match_number': 47,
#   'weather': {u'apparentTemperature': 75.3,
#    u'cloudCover': 0.98,
#    u'dewPoint': 54.95,
#    u'humidity': 0.49,
#    u'icon': u'cloudy',
#    u'ozone': 264.28,
#    u'precipIntensity': 0.0002,
#    u'precipProbability': 0.89,
#    u'precipType': u'rain',
#    u'pressure': 1014.2,
#    u'summary': u'Overcast',
#    u'temperature': 75.3,
#    u'time': 1403812800,
#    u'visibility': 3.11,
#    u'windBearing': 312,
#    u'windSpeed': 3.94},
#   'winner': u'BEL'},
#  {'away_team': {u'code': u'RUS', u'country': u'Russia', u'goals': 1},
#   'datetime': u'2014-06-26T17:00:00.000-03:00',
#   'home_team': {u'code': u'ALG', u'country': u'Algeria', u'goals': 1},
#   'lat': -25.4482121,
#   'lng': -49.276987,
#   'location': u'Arena da Baixada',
#   'match_number': 48,
#   'weather': {u'apparentTemperature': 69.96,
#    u'cloudCover': 0.34,
#    u'dewPoint': 57.35,
#    u'humidity': 0.64,
#    u'icon': u'rain',
#    u'ozone': 272.45,
#    u'precipIntensity': 0.0027,
#    u'precipProbability': 0.74,
#    u'precipType': u'rain',
#    u'pressure': 1013.16,
#    u'summary': u'Drizzle',
#    u'temperature': 69.96,
#    u'time': 1403812800,
#    u'visibility': 6.21,
#    u'windBearing': 17,
#    u'windSpeed': 3.36},
#   'winner': u'ALG'}]

# %%
teams = []
for m in matches:
    if m['away_team']['code'] not in teams:
        teams.append(m['away_team']['code'])
    if m['home_team']['code'] not in teams:
        teams.append(m['home_team']['code'])
teams
# Out:
# [u'CRO',
#  u'BRA',
#  u'CMR',
#  u'MEX',
#  u'NED',
#  u'ESP',
#  u'AUS',
#  u'CHI',
#  u'GRE',
#  u'COL',
#  u'JPN',
#  u'CIV',
#  u'CRC',
#  u'URU',
#  u'ITA',
#  u'ENG',
#  u'ECU',
#  u'SUI',
#  u'HON',
#  u'FRA',
#  u'BIH',
#  u'ARG',
#  u'NGA',
#  u'IRN',
#  u'POR',
#  u'GER',
#  u'USA',
#  u'GHA',
#  u'ALG',
#  u'BEL',
#  u'KOR',
#  u'RUS']

# %%
groups = list('ABCDEFGH')
groups
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']

# %%
teams_data = { t : {'group' : groups[i/4],'code': t} for i,t in enumerate(teams)}
teams_data
# Out:
# {u'ALG': {'code': u'ALG', 'group': 'H'},
#  u'ARG': {'code': u'ARG', 'group': 'F'},
#  u'AUS': {'code': u'AUS', 'group': 'B'},
#  u'BEL': {'code': u'BEL', 'group': 'H'},
#  u'BIH': {'code': u'BIH', 'group': 'F'},
#  u'BRA': {'code': u'BRA', 'group': 'A'},
#  u'CHI': {'code': u'CHI', 'group': 'B'},
#  u'CIV': {'code': u'CIV', 'group': 'C'},
#  u'CMR': {'code': u'CMR', 'group': 'A'},
#  u'COL': {'code': u'COL', 'group': 'C'},
#  u'CRC': {'code': u'CRC', 'group': 'D'},
#  u'CRO': {'code': u'CRO', 'group': 'A'},
#  u'ECU': {'code': u'ECU', 'group': 'E'},
#  u'ENG': {'code': u'ENG', 'group': 'D'},
#  u'ESP': {'code': u'ESP', 'group': 'B'},
#  u'FRA': {'code': u'FRA', 'group': 'E'},
#  u'GER': {'code': u'GER', 'group': 'G'},
#  u'GHA': {'code': u'GHA', 'group': 'G'},
#  u'GRE': {'code': u'GRE', 'group': 'C'},
#  u'HON': {'code': u'HON', 'group': 'E'},
#  u'IRN': {'code': u'IRN', 'group': 'F'},
#  u'ITA': {'code': u'ITA', 'group': 'D'},
#  u'JPN': {'code': u'JPN', 'group': 'C'},
#  u'KOR': {'code': u'KOR', 'group': 'H'},
#  u'MEX': {'code': u'MEX', 'group': 'A'},
#  u'NED': {'code': u'NED', 'group': 'B'},
#  u'NGA': {'code': u'NGA', 'group': 'F'},
#  u'POR': {'code': u'POR', 'group': 'G'},
#  u'RUS': {'code': u'RUS', 'group': 'H'},
#  u'SUI': {'code': u'SUI', 'group': 'E'},
#  u'URU': {'code': u'URU', 'group': 'D'},
#  u'USA': {'code': u'USA', 'group': 'G'}}

# %%
for teamkey, team in teams_data.items():
    team['matches'] = []
    i = 0
    for match in weather:
        if (match['away_team']['code'] == teamkey or match['home_team']['code'] == teamkey) and match not in team['matches']:
            m = copy(match)
            i += 1
            m['number'] = i
            m['code'] = teamkey;
            team['matches'].append(m)
            if(match['away_team']['code'] == teamkey):
                team['country'] = match['away_team']['country']
            if(match['home_team']['code'] == teamkey):
                team['country'] = match['home_team']['country']
teams_data
# Out:
# {u'ALG': {'code': u'ALG',
#   'country': u'Algeria',
#   'group': 'H',
#   'matches': [{'away_team': {u'code': u'ALG',
#      u'country': u'Algeria',
#      u'goals': 1},
#     'code': u'ALG',
#     'datetime': u'2014-06-17T13:00:00.000-03:00',
#     'home_team': {u'code': u'BEL', u'country': u'Belgium', u'goals': 2},
#     'lat': -19.865867,
#     'lng': -43.971132,
#     'location': u'Estadio Mineirao',
#     'match_number': 15,
#     'number': 1,
#     'weather': {u'apparentTemperature': 75.65,
#      u'cloudCover': 0.72,
#      u'dewPoint': 54.55,
#      u'humidity': 0.48,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 252.39,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 0.87,
#      u'precipType': u'rain',
#      u'pressure': 1019.34,
#      u'summary': u'Mostly Cloudy',
#      u'temperature': 75.65,
#      u'time': 1403020800,
#      u'windBearing': 90,
#      u'windSpeed': 4.39}},
#    {'away_team': {u'code': u'ALG', u'country': u'Algeria', u'goals': 4},
#     'code': u'ALG',
#     'datetime': u'2014-06-22T16:00:00.000-03:00',
#     'home_team': {u'code': u'KOR', u'country': u'Korea Republic', u'goals': 2},
#     'lat': -30.065384,
#     'lng': -51.235822,
#     'location': u'Estadio Beira-Rio',
#     'match_number': 32,
#     'number': 2,
#     'weather': {u'apparentTemperature': 67.47,
#      u'cloudCover': 0.3,
#      u'dewPoint': 57.65,
#      u'humidity': 0.71,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 264.33,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1019.13,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 67.47,
#      u'time': 1403463600,
#      u'windBearing': 113,
#      u'windSpeed': 1.24}},
#    {'away_team': {u'code': u'RUS', u'country': u'Russia', u'goals': 1},
#     'code': u'ALG',
#     'datetime': u'2014-06-26T17:00:00.000-03:00',
#     'home_team': {u'code': u'ALG', u'country': u'Algeria', u'goals': 1},
#     'lat': -25.4482121,
#     'lng': -49.276987,
#     'location': u'Arena da Baixada',
#     'match_number': 48,
#     'number': 3,
#     'weather': {u'apparentTemperature': 69.96,
#      u'cloudCover': 0.34,
#      u'dewPoint': 57.35,
#      u'humidity': 0.64,
#      u'icon': u'rain',
#      u'ozone': 272.45,
#      u'precipIntensity': 0.0027,
#      u'precipProbability': 0.74,
#      u'precipType': u'rain',
#      u'pressure': 1013.16,
#      u'summary': u'Drizzle',
#      u'temperature': 69.96,
#      u'time': 1403812800,
#      u'visibility': 6.21,
#      u'windBearing': 17,
#      u'windSpeed': 3.36}}]},
#  u'ARG': {'code': u'ARG',
#   'country': u'Argentina',
#   'group': 'F',
#   'matches': [{'away_team': {u'code': u'BIH',
#      u'country': u'Bosnia and Herzegovina',
#      u'goals': 1},
#     'code': u'ARG',
#     'datetime': u'2014-06-15T19:00:00.000-03:00',
#     'home_team': {u'code': u'ARG', u'country': u'Argentina', u'goals': 2},
#     'lat': -22.912109,
#     'lng': -43.230156,
#     'location': u'Estadio do Maracana',
#     'match_number': 11,
#     'number': 1,
#     'weather': {u'apparentTemperature': 71.96,
#      u'cloudCover': 0,
#      u'dewPoint': 67.26,
#      u'humidity': 0.85,
#      u'icon': u'rain',
#      u'ozone': 249.87,
#      u'precipIntensity': 0.0033,
#      u'precipProbability': 0.67,
#      u'precipType': u'rain',
#      u'pressure': 1021.92,
#      u'summary': u'Drizzle',
#      u'temperature': 71.96,
#      u'time': 1402869600,
#      u'visibility': 6.2,
#      u'windBearing': 215,
#      u'windSpeed': 5.58}},
#    {'away_team': {u'code': u'IRN', u'country': u'Iran', u'goals': 0},
#     'code': u'ARG',
#     'datetime': u'2014-06-21T13:00:00.000-03:00',
#     'home_team': {u'code': u'ARG', u'country': u'Argentina', u'goals': 1},
#     'lat': -19.865867,
#     'lng': -43.971132,
#     'location': u'Estadio Mineirao',
#     'match_number': 27,
#     'number': 2,
#     'weather': {u'apparentTemperature': 72.39,
#      u'cloudCover': 0.54,
#      u'dewPoint': 57.64,
#      u'humidity': 0.6,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 266.23,
#      u'precipIntensity': 0.0016,
#      u'precipProbability': 0.93,
#      u'precipType': u'rain',
#      u'pressure': 1019.94,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 72.39,
#      u'time': 1403366400,
#      u'visibility': 6.2,
#      u'windBearing': 84,
#      u'windSpeed': 5.45}},
#    {'away_team': {u'code': u'ARG', u'country': u'Argentina', u'goals': 3},
#     'code': u'ARG',
#     'datetime': u'2014-06-25T13:00:00.000-03:00',
#     'home_team': {u'code': u'NGA', u'country': u'Nigeria', u'goals': 2},
#     'lat': -30.065384,
#     'lng': -51.235822,
#     'location': u'Estadio Beira-Rio',
#     'match_number': 43,
#     'number': 3,
#     'weather': {u'apparentTemperature': 69.82,
#      u'cloudCover': 0.75,
#      u'dewPoint': 64.27,
#      u'humidity': 0.83,
#      u'icon': u'rain',
#      u'ozone': 274.12,
#      u'precipIntensity': 0.018,
#      u'precipProbability': 0.66,
#      u'precipType': u'rain',
#      u'pressure': 1011.94,
#      u'summary': u'Light Rain',
#      u'temperature': 69.82,
#      u'time': 1403712000,
#      u'visibility': 3.82,
#      u'windBearing': 280,
#      u'windSpeed': 1.35}}]},
#  u'AUS': {'code': u'AUS',
#   'country': u'Australia',
#   'group': 'B',
#   'matches': [{'away_team': {u'code': u'AUS',
#      u'country': u'Australia',
#      u'goals': 1},
#     'code': u'AUS',
#     'datetime': u'2014-06-13T19:00:00.000-03:00',
#     'home_team': {u'code': u'CHI', u'country': u'Chile', u'goals': 3},
#     'lat': -15.604017,
#     'lng': -56.121632,
#     'location': u'Arena Pantanal',
#     'match_number': 4,
#     'number': 1,
#     'weather': {u'apparentTemperature': 75,
#      u'dewPoint': 66.14,
#      u'humidity': 0.74,
#      u'icon': u'clear-night',
#      u'precipType': u'rain',
#      u'summary': u'Clear',
#      u'temperature': 75,
#      u'time': 1402700400,
#      u'windBearing': 0,
#      u'windSpeed': 3}},
#    {'away_team': {u'code': u'NED', u'country': u'Netherlands', u'goals': 3},
#     'code': u'AUS',
#     'datetime': u'2014-06-18T13:00:00.000-03:00',
#     'home_team': {u'code': u'AUS', u'country': u'Australia', u'goals': 2},
#     'lat': -30.065384,
#     'lng': -51.235822,
#     'location': u'Estadio Beira-Rio',
#     'match_number': 20,
#     'number': 2,
#     'weather': {u'apparentTemperature': 58.43,
#      u'cloudCover': 0.02,
#      u'dewPoint': 45.08,
#      u'humidity': 0.61,
#      u'icon': u'clear-day',
#      u'ozone': 312.67,
#      u'precipIntensity': 0.0005,
#      u'precipProbability': 0.88,
#      u'precipType': u'rain',
#      u'pressure': 1027.65,
#      u'summary': u'Clear',
#      u'temperature': 58.43,
#      u'time': 1403107200,
#      u'visibility': 6.2,
#      u'windBearing': 217,
#      u'windSpeed': 7.18}},
#    {'away_team': {u'code': u'ESP', u'country': u'Spain', u'goals': 3},
#     'code': u'AUS',
#     'datetime': u'2014-06-23T13:00:00.000-03:00',
#     'home_team': {u'code': u'AUS', u'country': u'Australia', u'goals': 0},
#     'lat': -25.4482121,
#     'lng': -49.276987,
#     'location': u'Arena da Baixada',
#     'match_number': 35,
#     'number': 3,
#     'weather': {u'apparentTemperature': 68.42,
#      u'cloudCover': 0.84,
#      u'dewPoint': 60.71,
#      u'humidity': 0.76,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 275.51,
#      u'precipIntensity': 0.0003,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1019.55,
#      u'summary': u'Mostly Cloudy',
#      u'temperature': 68.42,
#      u'time': 1403539200,
#      u'windBearing': 346,
#      u'windSpeed': 3.5}}]},
#  u'BEL': {'code': u'BEL',
#   'country': u'Belgium',
#   'group': 'H',
#   'matches': [{'away_team': {u'code': u'ALG',
#      u'country': u'Algeria',
#      u'goals': 1},
#     'code': u'BEL',
#     'datetime': u'2014-06-17T13:00:00.000-03:00',
#     'home_team': {u'code': u'BEL', u'country': u'Belgium', u'goals': 2},
#     'lat': -19.865867,
#     'lng': -43.971132,
#     'location': u'Estadio Mineirao',
#     'match_number': 15,
#     'number': 1,
#     'weather': {u'apparentTemperature': 75.65,
#      u'cloudCover': 0.72,
#      u'dewPoint': 54.55,
#      u'humidity': 0.48,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 252.39,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 0.87,
#      u'precipType': u'rain',
#      u'pressure': 1019.34,
#      u'summary': u'Mostly Cloudy',
#      u'temperature': 75.65,
#      u'time': 1403020800,
#      u'windBearing': 90,
#      u'windSpeed': 4.39}},
#    {'away_team': {u'code': u'RUS', u'country': u'Russia', u'goals': 0},
#     'code': u'BEL',
#     'datetime': u'2014-06-22T13:00:00.000-03:00',
#     'home_team': {u'code': u'BEL', u'country': u'Belgium', u'goals': 1},
#     'lat': -22.912109,
#     'lng': -43.230156,
#     'location': u'Estadio do Maracana',
#     'match_number': 31,
#     'number': 2,
#     'weather': {u'apparentTemperature': 76.48,
#      u'cloudCover': 0.05,
#      u'dewPoint': 67.53,
#      u'humidity': 0.74,
#      u'icon': u'rain',
#      u'ozone': 270.16,
#      u'precipIntensity': 0.0031,
#      u'precipProbability': 0.81,
#      u'precipType': u'rain',
#      u'pressure': 1023.39,
#      u'summary': u'Drizzle',
#      u'temperature': 76.48,
#      u'time': 1403452800,
#      u'windBearing': 84,
#      u'windSpeed': 10.35}},
#    {'away_team': {u'code': u'BEL', u'country': u'Belgium', u'goals': 1},
#     'code': u'BEL',
#     'datetime': u'2014-06-26T17:00:00.000-03:00',
#     'home_team': {u'code': u'KOR', u'country': u'Korea Republic', u'goals': 0},
#     'lat': -23.545333,
#     'lng': -46.473702,
#     'location': u'Arena de Sao Paulo',
#     'match_number': 47,
#     'number': 3,
#     'weather': {u'apparentTemperature': 75.3,
#      u'cloudCover': 0.98,
#      u'dewPoint': 54.95,
#      u'humidity': 0.49,
#      u'icon': u'cloudy',
#      u'ozone': 264.28,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 0.89,
#      u'precipType': u'rain',
#      u'pressure': 1014.2,
#      u'summary': u'Overcast',
#      u'temperature': 75.3,
#      u'time': 1403812800,
#      u'visibility': 3.11,
#      u'windBearing': 312,
#      u'windSpeed': 3.94}}]},
#  u'BIH': {'code': u'BIH',
#   'country': u'Bosnia and Herzegovina',
#   'group': 'F',
#   'matches': [{'away_team': {u'code': u'BIH',
#      u'country': u'Bosnia and Herzegovina',
#      u'goals': 1},
#     'code': u'BIH',
#     'datetime': u'2014-06-15T19:00:00.000-03:00',
#     'home_team': {u'code': u'ARG', u'country': u'Argentina', u'goals': 2},
#     'lat': -22.912109,
#     'lng': -43.230156,
#     'location': u'Estadio do Maracana',
#     'match_number': 11,
#     'number': 1,
#     'weather': {u'apparentTemperature': 71.96,
#      u'cloudCover': 0,
#      u'dewPoint': 67.26,
#      u'humidity': 0.85,
#      u'icon': u'rain',
#      u'ozone': 249.87,
#      u'precipIntensity': 0.0033,
#      u'precipProbability': 0.67,
#      u'precipType': u'rain',
#      u'pressure': 1021.92,
#      u'summary': u'Drizzle',
#      u'temperature': 71.96,
#      u'time': 1402869600,
#      u'visibility': 6.2,
#      u'windBearing': 215,
#      u'windSpeed': 5.58}},
#    {'away_team': {u'code': u'BIH',
#      u'country': u'Bosnia and Herzegovina',
#      u'goals': 0},
#     'code': u'BIH',
#     'datetime': u'2014-06-21T19:00:00.000-03:00',
#     'home_team': {u'code': u'NGA', u'country': u'Nigeria', u'goals': 1},
#     'lat': -15.604017,
#     'lng': -56.121632,
#     'location': u'Arena Pantanal',
#     'match_number': 28,
#     'number': 2,
#     'weather': {u'apparentTemperature': 76.62,
#      u'cloudCover': 0.32,
#      u'dewPoint': 68.24,
#      u'humidity': 0.75,
#      u'icon': u'partly-cloudy-night',
#      u'ozone': 254.45,
#      u'precipIntensity': 0.0001,
#      u'precipProbability': 0.98,
#      u'precipType': u'rain',
#      u'pressure': 1013.16,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 76.62,
#      u'time': 1403391600,
#      u'windBearing': 144,
#      u'windSpeed': 0.95}},
#    {'away_team': {u'code': u'IRN', u'country': u'Iran', u'goals': 1},
#     'code': u'BIH',
#     'datetime': u'2014-06-25T13:00:00.000-03:00',
#     'home_team': {u'code': u'BIH',
#      u'country': u'Bosnia and Herzegovina',
#      u'goals': 3},
#     'lat': -12.97883,
#     'lng': -38.504371,
#     'location': u'Arena Fonte Nova',
#     'match_number': 44,
#     'number': 3,
#     'weather': {u'apparentTemperature': 78.35,
#      u'cloudCover': 0.69,
#      u'dewPoint': 70.39,
#      u'humidity': 0.77,
#      u'icon': u'rain',
#      u'ozone': 253.89,
#      u'precipIntensity': 0.0097,
#      u'precipProbability': 0.32,
#      u'precipType': u'rain',
#      u'pressure': 1015.86,
#      u'summary': u'Drizzle',
#      u'temperature': 78.35,
#      u'time': 1403712000,
#      u'visibility': 10,
#      u'windBearing': 143,
#      u'windSpeed': 7.39}}]},
#  u'BRA': {'code': u'BRA',
#   'country': u'Brazil',
#   'group': 'A',
#   'matches': [{'away_team': {u'code': u'CRO',
#      u'country': u'Croatia',
#      u'goals': 1},
#     'code': u'BRA',
#     'datetime': u'2014-06-12T17:00:00.000-03:00',
#     'home_team': {u'code': u'BRA', u'country': u'Brazil', u'goals': 3},
#     'lat': -23.545333,
#     'lng': -46.473702,
#     'location': u'Arena de Sao Paulo',
#     'match_number': 1,
#     'number': 1,
#     'weather': {u'apparentTemperature': 74.8,
#      u'dewPoint': 62.7,
#      u'humidity': 0.66,
#      u'icon': u'clear-day',
#      u'precipType': u'rain',
#      u'summary': u'Clear',
#      u'temperature': 74.8,
#      u'time': 1402603200,
#      u'visibility': 6.2,
#      u'windBearing': 82,
#      u'windSpeed': 8.26}},
#    {'away_team': {u'code': u'MEX', u'country': u'Mexico', u'goals': 0},
#     'code': u'BRA',
#     'datetime': u'2014-06-17T16:00:00.000-03:00',
#     'home_team': {u'code': u'BRA', u'country': u'Brazil', u'goals': 0},
#     'lat': -3.807231,
#     'lng': -38.522434,
#     'location': u'Estadio Castelao',
#     'match_number': 17,
#     'number': 2,
#     'weather': {u'apparentTemperature': 87.93,
#      u'cloudCover': 0.43,
#      u'dewPoint': 70.16,
#      u'humidity': 0.64,
#      u'icon': u'rain',
#      u'ozone': 257.01,
#      u'precipIntensity': 0.0046,
#      u'precipProbability': 0.62,
#      u'precipType': u'rain',
#      u'pressure': 1012.35,
#      u'summary': u'Drizzle',
#      u'temperature': 83.59,
#      u'time': 1403031600,
#      u'visibility': 6.2,
#      u'windBearing': 92,
#      u'windSpeed': 14.24}},
#    {'away_team': {u'code': u'BRA', u'country': u'Brazil', u'goals': 4},
#     'code': u'BRA',
#     'datetime': u'2014-06-23T17:00:00.000-03:00',
#     'home_team': {u'code': u'CMR', u'country': u'Cameroon', u'goals': 1},
#     'lat': -15.783519,
#     'lng': -47.899211,
#     'location': u'Estadio Nacional',
#     'match_number': 33,
#     'number': 3,
#     'weather': {u'apparentTemperature': 72.01,
#      u'cloudCover': 0.98,
#      u'dewPoint': 58.63,
#      u'humidity': 0.63,
#      u'icon': u'cloudy',
#      u'ozone': 251.39,
#      u'precipIntensity': 0.0004,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1017.79,
#      u'summary': u'Overcast',
#      u'temperature': 72.01,
#      u'time': 1403553600,
#      u'windBearing': 76,
#      u'windSpeed': 7.63}}]},
#  u'CHI': {'code': u'CHI',
#   'country': u'Chile',
#   'group': 'B',
#   'matches': [{'away_team': {u'code': u'AUS',
#      u'country': u'Australia',
#      u'goals': 1},
#     'code': u'CHI',
#     'datetime': u'2014-06-13T19:00:00.000-03:00',
#     'home_team': {u'code': u'CHI', u'country': u'Chile', u'goals': 3},
#     'lat': -15.604017,
#     'lng': -56.121632,
#     'location': u'Arena Pantanal',
#     'match_number': 4,
#     'number': 1,
#     'weather': {u'apparentTemperature': 75,
#      u'dewPoint': 66.14,
#      u'humidity': 0.74,
#      u'icon': u'clear-night',
#      u'precipType': u'rain',
#      u'summary': u'Clear',
#      u'temperature': 75,
#      u'time': 1402700400,
#      u'windBearing': 0,
#      u'windSpeed': 3}},
#    {'away_team': {u'code': u'CHI', u'country': u'Chile', u'goals': 2},
#     'code': u'CHI',
#     'datetime': u'2014-06-18T16:00:00.000-03:00',
#     'home_team': {u'code': u'ESP', u'country': u'Spain', u'goals': 0},
#     'lat': -22.912109,
#     'lng': -43.230156,
#     'location': u'Estadio do Maracana',
#     'match_number': 19,
#     'number': 2,
#     'weather': {u'apparentTemperature': 73.6,
#      u'cloudCover': 0.25,
#      u'dewPoint': 67.93,
#      u'humidity': 0.83,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 263.01,
#      u'precipIntensity': 0.0006,
#      u'precipProbability': 0.88,
#      u'precipType': u'rain',
#      u'pressure': 1019.46,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 73.6,
#      u'time': 1403118000,
#      u'visibility': 3.53,
#      u'windBearing': 202,
#      u'windSpeed': 9.2}},
#    {'away_team': {u'code': u'CHI', u'country': u'Chile', u'goals': 0},
#     'code': u'CHI',
#     'datetime': u'2014-06-23T13:00:00.000-03:00',
#     'home_team': {u'code': u'NED', u'country': u'Netherlands', u'goals': 2},
#     'lat': -23.545333,
#     'lng': -46.473702,
#     'location': u'Arena de Sao Paulo',
#     'match_number': 36,
#     'number': 3,
#     'weather': {u'apparentTemperature': 73.86,
#      u'cloudCover': 0.82,
#      u'dewPoint': 63.24,
#      u'humidity': 0.69,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 265.14,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1020.67,
#      u'summary': u'Mostly Cloudy',
#      u'temperature': 73.86,
#      u'time': 1403539200,
#      u'windBearing': 337,
#      u'windSpeed': 3.68}}]},
#  u'CIV': {'code': u'CIV',
#   'country': u'Ivory Coast',
#   'group': 'C',
#   'matches': [{'away_team': {u'code': u'JPN',
#      u'country': u'Japan',
#      u'goals': 1},
#     'code': u'CIV',
#     'datetime': u'2014-06-14T22:00:00.000-03:00',
#     'home_team': {u'code': u'CIV', u'country': u'Ivory Coast', u'goals': 2},
#     'lat': -8.04065,
#     'lng': -35.008205,
#     'location': u'Arena Pernambuco',
#     'match_number': 6,
#     'number': 1,
#     'weather': {u'apparentTemperature': 74.82,
#      u'cloudCover': 0.05,
#      u'dewPoint': 71.3,
#      u'humidity': 0.89,
#      u'icon': u'clear-night',
#      u'ozone': 251.46,
#      u'precipIntensity': 0.0219,
#      u'precipProbability': 0.12,
#      u'precipType': u'rain',
#      u'pressure': 1015.85,
#      u'summary': u'Clear',
#      u'temperature': 74.82,
#      u'time': 1402794000,
#      u'visibility': 5.34,
#      u'windBearing': 141,
#      u'windSpeed': 9.43}},
#    {'away_team': {u'code': u'CIV', u'country': u'Ivory Coast', u'goals': 1},
#     'code': u'CIV',
#     'datetime': u'2014-06-19T13:00:00.000-03:00',
#     'home_team': {u'code': u'COL', u'country': u'Colombia', u'goals': 2},
#     'lat': -15.783519,
#     'lng': -47.899211,
#     'location': u'Estadio Nacional',
#     'match_number': 21,
#     'number': 2,
#     'weather': {u'apparentTemperature': 77.98,
#      u'cloudCover': 0.98,
#      u'dewPoint': 56.53,
#      u'humidity': 0.48,
#      u'icon': u'cloudy',
#      u'ozone': 259.05,
#      u'precipIntensity': 0.0003,
#      u'precipProbability': 0.92,
#      u'precipType': u'rain',
#      u'pressure': 1018.22,
#      u'summary': u'Overcast',
#      u'temperature': 77.98,
#      u'time': 1403193600,
#      u'visibility': 6.2,
#      u'windBearing': 152,
#      u'windSpeed': 6.07}},
#    {'away_team': {u'code': u'CIV', u'country': u'Ivory Coast', u'goals': 1},
#     'code': u'CIV',
#     'datetime': u'2014-06-24T17:00:00.000-03:00',
#     'home_team': {u'code': u'GRE', u'country': u'Greece', u'goals': 2},
#     'lat': -3.807231,
#     'lng': -38.522434,
#     'location': u'Estadio Castelao',
#     'match_number': 38,
#     'number': 3,
#     'weather': {u'apparentTemperature': 88.93,
#      u'cloudCover': 0.61,
#      u'dewPoint': 71.26,
#      u'humidity': 0.66,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 252.84,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1012.02,
#      u'summary': u'Mostly Cloudy',
#      u'temperature': 83.84,
#      u'time': 1403640000,
#      u'windBearing': 65,
#      u'windSpeed': 16.09}}]},
#  u'CMR': {'code': u'CMR',
#   'country': u'Cameroon',
#   'group': 'A',
#   'matches': [{'away_team': {u'code': u'CMR',
#      u'country': u'Cameroon',
#      u'goals': 0},
#     'code': u'CMR',
#     'datetime': u'2014-06-13T13:00:00.000-03:00',
#     'home_team': {u'code': u'MEX', u'country': u'Mexico', u'goals': 1},
#     'lat': -5.826827,
#     'lng': -35.21243,
#     'location': u'Estadio das Dunas',
#     'match_number': 2,
#     'number': 1,
#     'weather': {u'apparentTemperature': 73.92,
#      u'dewPoint': 72.01,
#      u'humidity': 0.94,
#      u'icon': u'clear-day',
#      u'precipType': u'rain',
#      u'summary': u'Humid',
#      u'temperature': 73.92,
#      u'time': 1402675200,
#      u'visibility': 3.47,
#      u'windBearing': 87,
#      u'windSpeed': 5.08}},
#    {'away_team': {u'code': u'CRO', u'country': u'Croatia', u'goals': 4},
#     'code': u'CMR',
#     'datetime': u'2014-06-18T19:00:00.000-03:00',
#     'home_team': {u'code': u'CMR', u'country': u'Cameroon', u'goals': 0},
#     'lat': -3.083142,
#     'lng': -60.028108,
#     'location': u'Arena Amazonia',
#     'match_number': 18,
#     'number': 2,
#     'weather': {u'apparentTemperature': 77.22,
#      u'cloudCover': 0.81,
#      u'dewPoint': 73.32,
#      u'humidity': 0.88,
#      u'icon': u'rain',
#      u'ozone': 249.45,
#      u'precipIntensity': 0.0115,
#      u'precipProbability': 0.4,
#      u'precipType': u'rain',
#      u'pressure': 1014.23,
#      u'summary': u'Drizzle',
#      u'temperature': 77.22,
#      u'time': 1403132400,
#      u'visibility': 6.2,
#      u'windBearing': 57,
#      u'windSpeed': 1.45}},
#    {'away_team': {u'code': u'BRA', u'country': u'Brazil', u'goals': 4},
#     'code': u'CMR',
#     'datetime': u'2014-06-23T17:00:00.000-03:00',
#     'home_team': {u'code': u'CMR', u'country': u'Cameroon', u'goals': 1},
#     'lat': -15.783519,
#     'lng': -47.899211,
#     'location': u'Estadio Nacional',
#     'match_number': 33,
#     'number': 3,
#     'weather': {u'apparentTemperature': 72.01,
#      u'cloudCover': 0.98,
#      u'dewPoint': 58.63,
#      u'humidity': 0.63,
#      u'icon': u'cloudy',
#      u'ozone': 251.39,
#      u'precipIntensity': 0.0004,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1017.79,
#      u'summary': u'Overcast',
#      u'temperature': 72.01,
#      u'time': 1403553600,
#      u'windBearing': 76,
#      u'windSpeed': 7.63}}]},
#  u'COL': {'code': u'COL',
#   'country': u'Colombia',
#   'group': 'C',
#   'matches': [{'away_team': {u'code': u'GRE',
#      u'country': u'Greece',
#      u'goals': 0},
#     'code': u'COL',
#     'datetime': u'2014-06-14T13:00:00.000-03:00',
#     'home_team': {u'code': u'COL', u'country': u'Colombia', u'goals': 3},
#     'lat': -19.865867,
#     'lng': -43.971132,
#     'location': u'Estadio Mineirao',
#     'match_number': 5,
#     'number': 1,
#     'weather': {u'apparentTemperature': 72.26,
#      u'cloudCover': 0.7,
#      u'dewPoint': 55.19,
#      u'humidity': 0.55,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 255.8,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 0.8,
#      u'precipType': u'rain',
#      u'pressure': 1020.92,
#      u'summary': u'Mostly Cloudy',
#      u'temperature': 72.26,
#      u'time': 1402761600,
#      u'visibility': 6.2,
#      u'windBearing': 84,
#      u'windSpeed': 7.13}},
#    {'away_team': {u'code': u'CIV', u'country': u'Ivory Coast', u'goals': 1},
#     'code': u'COL',
#     'datetime': u'2014-06-19T13:00:00.000-03:00',
#     'home_team': {u'code': u'COL', u'country': u'Colombia', u'goals': 2},
#     'lat': -15.783519,
#     'lng': -47.899211,
#     'location': u'Estadio Nacional',
#     'match_number': 21,
#     'number': 2,
#     'weather': {u'apparentTemperature': 77.98,
#      u'cloudCover': 0.98,
#      u'dewPoint': 56.53,
#      u'humidity': 0.48,
#      u'icon': u'cloudy',
#      u'ozone': 259.05,
#      u'precipIntensity': 0.0003,
#      u'precipProbability': 0.92,
#      u'precipType': u'rain',
#      u'pressure': 1018.22,
#      u'summary': u'Overcast',
#      u'temperature': 77.98,
#      u'time': 1403193600,
#      u'visibility': 6.2,
#      u'windBearing': 152,
#      u'windSpeed': 6.07}},
#    {'away_team': {u'code': u'COL', u'country': u'Colombia', u'goals': 4},
#     'code': u'COL',
#     'datetime': u'2014-06-24T17:00:00.000-03:00',
#     'home_team': {u'code': u'JPN', u'country': u'Japan', u'goals': 1},
#     'lat': -15.604017,
#     'lng': -56.121632,
#     'location': u'Arena Pantanal',
#     'match_number': 37,
#     'number': 3,
#     'weather': {u'apparentTemperature': 81.38,
#      u'cloudCover': 0.35,
#      u'dewPoint': 56.86,
#      u'humidity': 0.43,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 252.9,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1013.16,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 81.5,
#      u'time': 1403643600,
#      u'windBearing': 55,
#      u'windSpeed': 3.84}}]},
#  u'CRC': {'code': u'CRC',
#   'country': u'Costa Rica',
#   'group': 'D',
#   'matches': [{'away_team': {u'code': u'CRC',
#      u'country': u'Costa Rica',
#      u'goals': 3},
#     'code': u'CRC',
#     'datetime': u'2014-06-14T16:00:00.000-03:00',
#     'home_team': {u'code': u'URU', u'country': u'Uruguay', u'goals': 1},
#     'lat': -3.807231,
#     'lng': -38.522434,
#     'location': u'Estadio Castelao',
#     'match_number': 7,
#     'number': 1,
#     'weather': {u'apparentTemperature': 87.58,
#      u'cloudCover': 0.22,
#      u'dewPoint': 67.53,
#      u'humidity': 0.57,
#      u'icon': u'rain',
#      u'ozone': 247.92,
#      u'precipIntensity': 0.0046,
#      u'precipProbability': 0.61,
#      u'precipType': u'rain',
#      u'pressure': 1011.52,
#      u'summary': u'Drizzle',
#      u'temperature': 84.56,
#      u'time': 1402772400,
#      u'visibility': 6.2,
#      u'windBearing': 94,
#      u'windSpeed': 10.27}},
#    {'away_team': {u'code': u'CRC', u'country': u'Costa Rica', u'goals': 1},
#     'code': u'CRC',
#     'datetime': u'2014-06-20T13:00:00.000-03:00',
#     'home_team': {u'code': u'ITA', u'country': u'Italy', u'goals': 0},
#     'lat': -8.04065,
#     'lng': -35.008205,
#     'location': u'Arena Pernambuco',
#     'match_number': 24,
#     'number': 2,
#     'weather': {u'apparentTemperature': 86.1,
#      u'cloudCover': 0.23,
#      u'dewPoint': 70.47,
#      u'humidity': 0.68,
#      u'icon': u'rain',
#      u'ozone': 257.87,
#      u'precipIntensity': 0.0052,
#      u'precipProbability': 0.64,
#      u'precipType': u'rain',
#      u'pressure': 1015.33,
#      u'summary': u'Drizzle',
#      u'temperature': 82.04,
#      u'time': 1403280000,
#      u'visibility': 6.2,
#      u'windBearing': 149,
#      u'windSpeed': 14.06}},
#    {'away_team': {u'code': u'ENG', u'country': u'England', u'goals': 0},
#     'code': u'CRC',
#     'datetime': u'2014-06-24T13:00:00.000-03:00',
#     'home_team': {u'code': u'CRC', u'country': u'Costa Rica', u'goals': 0},
#     'lat': -19.865867,
#     'lng': -43.971132,
#     'location': u'Estadio Mineirao',
#     'match_number': 40,
#     'number': 3,
#     'weather': {u'apparentTemperature': 76.16,
#      u'cloudCover': 0.41,
#      u'dewPoint': 54.04,
#      u'humidity': 0.46,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 264.8,
#      u'precipIntensity': 0.0001,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1019.44,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 76.16,
#      u'time': 1403625600,
#      u'visibility': 6.21,
#      u'windBearing': 70,
#      u'windSpeed': 6.17}}]},
#  u'CRO': {'code': u'CRO',
#   'country': u'Croatia',
#   'group': 'A',
#   'matches': [{'away_team': {u'code': u'CRO',
#      u'country': u'Croatia',
#      u'goals': 1},
#     'code': u'CRO',
#     'datetime': u'2014-06-12T17:00:00.000-03:00',
#     'home_team': {u'code': u'BRA', u'country': u'Brazil', u'goals': 3},
#     'lat': -23.545333,
#     'lng': -46.473702,
#     'location': u'Arena de Sao Paulo',
#     'match_number': 1,
#     'number': 1,
#     'weather': {u'apparentTemperature': 74.8,
#      u'dewPoint': 62.7,
#      u'humidity': 0.66,
#      u'icon': u'clear-day',
#      u'precipType': u'rain',
#      u'summary': u'Clear',
#      u'temperature': 74.8,
#      u'time': 1402603200,
#      u'visibility': 6.2,
#      u'windBearing': 82,
#      u'windSpeed': 8.26}},
#    {'away_team': {u'code': u'CRO', u'country': u'Croatia', u'goals': 4},
#     'code': u'CRO',
#     'datetime': u'2014-06-18T19:00:00.000-03:00',
#     'home_team': {u'code': u'CMR', u'country': u'Cameroon', u'goals': 0},
#     'lat': -3.083142,
#     'lng': -60.028108,
#     'location': u'Arena Amazonia',
#     'match_number': 18,
#     'number': 2,
#     'weather': {u'apparentTemperature': 77.22,
#      u'cloudCover': 0.81,
#      u'dewPoint': 73.32,
#      u'humidity': 0.88,
#      u'icon': u'rain',
#      u'ozone': 249.45,
#      u'precipIntensity': 0.0115,
#      u'precipProbability': 0.4,
#      u'precipType': u'rain',
#      u'pressure': 1014.23,
#      u'summary': u'Drizzle',
#      u'temperature': 77.22,
#      u'time': 1403132400,
#      u'visibility': 6.2,
#      u'windBearing': 57,
#      u'windSpeed': 1.45}},
#    {'away_team': {u'code': u'MEX', u'country': u'Mexico', u'goals': 3},
#     'code': u'CRO',
#     'datetime': u'2014-06-23T17:00:00.000-03:00',
#     'home_team': {u'code': u'CRO', u'country': u'Croatia', u'goals': 1},
#     'lat': -8.04065,
#     'lng': -35.008205,
#     'location': u'Arena Pernambuco',
#     'match_number': 34,
#     'number': 3,
#     'weather': {u'apparentTemperature': 76.35,
#      u'cloudCover': 0.94,
#      u'dewPoint': 72.02,
#      u'humidity': 0.87,
#      u'icon': u'cloudy',
#      u'ozone': 254.04,
#      u'precipIntensity': 0.0293,
#      u'precipProbability': 0.03,
#      u'precipType': u'rain',
#      u'pressure': 1016.7,
#      u'summary': u'Humid and Overcast',
#      u'temperature': 76.35,
#      u'time': 1403553600,
#      u'windBearing': 149,
#      u'windSpeed': 10.8}}]},
#  u'ECU': {'code': u'ECU',
#   'country': u'Ecuador',
#   'group': 'E',
#   'matches': [{'away_team': {u'code': u'ECU',
#      u'country': u'Ecuador',
#      u'goals': 1},
#     'code': u'ECU',
#     'datetime': u'2014-06-15T13:00:00.000-03:00',
#     'home_team': {u'code': u'SUI', u'country': u'Switzerland', u'goals': 2},
#     'lat': -15.783519,
#     'lng': -47.899211,
#     'location': u'Estadio Nacional',
#     'match_number': 9,
#     'number': 1,
#     'weather': {u'apparentTemperature': 73.4,
#      u'cloudCover': 0.97,
#      u'dewPoint': 59.17,
#      u'humidity': 0.61,
#      u'icon': u'cloudy',
#      u'ozone': 254.22,
#      u'precipIntensity': 0.0009,
#      u'precipProbability': 0.8,
#      u'precipType': u'rain',
#      u'pressure': 1017.56,
#      u'summary': u'Overcast',
#      u'temperature': 73.4,
#      u'time': 1402848000,
#      u'visibility': 6.2,
#      u'windBearing': 92,
#      u'windSpeed': 9.32}},
#    {'away_team': {u'code': u'ECU', u'country': u'Ecuador', u'goals': 2},
#     'code': u'ECU',
#     'datetime': u'2014-06-20T19:00:00.000-03:00',
#     'home_team': {u'code': u'HON', u'country': u'Honduras', u'goals': 1},
#     'lat': -25.4482121,
#     'lng': -49.276987,
#     'location': u'Arena da Baixada',
#     'match_number': 26,
#     'number': 2,
#     'weather': {u'apparentTemperature': 54.76,
#      u'cloudCover': 1,
#      u'dewPoint': 51.02,
#      u'humidity': 0.87,
#      u'icon': u'cloudy',
#      u'ozone': 291.34,
#      u'precipIntensity': 0.0003,
#      u'precipProbability': 0.95,
#      u'precipType': u'rain',
#      u'pressure': 1022.15,
#      u'summary': u'Overcast',
#      u'temperature': 54.76,
#      u'time': 1403301600,
#      u'visibility': 6.2,
#      u'windBearing': 108,
#      u'windSpeed': 2.72}},
#    {'away_team': {u'code': u'FRA', u'country': u'France', u'goals': 0},
#     'code': u'ECU',
#     'datetime': u'2014-06-25T17:00:00.000-03:00',
#     'home_team': {u'code': u'ECU', u'country': u'Ecuador', u'goals': 0},
#     'lat': -22.912109,
#     'lng': -43.230156,
#     'location': u'Estadio do Maracana',
#     'match_number': 42,
#     'number': 3,
#     'weather': {u'apparentTemperature': 76.07,
#      u'cloudCover': 0.17,
#      u'dewPoint': 65.35,
#      u'humidity': 0.69,
#      u'icon': u'clear-day',
#      u'ozone': 262.48,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1015.99,
#      u'summary': u'Clear',
#      u'temperature': 76.07,
#      u'time': 1403726400,
#      u'visibility': 4.35,
#      u'windBearing': 166,
#      u'windSpeed': 7.81}}]},
#  u'ENG': {'code': u'ENG',
#   'country': u'England',
#   'group': 'D',
#   'matches': [{'away_team': {u'code': u'ITA',
#      u'country': u'Italy',
#      u'goals': 2},
#     'code': u'ENG',
#     'datetime': u'2014-06-14T19:00:00.000-03:00',
#     'home_team': {u'code': u'ENG', u'country': u'England', u'goals': 1},
#     'lat': -3.083142,
#     'lng': -60.028108,
#     'location': u'Arena Amazonia',
#     'match_number': 8,
#     'number': 1,
#     'weather': {u'apparentTemperature': 79.76,
#      u'cloudCover': 0.01,
#      u'dewPoint': 68.11,
#      u'humidity': 0.68,
#      u'icon': u'clear-night',
#      u'ozone': 251.99,
#      u'precipIntensity': 0.0003,
#      u'precipProbability': 0.8,
#      u'precipType': u'rain',
#      u'pressure': 1010.8,
#      u'summary': u'Clear',
#      u'temperature': 79.76,
#      u'time': 1402786800,
#      u'windBearing': 119,
#      u'windSpeed': 3}},
#    {'away_team': {u'code': u'ENG', u'country': u'England', u'goals': 1},
#     'code': u'ENG',
#     'datetime': u'2014-06-19T16:00:00.000-03:00',
#     'home_team': {u'code': u'URU', u'country': u'Uruguay', u'goals': 2},
#     'lat': -23.545333,
#     'lng': -46.473702,
#     'location': u'Arena de Sao Paulo',
#     'match_number': 23,
#     'number': 2,
#     'weather': {u'apparentTemperature': 61.03,
#      u'cloudCover': 0.91,
#      u'dewPoint': 56.8,
#      u'humidity': 0.86,
#      u'icon': u'rain',
#      u'ozone': 286.33,
#      u'precipIntensity': 0.0081,
#      u'precipProbability': 0.42,
#      u'precipType': u'rain',
#      u'pressure': 1024.34,
#      u'summary': u'Drizzle',
#      u'temperature': 61.03,
#      u'time': 1403204400,
#      u'visibility': 5.84,
#      u'windBearing': 166,
#      u'windSpeed': 9.02}},
#    {'away_team': {u'code': u'ENG', u'country': u'England', u'goals': 0},
#     'code': u'ENG',
#     'datetime': u'2014-06-24T13:00:00.000-03:00',
#     'home_team': {u'code': u'CRC', u'country': u'Costa Rica', u'goals': 0},
#     'lat': -19.865867,
#     'lng': -43.971132,
#     'location': u'Estadio Mineirao',
#     'match_number': 40,
#     'number': 3,
#     'weather': {u'apparentTemperature': 76.16,
#      u'cloudCover': 0.41,
#      u'dewPoint': 54.04,
#      u'humidity': 0.46,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 264.8,
#      u'precipIntensity': 0.0001,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1019.44,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 76.16,
#      u'time': 1403625600,
#      u'visibility': 6.21,
#      u'windBearing': 70,
#      u'windSpeed': 6.17}}]},
#  u'ESP': {'code': u'ESP',
#   'country': u'Spain',
#   'group': 'B',
#   'matches': [{'away_team': {u'code': u'NED',
#      u'country': u'Netherlands',
#      u'goals': 5},
#     'code': u'ESP',
#     'datetime': u'2014-06-13T16:00:00.000-03:00',
#     'home_team': {u'code': u'ESP', u'country': u'Spain', u'goals': 1},
#     'lat': -12.97883,
#     'lng': -38.504371,
#     'location': u'Arena Fonte Nova',
#     'match_number': 3,
#     'number': 1,
#     'weather': {u'apparentTemperature': 79,
#      u'dewPoint': 71.91,
#      u'humidity': 0.79,
#      u'icon': u'clear-day',
#      u'precipType': u'rain',
#      u'summary': u'Clear',
#      u'temperature': 79,
#      u'time': 1402686000,
#      u'visibility': 6.2,
#      u'windBearing': 150,
#      u'windSpeed': 8}},
#    {'away_team': {u'code': u'CHI', u'country': u'Chile', u'goals': 2},
#     'code': u'ESP',
#     'datetime': u'2014-06-18T16:00:00.000-03:00',
#     'home_team': {u'code': u'ESP', u'country': u'Spain', u'goals': 0},
#     'lat': -22.912109,
#     'lng': -43.230156,
#     'location': u'Estadio do Maracana',
#     'match_number': 19,
#     'number': 2,
#     'weather': {u'apparentTemperature': 73.6,
#      u'cloudCover': 0.25,
#      u'dewPoint': 67.93,
#      u'humidity': 0.83,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 263.01,
#      u'precipIntensity': 0.0006,
#      u'precipProbability': 0.88,
#      u'precipType': u'rain',
#      u'pressure': 1019.46,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 73.6,
#      u'time': 1403118000,
#      u'visibility': 3.53,
#      u'windBearing': 202,
#      u'windSpeed': 9.2}},
#    {'away_team': {u'code': u'ESP', u'country': u'Spain', u'goals': 3},
#     'code': u'ESP',
#     'datetime': u'2014-06-23T13:00:00.000-03:00',
#     'home_team': {u'code': u'AUS', u'country': u'Australia', u'goals': 0},
#     'lat': -25.4482121,
#     'lng': -49.276987,
#     'location': u'Arena da Baixada',
#     'match_number': 35,
#     'number': 3,
#     'weather': {u'apparentTemperature': 68.42,
#      u'cloudCover': 0.84,
#      u'dewPoint': 60.71,
#      u'humidity': 0.76,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 275.51,
#      u'precipIntensity': 0.0003,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1019.55,
#      u'summary': u'Mostly Cloudy',
#      u'temperature': 68.42,
#      u'time': 1403539200,
#      u'windBearing': 346,
#      u'windSpeed': 3.5}}]},
#  u'FRA': {'code': u'FRA',
#   'country': u'France',
#   'group': 'E',
#   'matches': [{'away_team': {u'code': u'HON',
#      u'country': u'Honduras',
#      u'goals': 0},
#     'code': u'FRA',
#     'datetime': u'2014-06-15T16:00:00.000-03:00',
#     'home_team': {u'code': u'FRA', u'country': u'France', u'goals': 3},
#     'lat': -30.065384,
#     'lng': -51.235822,
#     'location': u'Estadio Beira-Rio',
#     'match_number': 10,
#     'number': 1,
#     'weather': {u'apparentTemperature': 66.1,
#      u'cloudCover': 0.13,
#      u'dewPoint': 60.19,
#      u'humidity': 0.81,
#      u'icon': u'clear-day',
#      u'ozone': 265.66,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 0.83,
#      u'precipType': u'rain',
#      u'pressure': 1022.29,
#      u'summary': u'Clear',
#      u'temperature': 66.1,
#      u'time': 1402858800,
#      u'visibility': 6.1,
#      u'windBearing': 97,
#      u'windSpeed': 12}},
#    {'away_team': {u'code': u'FRA', u'country': u'France', u'goals': 5},
#     'code': u'FRA',
#     'datetime': u'2014-06-20T16:00:00.000-03:00',
#     'home_team': {u'code': u'SUI', u'country': u'Switzerland', u'goals': 2},
#     'lat': -12.97883,
#     'lng': -38.504371,
#     'location': u'Arena Fonte Nova',
#     'match_number': 25,
#     'number': 2,
#     'weather': {u'apparentTemperature': 83.45,
#      u'cloudCover': 0.94,
#      u'dewPoint': 70.53,
#      u'humidity': 0.73,
#      u'icon': u'rain',
#      u'ozone': 254.07,
#      u'precipIntensity': 0.0092,
#      u'precipProbability': 0.42,
#      u'precipType': u'rain',
#      u'pressure': 1016.83,
#      u'summary': u'Drizzle',
#      u'temperature': 80.09,
#      u'time': 1403290800,
#      u'visibility': 6.2,
#      u'windBearing': 134,
#      u'windSpeed': 7.72}},
#    {'away_team': {u'code': u'FRA', u'country': u'France', u'goals': 0},
#     'code': u'FRA',
#     'datetime': u'2014-06-25T17:00:00.000-03:00',
#     'home_team': {u'code': u'ECU', u'country': u'Ecuador', u'goals': 0},
#     'lat': -22.912109,
#     'lng': -43.230156,
#     'location': u'Estadio do Maracana',
#     'match_number': 42,
#     'number': 3,
#     'weather': {u'apparentTemperature': 76.07,
#      u'cloudCover': 0.17,
#      u'dewPoint': 65.35,
#      u'humidity': 0.69,
#      u'icon': u'clear-day',
#      u'ozone': 262.48,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1015.99,
#      u'summary': u'Clear',
#      u'temperature': 76.07,
#      u'time': 1403726400,
#      u'visibility': 4.35,
#      u'windBearing': 166,
#      u'windSpeed': 7.81}}]},
#  u'GER': {'code': u'GER',
#   'country': u'Germany',
#   'group': 'G',
#   'matches': [{'away_team': {u'code': u'POR',
#      u'country': u'Portugal',
#      u'goals': 0},
#     'code': u'GER',
#     'datetime': u'2014-06-16T13:00:00.000-03:00',
#     'home_team': {u'code': u'GER', u'country': u'Germany', u'goals': 4},
#     'lat': -12.97883,
#     'lng': -38.504371,
#     'location': u'Arena Fonte Nova',
#     'match_number': 13,
#     'number': 1,
#     'weather': {u'apparentTemperature': 79.86,
#      u'cloudCover': 0.17,
#      u'dewPoint': 70.52,
#      u'humidity': 0.73,
#      u'icon': u'clear-day',
#      u'ozone': 255.43,
#      u'precipIntensity': 0.0127,
#      u'precipProbability': 0.24,
#      u'precipType': u'rain',
#      u'pressure': 1017.5,
#      u'summary': u'Clear',
#      u'temperature': 79.86,
#      u'time': 1402934400,
#      u'visibility': 6.2,
#      u'windBearing': 130,
#      u'windSpeed': 11.61}},
#    {'away_team': {u'code': u'GHA', u'country': u'Ghana', u'goals': 2},
#     'code': u'GER',
#     'datetime': u'2014-06-21T16:00:00.000-03:00',
#     'home_team': {u'code': u'GER', u'country': u'Germany', u'goals': 2},
#     'lat': -3.807231,
#     'lng': -38.522434,
#     'location': u'Estadio Castelao',
#     'match_number': 29,
#     'number': 2,
#     'weather': {u'apparentTemperature': 86.49,
#      u'cloudCover': 0.24,
#      u'dewPoint': 64.4,
#      u'humidity': 0.5,
#      u'icon': u'clear-day',
#      u'ozone': 255.14,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1011.81,
#      u'summary': u'Clear',
#      u'temperature': 84.97,
#      u'time': 1403377200,
#      u'windBearing': 96,
#      u'windSpeed': 10.58}},
#    {'away_team': {u'code': u'GER', u'country': u'Germany', u'goals': 1},
#     'code': u'GER',
#     'datetime': u'2014-06-26T13:00:00.000-03:00',
#     'home_team': {u'code': u'USA', u'country': u'USA', u'goals': 0},
#     'lat': -8.04065,
#     'lng': -35.008205,
#     'location': u'Arena Pernambuco',
#     'match_number': 45,
#     'number': 3,
#     'weather': {u'apparentTemperature': 79.15,
#      u'cloudCover': 0.76,
#      u'dewPoint': 74.67,
#      u'humidity': 0.86,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 249.56,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1014.18,
#      u'summary': u'Humid and Mostly Cloudy',
#      u'temperature': 79.15,
#      u'time': 1403798400,
#      u'windBearing': 102,
#      u'windSpeed': 7.37}}]},
#  u'GHA': {'code': u'GHA',
#   'country': u'Ghana',
#   'group': 'G',
#   'matches': [{'away_team': {u'code': u'USA', u'country': u'USA', u'goals': 2},
#     'code': u'GHA',
#     'datetime': u'2014-06-16T19:00:00.000-03:00',
#     'home_team': {u'code': u'GHA', u'country': u'Ghana', u'goals': 1},
#     'lat': -5.826827,
#     'lng': -35.21243,
#     'location': u'Estadio das Dunas',
#     'match_number': 14,
#     'number': 1,
#     'weather': {u'apparentTemperature': 79.27,
#      u'cloudCover': 0.22,
#      u'dewPoint': 71.3,
#      u'humidity': 0.77,
#      u'icon': u'rain',
#      u'ozone': 252.42,
#      u'precipIntensity': 0.0101,
#      u'precipProbability': 0.49,
#      u'precipType': u'rain',
#      u'pressure': 1014.88,
#      u'summary': u'Drizzle',
#      u'temperature': 79.27,
#      u'time': 1402956000,
#      u'visibility': 6.2,
#      u'windBearing': 144,
#      u'windSpeed': 14.24}},
#    {'away_team': {u'code': u'GHA', u'country': u'Ghana', u'goals': 2},
#     'code': u'GHA',
#     'datetime': u'2014-06-21T16:00:00.000-03:00',
#     'home_team': {u'code': u'GER', u'country': u'Germany', u'goals': 2},
#     'lat': -3.807231,
#     'lng': -38.522434,
#     'location': u'Estadio Castelao',
#     'match_number': 29,
#     'number': 2,
#     'weather': {u'apparentTemperature': 86.49,
#      u'cloudCover': 0.24,
#      u'dewPoint': 64.4,
#      u'humidity': 0.5,
#      u'icon': u'clear-day',
#      u'ozone': 255.14,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1011.81,
#      u'summary': u'Clear',
#      u'temperature': 84.97,
#      u'time': 1403377200,
#      u'windBearing': 96,
#      u'windSpeed': 10.58}},
#    {'away_team': {u'code': u'GHA', u'country': u'Ghana', u'goals': 1},
#     'code': u'GHA',
#     'datetime': u'2014-06-26T13:00:00.000-03:00',
#     'home_team': {u'code': u'POR', u'country': u'Portugal', u'goals': 2},
#     'lat': -15.783519,
#     'lng': -47.899211,
#     'location': u'Estadio Nacional',
#     'match_number': 46,
#     'number': 3,
#     'weather': {u'apparentTemperature': 77.01,
#      u'cloudCover': 0.49,
#      u'dewPoint': 52.37,
#      u'humidity': 0.42,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 252.3,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1015.16,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 77.01,
#      u'time': 1403798400,
#      u'windBearing': 71,
#      u'windSpeed': 6.56}}]},
#  u'GRE': {'code': u'GRE',
#   'country': u'Greece',
#   'group': 'C',
#   'matches': [{'away_team': {u'code': u'GRE',
#      u'country': u'Greece',
#      u'goals': 0},
#     'code': u'GRE',
#     'datetime': u'2014-06-14T13:00:00.000-03:00',
#     'home_team': {u'code': u'COL', u'country': u'Colombia', u'goals': 3},
#     'lat': -19.865867,
#     'lng': -43.971132,
#     'location': u'Estadio Mineirao',
#     'match_number': 5,
#     'number': 1,
#     'weather': {u'apparentTemperature': 72.26,
#      u'cloudCover': 0.7,
#      u'dewPoint': 55.19,
#      u'humidity': 0.55,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 255.8,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 0.8,
#      u'precipType': u'rain',
#      u'pressure': 1020.92,
#      u'summary': u'Mostly Cloudy',
#      u'temperature': 72.26,
#      u'time': 1402761600,
#      u'visibility': 6.2,
#      u'windBearing': 84,
#      u'windSpeed': 7.13}},
#    {'away_team': {u'code': u'GRE', u'country': u'Greece', u'goals': 0},
#     'code': u'GRE',
#     'datetime': u'2014-06-19T19:00:00.000-03:00',
#     'home_team': {u'code': u'JPN', u'country': u'Japan', u'goals': 0},
#     'lat': -5.826827,
#     'lng': -35.21243,
#     'location': u'Estadio das Dunas',
#     'match_number': 22,
#     'number': 2,
#     'weather': {u'apparentTemperature': 78.78,
#      u'cloudCover': 0.61,
#      u'dewPoint': 73.38,
#      u'humidity': 0.84,
#      u'icon': u'rain',
#      u'ozone': 256.26,
#      u'precipIntensity': 0.0086,
#      u'precipProbability': 0.69,
#      u'precipType': u'rain',
#      u'pressure': 1015.07,
#      u'summary': u'Drizzle',
#      u'temperature': 78.78,
#      u'time': 1403215200,
#      u'visibility': 6.2,
#      u'windBearing': 143,
#      u'windSpeed': 16.3}},
#    {'away_team': {u'code': u'CIV', u'country': u'Ivory Coast', u'goals': 1},
#     'code': u'GRE',
#     'datetime': u'2014-06-24T17:00:00.000-03:00',
#     'home_team': {u'code': u'GRE', u'country': u'Greece', u'goals': 2},
#     'lat': -3.807231,
#     'lng': -38.522434,
#     'location': u'Estadio Castelao',
#     'match_number': 38,
#     'number': 3,
#     'weather': {u'apparentTemperature': 88.93,
#      u'cloudCover': 0.61,
#      u'dewPoint': 71.26,
#      u'humidity': 0.66,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 252.84,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1012.02,
#      u'summary': u'Mostly Cloudy',
#      u'temperature': 83.84,
#      u'time': 1403640000,
#      u'windBearing': 65,
#      u'windSpeed': 16.09}}]},
#  u'HON': {'code': u'HON',
#   'country': u'Honduras',
#   'group': 'E',
#   'matches': [{'away_team': {u'code': u'HON',
#      u'country': u'Honduras',
#      u'goals': 0},
#     'code': u'HON',
#     'datetime': u'2014-06-15T16:00:00.000-03:00',
#     'home_team': {u'code': u'FRA', u'country': u'France', u'goals': 3},
#     'lat': -30.065384,
#     'lng': -51.235822,
#     'location': u'Estadio Beira-Rio',
#     'match_number': 10,
#     'number': 1,
#     'weather': {u'apparentTemperature': 66.1,
#      u'cloudCover': 0.13,
#      u'dewPoint': 60.19,
#      u'humidity': 0.81,
#      u'icon': u'clear-day',
#      u'ozone': 265.66,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 0.83,
#      u'precipType': u'rain',
#      u'pressure': 1022.29,
#      u'summary': u'Clear',
#      u'temperature': 66.1,
#      u'time': 1402858800,
#      u'visibility': 6.1,
#      u'windBearing': 97,
#      u'windSpeed': 12}},
#    {'away_team': {u'code': u'ECU', u'country': u'Ecuador', u'goals': 2},
#     'code': u'HON',
#     'datetime': u'2014-06-20T19:00:00.000-03:00',
#     'home_team': {u'code': u'HON', u'country': u'Honduras', u'goals': 1},
#     'lat': -25.4482121,
#     'lng': -49.276987,
#     'location': u'Arena da Baixada',
#     'match_number': 26,
#     'number': 2,
#     'weather': {u'apparentTemperature': 54.76,
#      u'cloudCover': 1,
#      u'dewPoint': 51.02,
#      u'humidity': 0.87,
#      u'icon': u'cloudy',
#      u'ozone': 291.34,
#      u'precipIntensity': 0.0003,
#      u'precipProbability': 0.95,
#      u'precipType': u'rain',
#      u'pressure': 1022.15,
#      u'summary': u'Overcast',
#      u'temperature': 54.76,
#      u'time': 1403301600,
#      u'visibility': 6.2,
#      u'windBearing': 108,
#      u'windSpeed': 2.72}},
#    {'away_team': {u'code': u'SUI', u'country': u'Switzerland', u'goals': 3},
#     'code': u'HON',
#     'datetime': u'2014-06-25T17:00:00.000-03:00',
#     'home_team': {u'code': u'HON', u'country': u'Honduras', u'goals': 0},
#     'lat': -3.083142,
#     'lng': -60.028108,
#     'location': u'Arena Amazonia',
#     'match_number': 41,
#     'number': 3,
#     'weather': {u'apparentTemperature': 103.39,
#      u'cloudCover': 0.25,
#      u'dewPoint': 82.28,
#      u'humidity': 0.91,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 252.9,
#      u'precipIntensity': 0.0077,
#      u'precipProbability': 0.26,
#      u'precipType': u'rain',
#      u'pressure': 1010.19,
#      u'summary': u'Humid and Partly Cloudy',
#      u'temperature': 85.36,
#      u'time': 1403730000,
# ...
#     'lng': -51.235822,
#     'location': u'Estadio Beira-Rio',
#     'match_number': 20,
#     'number': 2,
#     'weather': {u'apparentTemperature': 58.43,
#      u'cloudCover': 0.02,
#      u'dewPoint': 45.08,
#      u'humidity': 0.61,
#      u'icon': u'clear-day',
#      u'ozone': 312.67,
#      u'precipIntensity': 0.0005,
#      u'precipProbability': 0.88,
#      u'precipType': u'rain',
#      u'pressure': 1027.65,
#      u'summary': u'Clear',
#      u'temperature': 58.43,
#      u'time': 1403107200,
#      u'visibility': 6.2,
#      u'windBearing': 217,
#      u'windSpeed': 7.18}},
#    {'away_team': {u'code': u'CHI', u'country': u'Chile', u'goals': 0},
#     'code': u'NED',
#     'datetime': u'2014-06-23T13:00:00.000-03:00',
#     'home_team': {u'code': u'NED', u'country': u'Netherlands', u'goals': 2},
#     'lat': -23.545333,
#     'lng': -46.473702,
#     'location': u'Arena de Sao Paulo',
#     'match_number': 36,
#     'number': 3,
#     'weather': {u'apparentTemperature': 73.86,
#      u'cloudCover': 0.82,
#      u'dewPoint': 63.24,
#      u'humidity': 0.69,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 265.14,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1020.67,
#      u'summary': u'Mostly Cloudy',
#      u'temperature': 73.86,
#      u'time': 1403539200,
#      u'windBearing': 337,
#      u'windSpeed': 3.68}}]},
#  u'NGA': {'code': u'NGA',
#   'country': u'Nigeria',
#   'group': 'F',
#   'matches': [{'away_team': {u'code': u'NGA',
#      u'country': u'Nigeria',
#      u'goals': 0},
#     'code': u'NGA',
#     'datetime': u'2014-06-16T16:00:00.000-03:00',
#     'home_team': {u'code': u'IRN', u'country': u'Iran', u'goals': 0},
#     'lat': -25.4482121,
#     'lng': -49.276987,
#     'location': u'Arena da Baixada',
#     'match_number': 12,
#     'number': 1,
#     'weather': {u'apparentTemperature': 70.21,
#      u'cloudCover': 0.51,
#      u'dewPoint': 62.3,
#      u'humidity': 0.76,
#      u'icon': u'rain',
#      u'ozone': 253.94,
#      u'precipIntensity': 0.0032,
#      u'precipProbability': 0.7,
#      u'precipType': u'rain',
#      u'pressure': 1019.68,
#      u'summary': u'Drizzle',
#      u'temperature': 70.21,
#      u'time': 1402945200,
#      u'visibility': 6.2,
#      u'windBearing': 259,
#      u'windSpeed': 5.21}},
#    {'away_team': {u'code': u'BIH',
#      u'country': u'Bosnia and Herzegovina',
#      u'goals': 0},
#     'code': u'NGA',
#     'datetime': u'2014-06-21T19:00:00.000-03:00',
#     'home_team': {u'code': u'NGA', u'country': u'Nigeria', u'goals': 1},
#     'lat': -15.604017,
#     'lng': -56.121632,
#     'location': u'Arena Pantanal',
#     'match_number': 28,
#     'number': 2,
#     'weather': {u'apparentTemperature': 76.62,
#      u'cloudCover': 0.32,
#      u'dewPoint': 68.24,
#      u'humidity': 0.75,
#      u'icon': u'partly-cloudy-night',
#      u'ozone': 254.45,
#      u'precipIntensity': 0.0001,
#      u'precipProbability': 0.98,
#      u'precipType': u'rain',
#      u'pressure': 1013.16,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 76.62,
#      u'time': 1403391600,
#      u'windBearing': 144,
#      u'windSpeed': 0.95}},
#    {'away_team': {u'code': u'ARG', u'country': u'Argentina', u'goals': 3},
#     'code': u'NGA',
#     'datetime': u'2014-06-25T13:00:00.000-03:00',
#     'home_team': {u'code': u'NGA', u'country': u'Nigeria', u'goals': 2},
#     'lat': -30.065384,
#     'lng': -51.235822,
#     'location': u'Estadio Beira-Rio',
#     'match_number': 43,
#     'number': 3,
#     'weather': {u'apparentTemperature': 69.82,
#      u'cloudCover': 0.75,
#      u'dewPoint': 64.27,
#      u'humidity': 0.83,
#      u'icon': u'rain',
#      u'ozone': 274.12,
#      u'precipIntensity': 0.018,
#      u'precipProbability': 0.66,
#      u'precipType': u'rain',
#      u'pressure': 1011.94,
#      u'summary': u'Light Rain',
#      u'temperature': 69.82,
#      u'time': 1403712000,
#      u'visibility': 3.82,
#      u'windBearing': 280,
#      u'windSpeed': 1.35}}]},
#  u'POR': {'code': u'POR',
#   'country': u'Portugal',
#   'group': 'G',
#   'matches': [{'away_team': {u'code': u'POR',
#      u'country': u'Portugal',
#      u'goals': 0},
#     'code': u'POR',
#     'datetime': u'2014-06-16T13:00:00.000-03:00',
#     'home_team': {u'code': u'GER', u'country': u'Germany', u'goals': 4},
#     'lat': -12.97883,
#     'lng': -38.504371,
#     'location': u'Arena Fonte Nova',
#     'match_number': 13,
#     'number': 1,
#     'weather': {u'apparentTemperature': 79.86,
#      u'cloudCover': 0.17,
#      u'dewPoint': 70.52,
#      u'humidity': 0.73,
#      u'icon': u'clear-day',
#      u'ozone': 255.43,
#      u'precipIntensity': 0.0127,
#      u'precipProbability': 0.24,
#      u'precipType': u'rain',
#      u'pressure': 1017.5,
#      u'summary': u'Clear',
#      u'temperature': 79.86,
#      u'time': 1402934400,
#      u'visibility': 6.2,
#      u'windBearing': 130,
#      u'windSpeed': 11.61}},
#    {'away_team': {u'code': u'POR', u'country': u'Portugal', u'goals': 2},
#     'code': u'POR',
#     'datetime': u'2014-06-22T19:00:00.000-03:00',
#     'home_team': {u'code': u'USA', u'country': u'USA', u'goals': 2},
#     'lat': -3.083142,
#     'lng': -60.028108,
#     'location': u'Arena Amazonia',
#     'match_number': 30,
#     'number': 2,
#     'weather': {u'apparentTemperature': 86.94,
#      u'cloudCover': 0.96,
#      u'dewPoint': 74.86,
#      u'humidity': 0.81,
#      u'icon': u'rain',
#      u'ozone': 255.76,
#      u'precipIntensity': 0.0055,
#      u'precipProbability': 0.63,
#      u'precipType': u'rain',
#      u'pressure': 1011.72,
#      u'summary': u'Drizzle',
#      u'temperature': 81.1,
#      u'time': 1403478000,
#      u'windBearing': 85,
#      u'windSpeed': 1.58}},
#    {'away_team': {u'code': u'GHA', u'country': u'Ghana', u'goals': 1},
#     'code': u'POR',
#     'datetime': u'2014-06-26T13:00:00.000-03:00',
#     'home_team': {u'code': u'POR', u'country': u'Portugal', u'goals': 2},
#     'lat': -15.783519,
#     'lng': -47.899211,
#     'location': u'Estadio Nacional',
#     'match_number': 46,
#     'number': 3,
#     'weather': {u'apparentTemperature': 77.01,
#      u'cloudCover': 0.49,
#      u'dewPoint': 52.37,
#      u'humidity': 0.42,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 252.3,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1015.16,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 77.01,
#      u'time': 1403798400,
#      u'windBearing': 71,
#      u'windSpeed': 6.56}}]},
#  u'RUS': {'code': u'RUS',
#   'country': u'Russia',
#   'group': 'H',
#   'matches': [{'away_team': {u'code': u'KOR',
#      u'country': u'Korea Republic',
#      u'goals': 1},
#     'code': u'RUS',
#     'datetime': u'2014-06-17T19:00:00.000-03:00',
#     'home_team': {u'code': u'RUS', u'country': u'Russia', u'goals': 1},
#     'lat': -15.604017,
#     'lng': -56.121632,
#     'location': u'Arena Pantanal',
#     'match_number': 16,
#     'number': 1,
#     'weather': {u'apparentTemperature': 74.51,
#      u'cloudCover': 0.96,
#      u'dewPoint': 65.67,
#      u'humidity': 0.74,
#      u'icon': u'cloudy',
#      u'ozone': 260.83,
#      u'precipIntensity': 0.0001,
#      u'precipProbability': 0.88,
#      u'precipType': u'rain',
#      u'pressure': 1015.31,
#      u'summary': u'Overcast',
#      u'temperature': 74.51,
#      u'time': 1403046000,
#      u'visibility': 6.2,
#      u'windBearing': 168,
#      u'windSpeed': 3.05}},
#    {'away_team': {u'code': u'RUS', u'country': u'Russia', u'goals': 0},
#     'code': u'RUS',
#     'datetime': u'2014-06-22T13:00:00.000-03:00',
#     'home_team': {u'code': u'BEL', u'country': u'Belgium', u'goals': 1},
#     'lat': -22.912109,
#     'lng': -43.230156,
#     'location': u'Estadio do Maracana',
#     'match_number': 31,
#     'number': 2,
#     'weather': {u'apparentTemperature': 76.48,
#      u'cloudCover': 0.05,
#      u'dewPoint': 67.53,
#      u'humidity': 0.74,
#      u'icon': u'rain',
#      u'ozone': 270.16,
#      u'precipIntensity': 0.0031,
#      u'precipProbability': 0.81,
#      u'precipType': u'rain',
#      u'pressure': 1023.39,
#      u'summary': u'Drizzle',
#      u'temperature': 76.48,
#      u'time': 1403452800,
#      u'windBearing': 84,
#      u'windSpeed': 10.35}},
#    {'away_team': {u'code': u'RUS', u'country': u'Russia', u'goals': 1},
#     'code': u'RUS',
#     'datetime': u'2014-06-26T17:00:00.000-03:00',
#     'home_team': {u'code': u'ALG', u'country': u'Algeria', u'goals': 1},
#     'lat': -25.4482121,
#     'lng': -49.276987,
#     'location': u'Arena da Baixada',
#     'match_number': 48,
#     'number': 3,
#     'weather': {u'apparentTemperature': 69.96,
#      u'cloudCover': 0.34,
#      u'dewPoint': 57.35,
#      u'humidity': 0.64,
#      u'icon': u'rain',
#      u'ozone': 272.45,
#      u'precipIntensity': 0.0027,
#      u'precipProbability': 0.74,
#      u'precipType': u'rain',
#      u'pressure': 1013.16,
#      u'summary': u'Drizzle',
#      u'temperature': 69.96,
#      u'time': 1403812800,
#      u'visibility': 6.21,
#      u'windBearing': 17,
#      u'windSpeed': 3.36}}]},
#  u'SUI': {'code': u'SUI',
#   'country': u'Switzerland',
#   'group': 'E',
#   'matches': [{'away_team': {u'code': u'ECU',
#      u'country': u'Ecuador',
#      u'goals': 1},
#     'code': u'SUI',
#     'datetime': u'2014-06-15T13:00:00.000-03:00',
#     'home_team': {u'code': u'SUI', u'country': u'Switzerland', u'goals': 2},
#     'lat': -15.783519,
#     'lng': -47.899211,
#     'location': u'Estadio Nacional',
#     'match_number': 9,
#     'number': 1,
#     'weather': {u'apparentTemperature': 73.4,
#      u'cloudCover': 0.97,
#      u'dewPoint': 59.17,
#      u'humidity': 0.61,
#      u'icon': u'cloudy',
#      u'ozone': 254.22,
#      u'precipIntensity': 0.0009,
#      u'precipProbability': 0.8,
#      u'precipType': u'rain',
#      u'pressure': 1017.56,
#      u'summary': u'Overcast',
#      u'temperature': 73.4,
#      u'time': 1402848000,
#      u'visibility': 6.2,
#      u'windBearing': 92,
#      u'windSpeed': 9.32}},
#    {'away_team': {u'code': u'FRA', u'country': u'France', u'goals': 5},
#     'code': u'SUI',
#     'datetime': u'2014-06-20T16:00:00.000-03:00',
#     'home_team': {u'code': u'SUI', u'country': u'Switzerland', u'goals': 2},
#     'lat': -12.97883,
#     'lng': -38.504371,
#     'location': u'Arena Fonte Nova',
#     'match_number': 25,
#     'number': 2,
#     'weather': {u'apparentTemperature': 83.45,
#      u'cloudCover': 0.94,
#      u'dewPoint': 70.53,
#      u'humidity': 0.73,
#      u'icon': u'rain',
#      u'ozone': 254.07,
#      u'precipIntensity': 0.0092,
#      u'precipProbability': 0.42,
#      u'precipType': u'rain',
#      u'pressure': 1016.83,
#      u'summary': u'Drizzle',
#      u'temperature': 80.09,
#      u'time': 1403290800,
#      u'visibility': 6.2,
#      u'windBearing': 134,
#      u'windSpeed': 7.72}},
#    {'away_team': {u'code': u'SUI', u'country': u'Switzerland', u'goals': 3},
#     'code': u'SUI',
#     'datetime': u'2014-06-25T17:00:00.000-03:00',
#     'home_team': {u'code': u'HON', u'country': u'Honduras', u'goals': 0},
#     'lat': -3.083142,
#     'lng': -60.028108,
#     'location': u'Arena Amazonia',
#     'match_number': 41,
#     'number': 3,
#     'weather': {u'apparentTemperature': 103.39,
#      u'cloudCover': 0.25,
#      u'dewPoint': 82.28,
#      u'humidity': 0.91,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 252.9,
#      u'precipIntensity': 0.0077,
#      u'precipProbability': 0.26,
#      u'precipType': u'rain',
#      u'pressure': 1010.19,
#      u'summary': u'Humid and Partly Cloudy',
#      u'temperature': 85.36,
#      u'time': 1403730000,
#      u'visibility': 6.21,
#      u'windBearing': 7,
#      u'windSpeed': 1.88}}]},
#  u'URU': {'code': u'URU',
#   'country': u'Uruguay',
#   'group': 'D',
#   'matches': [{'away_team': {u'code': u'CRC',
#      u'country': u'Costa Rica',
#      u'goals': 3},
#     'code': u'URU',
#     'datetime': u'2014-06-14T16:00:00.000-03:00',
#     'home_team': {u'code': u'URU', u'country': u'Uruguay', u'goals': 1},
#     'lat': -3.807231,
#     'lng': -38.522434,
#     'location': u'Estadio Castelao',
#     'match_number': 7,
#     'number': 1,
#     'weather': {u'apparentTemperature': 87.58,
#      u'cloudCover': 0.22,
#      u'dewPoint': 67.53,
#      u'humidity': 0.57,
#      u'icon': u'rain',
#      u'ozone': 247.92,
#      u'precipIntensity': 0.0046,
#      u'precipProbability': 0.61,
#      u'precipType': u'rain',
#      u'pressure': 1011.52,
#      u'summary': u'Drizzle',
#      u'temperature': 84.56,
#      u'time': 1402772400,
#      u'visibility': 6.2,
#      u'windBearing': 94,
#      u'windSpeed': 10.27}},
#    {'away_team': {u'code': u'ENG', u'country': u'England', u'goals': 1},
#     'code': u'URU',
#     'datetime': u'2014-06-19T16:00:00.000-03:00',
#     'home_team': {u'code': u'URU', u'country': u'Uruguay', u'goals': 2},
#     'lat': -23.545333,
#     'lng': -46.473702,
#     'location': u'Arena de Sao Paulo',
#     'match_number': 23,
#     'number': 2,
#     'weather': {u'apparentTemperature': 61.03,
#      u'cloudCover': 0.91,
#      u'dewPoint': 56.8,
#      u'humidity': 0.86,
#      u'icon': u'rain',
#      u'ozone': 286.33,
#      u'precipIntensity': 0.0081,
#      u'precipProbability': 0.42,
#      u'precipType': u'rain',
#      u'pressure': 1024.34,
#      u'summary': u'Drizzle',
#      u'temperature': 61.03,
#      u'time': 1403204400,
#      u'visibility': 5.84,
#      u'windBearing': 166,
#      u'windSpeed': 9.02}},
#    {'away_team': {u'code': u'URU', u'country': u'Uruguay', u'goals': 1},
#     'code': u'URU',
#     'datetime': u'2014-06-24T13:00:00.000-03:00',
#     'home_team': {u'code': u'ITA', u'country': u'Italy', u'goals': 0},
#     'lat': -5.826827,
#     'lng': -35.21243,
#     'location': u'Estadio das Dunas',
#     'match_number': 39,
#     'number': 3,
#     'weather': {u'apparentTemperature': 88.05,
#      u'cloudCover': 0.74,
#      u'dewPoint': 74.34,
#      u'humidity': 0.78,
#      u'icon': u'rain',
#      u'ozone': 251.98,
#      u'precipIntensity': 0.0144,
#      u'precipProbability': 0.25,
#      u'precipType': u'rain',
#      u'pressure': 1014.64,
#      u'summary': u'Drizzle',
#      u'temperature': 81.89,
#      u'time': 1403625600,
#      u'visibility': 6.21,
#      u'windBearing': 133,
#      u'windSpeed': 17.81}}]},
#  u'USA': {'code': u'USA',
#   'country': u'USA',
#   'group': 'G',
#   'matches': [{'away_team': {u'code': u'USA', u'country': u'USA', u'goals': 2},
#     'code': u'USA',
#     'datetime': u'2014-06-16T19:00:00.000-03:00',
#     'home_team': {u'code': u'GHA', u'country': u'Ghana', u'goals': 1},
#     'lat': -5.826827,
#     'lng': -35.21243,
#     'location': u'Estadio das Dunas',
#     'match_number': 14,
#     'number': 1,
#     'weather': {u'apparentTemperature': 79.27,
#      u'cloudCover': 0.22,
#      u'dewPoint': 71.3,
#      u'humidity': 0.77,
#      u'icon': u'rain',
#      u'ozone': 252.42,
#      u'precipIntensity': 0.0101,
#      u'precipProbability': 0.49,
#      u'precipType': u'rain',
#      u'pressure': 1014.88,
#      u'summary': u'Drizzle',
#      u'temperature': 79.27,
#      u'time': 1402956000,
#      u'visibility': 6.2,
#      u'windBearing': 144,
#      u'windSpeed': 14.24}},
#    {'away_team': {u'code': u'POR', u'country': u'Portugal', u'goals': 2},
#     'code': u'USA',
#     'datetime': u'2014-06-22T19:00:00.000-03:00',
#     'home_team': {u'code': u'USA', u'country': u'USA', u'goals': 2},
#     'lat': -3.083142,
#     'lng': -60.028108,
#     'location': u'Arena Amazonia',
#     'match_number': 30,
#     'number': 2,
#     'weather': {u'apparentTemperature': 86.94,
#      u'cloudCover': 0.96,
#      u'dewPoint': 74.86,
#      u'humidity': 0.81,
#      u'icon': u'rain',
#      u'ozone': 255.76,
#      u'precipIntensity': 0.0055,
#      u'precipProbability': 0.63,
#      u'precipType': u'rain',
#      u'pressure': 1011.72,
#      u'summary': u'Drizzle',
#      u'temperature': 81.1,
#      u'time': 1403478000,
#      u'windBearing': 85,
#      u'windSpeed': 1.58}},
#    {'away_team': {u'code': u'GER', u'country': u'Germany', u'goals': 1},
#     'code': u'USA',
#     'datetime': u'2014-06-26T13:00:00.000-03:00',
#     'home_team': {u'code': u'USA', u'country': u'USA', u'goals': 0},
#     'lat': -8.04065,
#     'lng': -35.008205,
#     'location': u'Arena Pernambuco',
#     'match_number': 45,
#     'number': 3,
#     'weather': {u'apparentTemperature': 79.15,
#      u'cloudCover': 0.76,
#      u'dewPoint': 74.67,
#      u'humidity': 0.86,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 249.56,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1014.18,
#      u'summary': u'Humid and Mostly Cloudy',
#      u'temperature': 79.15,
#      u'time': 1403798400,
#      u'windBearing': 102,
#      u'windSpeed': 7.37}}]}}

# %%
group_ranks = {
    "BRA" : 1, "MEX" : 2, "CRO" : 3, "CMR" : 4,
    "NED" : 1, "CHI" : 2, "ESP" : 3, "AUS" : 4,
    "COL" : 1, "GRE" : 2, "CIV" : 3, "JPN" : 4,
    "CRC" : 1, "URU" : 2, "ITA" : 3, "ENG" : 4,
    "FRA" : 1, "SUI" : 2, "ECU" : 3, "HON" : 4,
    "ARG" : 1, "NGA" : 2, "BIH" : 3, "IRN" : 4,
    "GER" : 1, "USA" : 2, "POR" : 3, "GHA" : 4,
    "BEL" : 1, "ALG" : 2, "RUS" : 3, "KOR" : 4
}

# %%
for team in teams_data.values():
    goals_for = 0
    goals_against = 0
    temps = []
    humidities = []
    for match in team['matches']:
        temps.append(match['weather']['temperature'])
        humidities.append(match['weather']['humidity'])
        if match['away_team']['code'] == team['code']:
            self_team = match['away_team']
            other_team = match['home_team']
        else:
            self_team = match['home_team']
            other_team = match['away_team']
        goals_for += self_team['goals']
        goals_against += other_team['goals']
    team['temps'] = temps
    team['average_temps'] = np.average(temps)
    team['humidities'] = humidities
    team['average_humidities'] = np.average(humidities)
    team['goals for'] = goals_for
    team['goals_against'] = goals_against
    team['goal_difference'] = goals_for - goals_against
    team['group_position'] = group_ranks[team['code']]

# %%
teams_data
# Out:
# {u'ALG': {'average_humidities': 0.60999999999999999,
#   'average_temps': 71.026666666666657,
#   'code': u'ALG',
#   'country': u'Algeria',
#   'goal_difference': 1,
#   'goals for': 6,
#   'goals_against': 5,
#   'group': 'H',
#   'group_position': 2,
#   'humidities': [0.48, 0.71, 0.64],
#   'matches': [{'away_team': {u'code': u'ALG',
#      u'country': u'Algeria',
#      u'goals': 1},
#     'code': u'ALG',
#     'datetime': u'2014-06-17T13:00:00.000-03:00',
#     'home_team': {u'code': u'BEL', u'country': u'Belgium', u'goals': 2},
#     'lat': -19.865867,
#     'lng': -43.971132,
#     'location': u'Estadio Mineirao',
#     'match_number': 15,
#     'number': 1,
#     'weather': {u'apparentTemperature': 75.65,
#      u'cloudCover': 0.72,
#      u'dewPoint': 54.55,
#      u'humidity': 0.48,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 252.39,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 0.87,
#      u'precipType': u'rain',
#      u'pressure': 1019.34,
#      u'summary': u'Mostly Cloudy',
#      u'temperature': 75.65,
#      u'time': 1403020800,
#      u'windBearing': 90,
#      u'windSpeed': 4.39}},
#    {'away_team': {u'code': u'ALG', u'country': u'Algeria', u'goals': 4},
#     'code': u'ALG',
#     'datetime': u'2014-06-22T16:00:00.000-03:00',
#     'home_team': {u'code': u'KOR', u'country': u'Korea Republic', u'goals': 2},
#     'lat': -30.065384,
#     'lng': -51.235822,
#     'location': u'Estadio Beira-Rio',
#     'match_number': 32,
#     'number': 2,
#     'weather': {u'apparentTemperature': 67.47,
#      u'cloudCover': 0.3,
#      u'dewPoint': 57.65,
#      u'humidity': 0.71,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 264.33,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1019.13,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 67.47,
#      u'time': 1403463600,
#      u'windBearing': 113,
#      u'windSpeed': 1.24}},
#    {'away_team': {u'code': u'RUS', u'country': u'Russia', u'goals': 1},
#     'code': u'ALG',
#     'datetime': u'2014-06-26T17:00:00.000-03:00',
#     'home_team': {u'code': u'ALG', u'country': u'Algeria', u'goals': 1},
#     'lat': -25.4482121,
#     'lng': -49.276987,
#     'location': u'Arena da Baixada',
#     'match_number': 48,
#     'number': 3,
#     'weather': {u'apparentTemperature': 69.96,
#      u'cloudCover': 0.34,
#      u'dewPoint': 57.35,
#      u'humidity': 0.64,
#      u'icon': u'rain',
#      u'ozone': 272.45,
#      u'precipIntensity': 0.0027,
#      u'precipProbability': 0.74,
#      u'precipType': u'rain',
#      u'pressure': 1013.16,
#      u'summary': u'Drizzle',
#      u'temperature': 69.96,
#      u'time': 1403812800,
#      u'visibility': 6.21,
#      u'windBearing': 17,
#      u'windSpeed': 3.36}}],
#   'temps': [75.65, 67.47, 69.96]},
#  u'ARG': {'average_humidities': 0.7599999999999999,
#   'average_temps': 71.390000000000001,
#   'code': u'ARG',
#   'country': u'Argentina',
#   'goal_difference': 3,
#   'goals for': 6,
#   'goals_against': 3,
#   'group': 'F',
#   'group_position': 1,
#   'humidities': [0.85, 0.6, 0.83],
#   'matches': [{'away_team': {u'code': u'BIH',
#      u'country': u'Bosnia and Herzegovina',
#      u'goals': 1},
#     'code': u'ARG',
#     'datetime': u'2014-06-15T19:00:00.000-03:00',
#     'home_team': {u'code': u'ARG', u'country': u'Argentina', u'goals': 2},
#     'lat': -22.912109,
#     'lng': -43.230156,
#     'location': u'Estadio do Maracana',
#     'match_number': 11,
#     'number': 1,
#     'weather': {u'apparentTemperature': 71.96,
#      u'cloudCover': 0,
#      u'dewPoint': 67.26,
#      u'humidity': 0.85,
#      u'icon': u'rain',
#      u'ozone': 249.87,
#      u'precipIntensity': 0.0033,
#      u'precipProbability': 0.67,
#      u'precipType': u'rain',
#      u'pressure': 1021.92,
#      u'summary': u'Drizzle',
#      u'temperature': 71.96,
#      u'time': 1402869600,
#      u'visibility': 6.2,
#      u'windBearing': 215,
#      u'windSpeed': 5.58}},
#    {'away_team': {u'code': u'IRN', u'country': u'Iran', u'goals': 0},
#     'code': u'ARG',
#     'datetime': u'2014-06-21T13:00:00.000-03:00',
#     'home_team': {u'code': u'ARG', u'country': u'Argentina', u'goals': 1},
#     'lat': -19.865867,
#     'lng': -43.971132,
#     'location': u'Estadio Mineirao',
#     'match_number': 27,
#     'number': 2,
#     'weather': {u'apparentTemperature': 72.39,
#      u'cloudCover': 0.54,
#      u'dewPoint': 57.64,
#      u'humidity': 0.6,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 266.23,
#      u'precipIntensity': 0.0016,
#      u'precipProbability': 0.93,
#      u'precipType': u'rain',
#      u'pressure': 1019.94,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 72.39,
#      u'time': 1403366400,
#      u'visibility': 6.2,
#      u'windBearing': 84,
#      u'windSpeed': 5.45}},
#    {'away_team': {u'code': u'ARG', u'country': u'Argentina', u'goals': 3},
#     'code': u'ARG',
#     'datetime': u'2014-06-25T13:00:00.000-03:00',
#     'home_team': {u'code': u'NGA', u'country': u'Nigeria', u'goals': 2},
#     'lat': -30.065384,
#     'lng': -51.235822,
#     'location': u'Estadio Beira-Rio',
#     'match_number': 43,
#     'number': 3,
#     'weather': {u'apparentTemperature': 69.82,
#      u'cloudCover': 0.75,
#      u'dewPoint': 64.27,
#      u'humidity': 0.83,
#      u'icon': u'rain',
#      u'ozone': 274.12,
#      u'precipIntensity': 0.018,
#      u'precipProbability': 0.66,
#      u'precipType': u'rain',
#      u'pressure': 1011.94,
#      u'summary': u'Light Rain',
#      u'temperature': 69.82,
#      u'time': 1403712000,
#      u'visibility': 3.82,
#      u'windBearing': 280,
#      u'windSpeed': 1.35}}],
#   'temps': [71.96, 72.39, 69.82]},
#  u'AUS': {'average_humidities': 0.70333333333333348,
#   'average_temps': 67.283333333333346,
#   'code': u'AUS',
#   'country': u'Australia',
#   'goal_difference': -6,
#   'goals for': 3,
#   'goals_against': 9,
#   'group': 'B',
#   'group_position': 4,
#   'humidities': [0.74, 0.61, 0.76],
#   'matches': [{'away_team': {u'code': u'AUS',
#      u'country': u'Australia',
#      u'goals': 1},
#     'code': u'AUS',
#     'datetime': u'2014-06-13T19:00:00.000-03:00',
#     'home_team': {u'code': u'CHI', u'country': u'Chile', u'goals': 3},
#     'lat': -15.604017,
#     'lng': -56.121632,
#     'location': u'Arena Pantanal',
#     'match_number': 4,
#     'number': 1,
#     'weather': {u'apparentTemperature': 75,
#      u'dewPoint': 66.14,
#      u'humidity': 0.74,
#      u'icon': u'clear-night',
#      u'precipType': u'rain',
#      u'summary': u'Clear',
#      u'temperature': 75,
#      u'time': 1402700400,
#      u'windBearing': 0,
#      u'windSpeed': 3}},
#    {'away_team': {u'code': u'NED', u'country': u'Netherlands', u'goals': 3},
#     'code': u'AUS',
#     'datetime': u'2014-06-18T13:00:00.000-03:00',
#     'home_team': {u'code': u'AUS', u'country': u'Australia', u'goals': 2},
#     'lat': -30.065384,
#     'lng': -51.235822,
#     'location': u'Estadio Beira-Rio',
#     'match_number': 20,
#     'number': 2,
#     'weather': {u'apparentTemperature': 58.43,
#      u'cloudCover': 0.02,
#      u'dewPoint': 45.08,
#      u'humidity': 0.61,
#      u'icon': u'clear-day',
#      u'ozone': 312.67,
#      u'precipIntensity': 0.0005,
#      u'precipProbability': 0.88,
#      u'precipType': u'rain',
#      u'pressure': 1027.65,
#      u'summary': u'Clear',
#      u'temperature': 58.43,
#      u'time': 1403107200,
#      u'visibility': 6.2,
#      u'windBearing': 217,
#      u'windSpeed': 7.18}},
#    {'away_team': {u'code': u'ESP', u'country': u'Spain', u'goals': 3},
#     'code': u'AUS',
#     'datetime': u'2014-06-23T13:00:00.000-03:00',
#     'home_team': {u'code': u'AUS', u'country': u'Australia', u'goals': 0},
#     'lat': -25.4482121,
#     'lng': -49.276987,
#     'location': u'Arena da Baixada',
#     'match_number': 35,
#     'number': 3,
#     'weather': {u'apparentTemperature': 68.42,
#      u'cloudCover': 0.84,
#      u'dewPoint': 60.71,
#      u'humidity': 0.76,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 275.51,
#      u'precipIntensity': 0.0003,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1019.55,
#      u'summary': u'Mostly Cloudy',
#      u'temperature': 68.42,
#      u'time': 1403539200,
#      u'windBearing': 346,
#      u'windSpeed': 3.5}}],
#   'temps': [75, 58.43, 68.42]},
#  u'BEL': {'average_humidities': 0.56999999999999995,
#   'average_temps': 75.810000000000002,
#   'code': u'BEL',
#   'country': u'Belgium',
#   'goal_difference': 3,
#   'goals for': 4,
#   'goals_against': 1,
#   'group': 'H',
#   'group_position': 1,
#   'humidities': [0.48, 0.74, 0.49],
#   'matches': [{'away_team': {u'code': u'ALG',
#      u'country': u'Algeria',
#      u'goals': 1},
#     'code': u'BEL',
#     'datetime': u'2014-06-17T13:00:00.000-03:00',
#     'home_team': {u'code': u'BEL', u'country': u'Belgium', u'goals': 2},
#     'lat': -19.865867,
#     'lng': -43.971132,
#     'location': u'Estadio Mineirao',
#     'match_number': 15,
#     'number': 1,
#     'weather': {u'apparentTemperature': 75.65,
#      u'cloudCover': 0.72,
#      u'dewPoint': 54.55,
#      u'humidity': 0.48,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 252.39,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 0.87,
#      u'precipType': u'rain',
#      u'pressure': 1019.34,
#      u'summary': u'Mostly Cloudy',
#      u'temperature': 75.65,
#      u'time': 1403020800,
#      u'windBearing': 90,
#      u'windSpeed': 4.39}},
#    {'away_team': {u'code': u'RUS', u'country': u'Russia', u'goals': 0},
#     'code': u'BEL',
#     'datetime': u'2014-06-22T13:00:00.000-03:00',
#     'home_team': {u'code': u'BEL', u'country': u'Belgium', u'goals': 1},
#     'lat': -22.912109,
#     'lng': -43.230156,
#     'location': u'Estadio do Maracana',
#     'match_number': 31,
#     'number': 2,
#     'weather': {u'apparentTemperature': 76.48,
#      u'cloudCover': 0.05,
#      u'dewPoint': 67.53,
#      u'humidity': 0.74,
#      u'icon': u'rain',
#      u'ozone': 270.16,
#      u'precipIntensity': 0.0031,
#      u'precipProbability': 0.81,
#      u'precipType': u'rain',
#      u'pressure': 1023.39,
#      u'summary': u'Drizzle',
#      u'temperature': 76.48,
#      u'time': 1403452800,
#      u'windBearing': 84,
#      u'windSpeed': 10.35}},
#    {'away_team': {u'code': u'BEL', u'country': u'Belgium', u'goals': 1},
#     'code': u'BEL',
#     'datetime': u'2014-06-26T17:00:00.000-03:00',
#     'home_team': {u'code': u'KOR', u'country': u'Korea Republic', u'goals': 0},
#     'lat': -23.545333,
#     'lng': -46.473702,
#     'location': u'Arena de Sao Paulo',
#     'match_number': 47,
#     'number': 3,
#     'weather': {u'apparentTemperature': 75.3,
#      u'cloudCover': 0.98,
#      u'dewPoint': 54.95,
#      u'humidity': 0.49,
#      u'icon': u'cloudy',
#      u'ozone': 264.28,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 0.89,
#      u'precipType': u'rain',
#      u'pressure': 1014.2,
#      u'summary': u'Overcast',
#      u'temperature': 75.3,
#      u'time': 1403812800,
#      u'visibility': 3.11,
#      u'windBearing': 312,
#      u'windSpeed': 3.94}}],
#   'temps': [75.65, 76.48, 75.3]},
#  u'BIH': {'average_humidities': 0.79000000000000004,
#   'average_temps': 75.643333333333331,
#   'code': u'BIH',
#   'country': u'Bosnia and Herzegovina',
#   'goal_difference': 0,
#   'goals for': 4,
#   'goals_against': 4,
#   'group': 'F',
#   'group_position': 3,
#   'humidities': [0.85, 0.75, 0.77],
#   'matches': [{'away_team': {u'code': u'BIH',
#      u'country': u'Bosnia and Herzegovina',
#      u'goals': 1},
#     'code': u'BIH',
#     'datetime': u'2014-06-15T19:00:00.000-03:00',
#     'home_team': {u'code': u'ARG', u'country': u'Argentina', u'goals': 2},
#     'lat': -22.912109,
#     'lng': -43.230156,
#     'location': u'Estadio do Maracana',
#     'match_number': 11,
#     'number': 1,
#     'weather': {u'apparentTemperature': 71.96,
#      u'cloudCover': 0,
#      u'dewPoint': 67.26,
#      u'humidity': 0.85,
#      u'icon': u'rain',
#      u'ozone': 249.87,
#      u'precipIntensity': 0.0033,
#      u'precipProbability': 0.67,
#      u'precipType': u'rain',
#      u'pressure': 1021.92,
#      u'summary': u'Drizzle',
#      u'temperature': 71.96,
#      u'time': 1402869600,
#      u'visibility': 6.2,
#      u'windBearing': 215,
#      u'windSpeed': 5.58}},
#    {'away_team': {u'code': u'BIH',
#      u'country': u'Bosnia and Herzegovina',
#      u'goals': 0},
#     'code': u'BIH',
#     'datetime': u'2014-06-21T19:00:00.000-03:00',
#     'home_team': {u'code': u'NGA', u'country': u'Nigeria', u'goals': 1},
#     'lat': -15.604017,
#     'lng': -56.121632,
#     'location': u'Arena Pantanal',
#     'match_number': 28,
#     'number': 2,
#     'weather': {u'apparentTemperature': 76.62,
#      u'cloudCover': 0.32,
#      u'dewPoint': 68.24,
#      u'humidity': 0.75,
#      u'icon': u'partly-cloudy-night',
#      u'ozone': 254.45,
#      u'precipIntensity': 0.0001,
#      u'precipProbability': 0.98,
#      u'precipType': u'rain',
#      u'pressure': 1013.16,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 76.62,
#      u'time': 1403391600,
#      u'windBearing': 144,
#      u'windSpeed': 0.95}},
#    {'away_team': {u'code': u'IRN', u'country': u'Iran', u'goals': 1},
#     'code': u'BIH',
#     'datetime': u'2014-06-25T13:00:00.000-03:00',
#     'home_team': {u'code': u'BIH',
#      u'country': u'Bosnia and Herzegovina',
#      u'goals': 3},
#     'lat': -12.97883,
#     'lng': -38.504371,
#     'location': u'Arena Fonte Nova',
#     'match_number': 44,
#     'number': 3,
#     'weather': {u'apparentTemperature': 78.35,
#      u'cloudCover': 0.69,
#      u'dewPoint': 70.39,
#      u'humidity': 0.77,
#      u'icon': u'rain',
#      u'ozone': 253.89,
#      u'precipIntensity': 0.0097,
#      u'precipProbability': 0.32,
#      u'precipType': u'rain',
#      u'pressure': 1015.86,
#      u'summary': u'Drizzle',
#      u'temperature': 78.35,
#      u'time': 1403712000,
#      u'visibility': 10,
#      u'windBearing': 143,
#      u'windSpeed': 7.39}}],
#   'temps': [71.96, 76.62, 78.35]},
#  u'BRA': {'average_humidities': 0.64333333333333342,
#   'average_temps': 76.799999999999997,
#   'code': u'BRA',
#   'country': u'Brazil',
#   'goal_difference': 5,
#   'goals for': 7,
#   'goals_against': 2,
#   'group': 'A',
#   'group_position': 1,
#   'humidities': [0.66, 0.64, 0.63],
#   'matches': [{'away_team': {u'code': u'CRO',
#      u'country': u'Croatia',
#      u'goals': 1},
#     'code': u'BRA',
#     'datetime': u'2014-06-12T17:00:00.000-03:00',
#     'home_team': {u'code': u'BRA', u'country': u'Brazil', u'goals': 3},
#     'lat': -23.545333,
#     'lng': -46.473702,
#     'location': u'Arena de Sao Paulo',
#     'match_number': 1,
#     'number': 1,
#     'weather': {u'apparentTemperature': 74.8,
#      u'dewPoint': 62.7,
#      u'humidity': 0.66,
#      u'icon': u'clear-day',
#      u'precipType': u'rain',
#      u'summary': u'Clear',
#      u'temperature': 74.8,
#      u'time': 1402603200,
#      u'visibility': 6.2,
#      u'windBearing': 82,
#      u'windSpeed': 8.26}},
#    {'away_team': {u'code': u'MEX', u'country': u'Mexico', u'goals': 0},
#     'code': u'BRA',
#     'datetime': u'2014-06-17T16:00:00.000-03:00',
#     'home_team': {u'code': u'BRA', u'country': u'Brazil', u'goals': 0},
#     'lat': -3.807231,
#     'lng': -38.522434,
#     'location': u'Estadio Castelao',
#     'match_number': 17,
#     'number': 2,
#     'weather': {u'apparentTemperature': 87.93,
#      u'cloudCover': 0.43,
#      u'dewPoint': 70.16,
#      u'humidity': 0.64,
#      u'icon': u'rain',
#      u'ozone': 257.01,
#      u'precipIntensity': 0.0046,
#      u'precipProbability': 0.62,
#      u'precipType': u'rain',
#      u'pressure': 1012.35,
#      u'summary': u'Drizzle',
#      u'temperature': 83.59,
#      u'time': 1403031600,
#      u'visibility': 6.2,
#      u'windBearing': 92,
#      u'windSpeed': 14.24}},
#    {'away_team': {u'code': u'BRA', u'country': u'Brazil', u'goals': 4},
#     'code': u'BRA',
#     'datetime': u'2014-06-23T17:00:00.000-03:00',
#     'home_team': {u'code': u'CMR', u'country': u'Cameroon', u'goals': 1},
#     'lat': -15.783519,
#     'lng': -47.899211,
#     'location': u'Estadio Nacional',
#     'match_number': 33,
#     'number': 3,
#     'weather': {u'apparentTemperature': 72.01,
#      u'cloudCover': 0.98,
#      u'dewPoint': 58.63,
#      u'humidity': 0.63,
#      u'icon': u'cloudy',
#      u'ozone': 251.39,
#      u'precipIntensity': 0.0004,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1017.79,
#      u'summary': u'Overcast',
#      u'temperature': 72.01,
#      u'time': 1403553600,
#      u'windBearing': 76,
#      u'windSpeed': 7.63}}],
#   'temps': [74.8, 83.59, 72.01]},
#  u'CHI': {'average_humidities': 0.7533333333333333,
#   'average_temps': 74.153333333333322,
#   'code': u'CHI',
#   'country': u'Chile',
#   'goal_difference': 2,
#   'goals for': 5,
#   'goals_against': 3,
#   'group': 'B',
#   'group_position': 2,
#   'humidities': [0.74, 0.83, 0.69],
#   'matches': [{'away_team': {u'code': u'AUS',
#      u'country': u'Australia',
#      u'goals': 1},
#     'code': u'CHI',
#     'datetime': u'2014-06-13T19:00:00.000-03:00',
#     'home_team': {u'code': u'CHI', u'country': u'Chile', u'goals': 3},
#     'lat': -15.604017,
#     'lng': -56.121632,
#     'location': u'Arena Pantanal',
#     'match_number': 4,
#     'number': 1,
#     'weather': {u'apparentTemperature': 75,
#      u'dewPoint': 66.14,
#      u'humidity': 0.74,
#      u'icon': u'clear-night',
#      u'precipType': u'rain',
#      u'summary': u'Clear',
#      u'temperature': 75,
#      u'time': 1402700400,
#      u'windBearing': 0,
#      u'windSpeed': 3}},
#    {'away_team': {u'code': u'CHI', u'country': u'Chile', u'goals': 2},
#     'code': u'CHI',
#     'datetime': u'2014-06-18T16:00:00.000-03:00',
#     'home_team': {u'code': u'ESP', u'country': u'Spain', u'goals': 0},
#     'lat': -22.912109,
#     'lng': -43.230156,
#     'location': u'Estadio do Maracana',
#     'match_number': 19,
#     'number': 2,
#     'weather': {u'apparentTemperature': 73.6,
#      u'cloudCover': 0.25,
#      u'dewPoint': 67.93,
#      u'humidity': 0.83,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 263.01,
#      u'precipIntensity': 0.0006,
#      u'precipProbability': 0.88,
#      u'precipType': u'rain',
#      u'pressure': 1019.46,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 73.6,
#      u'time': 1403118000,
#      u'visibility': 3.53,
#      u'windBearing': 202,
#      u'windSpeed': 9.2}},
#    {'away_team': {u'code': u'CHI', u'country': u'Chile', u'goals': 0},
#     'code': u'CHI',
#     'datetime': u'2014-06-23T13:00:00.000-03:00',
#     'home_team': {u'code': u'NED', u'country': u'Netherlands', u'goals': 2},
#     'lat': -23.545333,
#     'lng': -46.473702,
#     'location': u'Arena de Sao Paulo',
#     'match_number': 36,
#     'number': 3,
#     'weather': {u'apparentTemperature': 73.86,
#      u'cloudCover': 0.82,
#      u'dewPoint': 63.24,
#      u'humidity': 0.69,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 265.14,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1020.67,
#      u'summary': u'Mostly Cloudy',
#      u'temperature': 73.86,
#      u'time': 1403539200,
#      u'windBearing': 337,
#      u'windSpeed': 3.68}}],
#   'temps': [75, 73.6, 73.86]},
#  u'CIV': {'average_humidities': 0.67666666666666675,
#   'average_temps': 78.88000000000001,
#   'code': u'CIV',
#   'country': u'Ivory Coast',
#   'goal_difference': -1,
#   'goals for': 4,
#   'goals_against': 5,
#   'group': 'C',
#   'group_position': 3,
#   'humidities': [0.89, 0.48, 0.66],
#   'matches': [{'away_team': {u'code': u'JPN',
#      u'country': u'Japan',
#      u'goals': 1},
#     'code': u'CIV',
#     'datetime': u'2014-06-14T22:00:00.000-03:00',
#     'home_team': {u'code': u'CIV', u'country': u'Ivory Coast', u'goals': 2},
#     'lat': -8.04065,
#     'lng': -35.008205,
#     'location': u'Arena Pernambuco',
#     'match_number': 6,
#     'number': 1,
#     'weather': {u'apparentTemperature': 74.82,
#      u'cloudCover': 0.05,
#      u'dewPoint': 71.3,
#      u'humidity': 0.89,
#      u'icon': u'clear-night',
#      u'ozone': 251.46,
#      u'precipIntensity': 0.0219,
#      u'precipProbability': 0.12,
#      u'precipType': u'rain',
#      u'pressure': 1015.85,
#      u'summary': u'Clear',
#      u'temperature': 74.82,
#      u'time': 1402794000,
#      u'visibility': 5.34,
#      u'windBearing': 141,
#      u'windSpeed': 9.43}},
#    {'away_team': {u'code': u'CIV', u'country': u'Ivory Coast', u'goals': 1},
#     'code': u'CIV',
#     'datetime': u'2014-06-19T13:00:00.000-03:00',
#     'home_team': {u'code': u'COL', u'country': u'Colombia', u'goals': 2},
#     'lat': -15.783519,
#     'lng': -47.899211,
#     'location': u'Estadio Nacional',
#     'match_number': 21,
#     'number': 2,
#     'weather': {u'apparentTemperature': 77.98,
#      u'cloudCover': 0.98,
#      u'dewPoint': 56.53,
#      u'humidity': 0.48,
#      u'icon': u'cloudy',
#      u'ozone': 259.05,
#      u'precipIntensity': 0.0003,
#      u'precipProbability': 0.92,
#      u'precipType': u'rain',
#      u'pressure': 1018.22,
#      u'summary': u'Overcast',
#      u'temperature': 77.98,
#      u'time': 1403193600,
#      u'visibility': 6.2,
#      u'windBearing': 152,
#      u'windSpeed': 6.07}},
#    {'away_team': {u'code': u'CIV', u'country': u'Ivory Coast', u'goals': 1},
#     'code': u'CIV',
#     'datetime': u'2014-06-24T17:00:00.000-03:00',
#     'home_team': {u'code': u'GRE', u'country': u'Greece', u'goals': 2},
#     'lat': -3.807231,
#     'lng': -38.522434,
#     'location': u'Estadio Castelao',
#     'match_number': 38,
#     'number': 3,
#     'weather': {u'apparentTemperature': 88.93,
#      u'cloudCover': 0.61,
#      u'dewPoint': 71.26,
#      u'humidity': 0.66,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 252.84,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1012.02,
#      u'summary': u'Mostly Cloudy',
#      u'temperature': 83.84,
#      u'time': 1403640000,
#      u'windBearing': 65,
#      u'windSpeed': 16.09}}],
#   'temps': [74.82, 77.98, 83.84]},
#  u'CMR': {'average_humidities': 0.81666666666666654,
#   'average_temps': 74.383333333333326,
#   'code': u'CMR',
#   'country': u'Cameroon',
#   'goal_difference': -8,
#   'goals for': 1,
#   'goals_against': 9,
#   'group': 'A',
#   'group_position': 4,
#   'humidities': [0.94, 0.88, 0.63],
#   'matches': [{'away_team': {u'code': u'CMR',
#      u'country': u'Cameroon',
#      u'goals': 0},
#     'code': u'CMR',
#     'datetime': u'2014-06-13T13:00:00.000-03:00',
#     'home_team': {u'code': u'MEX', u'country': u'Mexico', u'goals': 1},
#     'lat': -5.826827,
#     'lng': -35.21243,
#     'location': u'Estadio das Dunas',
#     'match_number': 2,
#     'number': 1,
#     'weather': {u'apparentTemperature': 73.92,
#      u'dewPoint': 72.01,
#      u'humidity': 0.94,
#      u'icon': u'clear-day',
#      u'precipType': u'rain',
#      u'summary': u'Humid',
#      u'temperature': 73.92,
#      u'time': 1402675200,
#      u'visibility': 3.47,
#      u'windBearing': 87,
#      u'windSpeed': 5.08}},
#    {'away_team': {u'code': u'CRO', u'country': u'Croatia', u'goals': 4},
#     'code': u'CMR',
#     'datetime': u'2014-06-18T19:00:00.000-03:00',
#     'home_team': {u'code': u'CMR', u'country': u'Cameroon', u'goals': 0},
#     'lat': -3.083142,
#     'lng': -60.028108,
#     'location': u'Arena Amazonia',
#     'match_number': 18,
#     'number': 2,
#     'weather': {u'apparentTemperature': 77.22,
#      u'cloudCover': 0.81,
#      u'dewPoint': 73.32,
#      u'humidity': 0.88,
#      u'icon': u'rain',
#      u'ozone': 249.45,
#      u'precipIntensity': 0.0115,
#      u'precipProbability': 0.4,
#      u'precipType': u'rain',
#      u'pressure': 1014.23,
#      u'summary': u'Drizzle',
#      u'temperature': 77.22,
#      u'time': 1403132400,
#      u'visibility': 6.2,
#      u'windBearing': 57,
#      u'windSpeed': 1.45}},
#    {'away_team': {u'code': u'BRA', u'country': u'Brazil', u'goals': 4},
#     'code': u'CMR',
#     'datetime': u'2014-06-23T17:00:00.000-03:00',
#     'home_team': {u'code': u'CMR', u'country': u'Cameroon', u'goals': 1},
#     'lat': -15.783519,
#     'lng': -47.899211,
#     'location': u'Estadio Nacional',
#     'match_number': 33,
#     'number': 3,
#     'weather': {u'apparentTemperature': 72.01,
#      u'cloudCover': 0.98,
#      u'dewPoint': 58.63,
#      u'humidity': 0.63,
#      u'icon': u'cloudy',
#      u'ozone': 251.39,
#      u'precipIntensity': 0.0004,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1017.79,
#      u'summary': u'Overcast',
#      u'temperature': 72.01,
#      u'time': 1403553600,
#      u'windBearing': 76,
#      u'windSpeed': 7.63}}],
#   'temps': [73.92, 77.22, 72.01]},
#  u'COL': {'average_humidities': 0.48666666666666664,
#   'average_temps': 77.24666666666667,
#   'code': u'COL',
#   'country': u'Colombia',
#   'goal_difference': 7,
#   'goals for': 9,
#   'goals_against': 2,
#   'group': 'C',
#   'group_position': 1,
#   'humidities': [0.55, 0.48, 0.43],
#   'matches': [{'away_team': {u'code': u'GRE',
#      u'country': u'Greece',
#      u'goals': 0},
#     'code': u'COL',
#     'datetime': u'2014-06-14T13:00:00.000-03:00',
#     'home_team': {u'code': u'COL', u'country': u'Colombia', u'goals': 3},
#     'lat': -19.865867,
#     'lng': -43.971132,
#     'location': u'Estadio Mineirao',
#     'match_number': 5,
#     'number': 1,
#     'weather': {u'apparentTemperature': 72.26,
#      u'cloudCover': 0.7,
#      u'dewPoint': 55.19,
#      u'humidity': 0.55,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 255.8,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 0.8,
#      u'precipType': u'rain',
#      u'pressure': 1020.92,
#      u'summary': u'Mostly Cloudy',
#      u'temperature': 72.26,
#      u'time': 1402761600,
#      u'visibility': 6.2,
#      u'windBearing': 84,
#      u'windSpeed': 7.13}},
#    {'away_team': {u'code': u'CIV', u'country': u'Ivory Coast', u'goals': 1},
#     'code': u'COL',
#     'datetime': u'2014-06-19T13:00:00.000-03:00',
#     'home_team': {u'code': u'COL', u'country': u'Colombia', u'goals': 2},
#     'lat': -15.783519,
#     'lng': -47.899211,
#     'location': u'Estadio Nacional',
#     'match_number': 21,
#     'number': 2,
#     'weather': {u'apparentTemperature': 77.98,
#      u'cloudCover': 0.98,
#      u'dewPoint': 56.53,
#      u'humidity': 0.48,
#      u'icon': u'cloudy',
#      u'ozone': 259.05,
#      u'precipIntensity': 0.0003,
#      u'precipProbability': 0.92,
#      u'precipType': u'rain',
#      u'pressure': 1018.22,
#      u'summary': u'Overcast',
#      u'temperature': 77.98,
#      u'time': 1403193600,
#      u'visibility': 6.2,
#      u'windBearing': 152,
#      u'windSpeed': 6.07}},
#    {'away_team': {u'code': u'COL', u'country': u'Colombia', u'goals': 4},
#     'code': u'COL',
#     'datetime': u'2014-06-24T17:00:00.000-03:00',
#     'home_team': {u'code': u'JPN', u'country': u'Japan', u'goals': 1},
#     'lat': -15.604017,
#     'lng': -56.121632,
#     'location': u'Arena Pantanal',
#     'match_number': 37,
#     'number': 3,
#     'weather': {u'apparentTemperature': 81.38,
#      u'cloudCover': 0.35,
#      u'dewPoint': 56.86,
#      u'humidity': 0.43,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 252.9,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1013.16,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 81.5,
#      u'time': 1403643600,
#      u'windBearing': 55,
#      u'windSpeed': 3.84}}],
#   'temps': [72.26, 77.98, 81.5]},
#  u'CRC': {'average_humidities': 0.56999999999999995,
#   'average_temps': 80.920000000000002,
#   'code': u'CRC',
#   'country': u'Costa Rica',
#   'goal_difference': 3,
#   'goals for': 4,
#   'goals_against': 1,
#   'group': 'D',
#   'group_position': 1,
#   'humidities': [0.57, 0.68, 0.46],
#   'matches': [{'away_team': {u'code': u'CRC',
#      u'country': u'Costa Rica',
#      u'goals': 3},
#     'code': u'CRC',
#     'datetime': u'2014-06-14T16:00:00.000-03:00',
#     'home_team': {u'code': u'URU', u'country': u'Uruguay', u'goals': 1},
#     'lat': -3.807231,
#     'lng': -38.522434,
#     'location': u'Estadio Castelao',
#     'match_number': 7,
#     'number': 1,
#     'weather': {u'apparentTemperature': 87.58,
#      u'cloudCover': 0.22,
#      u'dewPoint': 67.53,
#      u'humidity': 0.57,
#      u'icon': u'rain',
#      u'ozone': 247.92,
#      u'precipIntensity': 0.0046,
#      u'precipProbability': 0.61,
#      u'precipType': u'rain',
#      u'pressure': 1011.52,
#      u'summary': u'Drizzle',
#      u'temperature': 84.56,
#      u'time': 1402772400,
#      u'visibility': 6.2,
#      u'windBearing': 94,
#      u'windSpeed': 10.27}},
#    {'away_team': {u'code': u'CRC', u'country': u'Costa Rica', u'goals': 1},
#     'code': u'CRC',
#     'datetime': u'2014-06-20T13:00:00.000-03:00',
#     'home_team': {u'code': u'ITA', u'country': u'Italy', u'goals': 0},
#     'lat': -8.04065,
#     'lng': -35.008205,
#     'location': u'Arena Pernambuco',
#     'match_number': 24,
#     'number': 2,
#     'weather': {u'apparentTemperature': 86.1,
#      u'cloudCover': 0.23,
#      u'dewPoint': 70.47,
#      u'humidity': 0.68,
#      u'icon': u'rain',
#      u'ozone': 257.87,
#      u'precipIntensity': 0.0052,
#      u'precipProbability': 0.64,
#      u'precipType': u'rain',
#      u'pressure': 1015.33,
#      u'summary': u'Drizzle',
#      u'temperature': 82.04,
#      u'time': 1403280000,
#      u'visibility': 6.2,
#      u'windBearing': 149,
#      u'windSpeed': 14.06}},
#    {'away_team': {u'code': u'ENG', u'country': u'England', u'goals': 0},
#     'code': u'CRC',
#     'datetime': u'2014-06-24T13:00:00.000-03:00',
#     'home_team': {u'code': u'CRC', u'country': u'Costa Rica', u'goals': 0},
#     'lat': -19.865867,
#     'lng': -43.971132,
#     'location': u'Estadio Mineirao',
#     'match_number': 40,
#     'number': 3,
#     'weather': {u'apparentTemperature': 76.16,
#      u'cloudCover': 0.41,
#      u'dewPoint': 54.04,
#      u'humidity': 0.46,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 264.8,
#      u'precipIntensity': 0.0001,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1019.44,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 76.16,
#      u'time': 1403625600,
#      u'visibility': 6.21,
#      u'windBearing': 70,
#      u'windSpeed': 6.17}}],
#   'temps': [84.56, 82.04, 76.16]},
#  u'CRO': {'average_humidities': 0.80333333333333334,
#   'average_temps': 76.123333333333321,
#   'code': u'CRO',
#   'country': u'Croatia',
#   'goal_difference': 0,
#   'goals for': 6,
#   'goals_against': 6,
#   'group': 'A',
#   'group_position': 3,
#   'humidities': [0.66, 0.88, 0.87],
#   'matches': [{'away_team': {u'code': u'CRO',
#      u'country': u'Croatia',
#      u'goals': 1},
#     'code': u'CRO',
#     'datetime': u'2014-06-12T17:00:00.000-03:00',
#     'home_team': {u'code': u'BRA', u'country': u'Brazil', u'goals': 3},
#     'lat': -23.545333,
#     'lng': -46.473702,
#     'location': u'Arena de Sao Paulo',
#     'match_number': 1,
#     'number': 1,
#     'weather': {u'apparentTemperature': 74.8,
#      u'dewPoint': 62.7,
#      u'humidity': 0.66,
#      u'icon': u'clear-day',
#      u'precipType': u'rain',
#      u'summary': u'Clear',
#      u'temperature': 74.8,
#      u'time': 1402603200,
#      u'visibility': 6.2,
#      u'windBearing': 82,
#      u'windSpeed': 8.26}},
#    {'away_team': {u'code': u'CRO', u'country': u'Croatia', u'goals': 4},
#     'code': u'CRO',
#     'datetime': u'2014-06-18T19:00:00.000-03:00',
#     'home_team': {u'code': u'CMR', u'country': u'Cameroon', u'goals': 0},
#     'lat': -3.083142,
#     'lng': -60.028108,
#     'location': u'Arena Amazonia',
#     'match_number': 18,
#     'number': 2,
#     'weather': {u'apparentTemperature': 77.22,
#      u'cloudCover': 0.81,
#      u'dewPoint': 73.32,
#      u'humidity': 0.88,
#      u'icon': u'rain',
#      u'ozone': 249.45,
#      u'precipIntensity': 0.0115,
#      u'precipProbability': 0.4,
#      u'precipType': u'rain',
#      u'pressure': 1014.23,
#      u'summary': u'Drizzle',
#      u'temperature': 77.22,
#      u'time': 1403132400,
#      u'visibility': 6.2,
#      u'windBearing': 57,
#      u'windSpeed': 1.45}},
#    {'away_team': {u'code': u'MEX', u'country': u'Mexico', u'goals': 3},
#     'code': u'CRO',
#     'datetime': u'2014-06-23T17:00:00.000-03:00',
#     'home_team': {u'code': u'CRO', u'country': u'Croatia', u'goals': 1},
#     'lat': -8.04065,
#     'lng': -35.008205,
#     'location': u'Arena Pernambuco',
#     'match_number': 34,
#     'number': 3,
#     'weather': {u'apparentTemperature': 76.35,
#      u'cloudCover': 0.94,
#      u'dewPoint': 72.02,
#      u'humidity': 0.87,
#      u'icon': u'cloudy',
#      u'ozone': 254.04,
#      u'precipIntensity': 0.0293,
#      u'precipProbability': 0.03,
#      u'precipType': u'rain',
#      u'pressure': 1016.7,
#      u'summary': u'Humid and Overcast',
#      u'temperature': 76.35,
#      u'time': 1403553600,
#      u'windBearing': 149,
#      u'windSpeed': 10.8}}],
#   'temps': [74.8, 77.22, 76.35]},
#  u'ECU': {'average_humidities': 0.72333333333333327,
#   'average_temps': 68.076666666666668,
#   'code': u'ECU',
#   'country': u'Ecuador',
#   'goal_difference': 0,
#   'goals for': 3,
#   'goals_against': 3,
#   'group': 'E',
#   'group_position': 3,
#   'humidities': [0.61, 0.87, 0.69],
#   'matches': [{'away_team': {u'code': u'ECU',
#      u'country': u'Ecuador',
#      u'goals': 1},
#     'code': u'ECU',
#     'datetime': u'2014-06-15T13:00:00.000-03:00',
#     'home_team': {u'code': u'SUI', u'country': u'Switzerland', u'goals': 2},
#     'lat': -15.783519,
#     'lng': -47.899211,
#     'location': u'Estadio Nacional',
#     'match_number': 9,
#     'number': 1,
#     'weather': {u'apparentTemperature': 73.4,
#      u'cloudCover': 0.97,
#      u'dewPoint': 59.17,
#      u'humidity': 0.61,
#      u'icon': u'cloudy',
#      u'ozone': 254.22,
#      u'precipIntensity': 0.0009,
#      u'precipProbability': 0.8,
#      u'precipType': u'rain',
#      u'pressure': 1017.56,
#      u'summary': u'Overcast',
#      u'temperature': 73.4,
#      u'time': 1402848000,
#      u'visibility': 6.2,
#      u'windBearing': 92,
#      u'windSpeed': 9.32}},
#    {'away_team': {u'code': u'ECU', u'country': u'Ecuador', u'goals': 2},
#     'code': u'ECU',
#     'datetime': u'2014-06-20T19:00:00.000-03:00',
#     'home_team': {u'code': u'HON', u'country': u'Honduras', u'goals': 1},
#     'lat': -25.4482121,
#     'lng': -49.276987,
#     'location': u'Arena da Baixada',
#     'match_number': 26,
#     'number': 2,
#     'weather': {u'apparentTemperature': 54.76,
#      u'cloudCover': 1,
#      u'dewPoint': 51.02,
#      u'humidity': 0.87,
#      u'icon': u'cloudy',
#      u'ozone': 291.34,
#      u'precipIntensity': 0.0003,
#      u'precipProbability': 0.95,
#      u'precipType': u'rain',
#      u'pressure': 1022.15,
#      u'summary': u'Overcast',
#      u'temperature': 54.76,
#      u'time': 1403301600,
#      u'visibility': 6.2,
#      u'windBearing': 108,
#      u'windSpeed': 2.72}},
#    {'away_team': {u'code': u'FRA', u'country': u'France', u'goals': 0},
#     'code': u'ECU',
#     'datetime': u'2014-06-25T17:00:00.000-03:00',
#     'home_team': {u'code': u'ECU', u'country': u'Ecuador', u'goals': 0},
#     'lat': -22.912109,
#     'lng': -43.230156,
#     'location': u'Estadio do Maracana',
#     'match_number': 42,
#     'number': 3,
#     'weather': {u'apparentTemperature': 76.07,
#      u'cloudCover': 0.17,
#      u'dewPoint': 65.35,
#      u'humidity': 0.69,
#      u'icon': u'clear-day',
#      u'ozone': 262.48,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1015.99,
#      u'summary': u'Clear',
#      u'temperature': 76.07,
#      u'time': 1403726400,
#      u'visibility': 4.35,
#      u'windBearing': 166,
#      u'windSpeed': 7.81}}],
#   'temps': [73.4, 54.76, 76.07]},
#  u'ENG': {'average_humidities': 0.66666666666666663,
#   'average_temps': 72.316666666666677,
#   'code': u'ENG',
#   'country': u'England',
#   'goal_difference': -2,
#   'goals for': 2,
#   'goals_against': 4,
#   'group': 'D',
#   'group_position': 4,
#   'humidities': [0.68, 0.86, 0.46],
#   'matches': [{'away_team': {u'code': u'ITA',
#      u'country': u'Italy',
#      u'goals': 2},
#     'code': u'ENG',
#     'datetime': u'2014-06-14T19:00:00.000-03:00',
#     'home_team': {u'code': u'ENG', u'country': u'England', u'goals': 1},
#     'lat': -3.083142,
#     'lng': -60.028108,
#     'location': u'Arena Amazonia',
#     'match_number': 8,
#     'number': 1,
#     'weather': {u'apparentTemperature': 79.76,
#      u'cloudCover': 0.01,
#      u'dewPoint': 68.11,
#      u'humidity': 0.68,
#      u'icon': u'clear-night',
#      u'ozone': 251.99,
#      u'precipIntensity': 0.0003,
#      u'precipProbability': 0.8,
#      u'precipType': u'rain',
#      u'pressure': 1010.8,
#      u'summary': u'Clear',
#      u'temperature': 79.76,
#      u'time': 1402786800,
#      u'windBearing': 119,
#      u'windSpeed': 3}},
#    {'away_team': {u'code': u'ENG', u'country': u'England', u'goals': 1},
#     'code': u'ENG',
#     'datetime': u'2014-06-19T16:00:00.000-03:00',
#     'home_team': {u'code': u'URU', u'country': u'Uruguay', u'goals': 2},
#     'lat': -23.545333,
#     'lng': -46.473702,
#     'location': u'Arena de Sao Paulo',
#     'match_number': 23,
#     'number': 2,
#     'weather': {u'apparentTemperature': 61.03,
#      u'cloudCover': 0.91,
#      u'dewPoint': 56.8,
#      u'humidity': 0.86,
#      u'icon': u'rain',
#      u'ozone': 286.33,
#      u'precipIntensity': 0.0081,
#      u'precipProbability': 0.42,
#      u'precipType': u'rain',
#      u'pressure': 1024.34,
#      u'summary': u'Drizzle',
#      u'temperature': 61.03,
#      u'time': 1403204400,
#      u'visibility': 5.84,
#      u'windBearing': 166,
#      u'windSpeed': 9.02}},
#    {'away_team': {u'code': u'ENG', u'country': u'England', u'goals': 0},
#     'code': u'ENG',
#     'datetime': u'2014-06-24T13:00:00.000-03:00',
#     'home_team': {u'code': u'CRC', u'country': u'Costa Rica', u'goals': 0},
#     'lat': -19.865867,
#     'lng': -43.971132,
#     'location': u'Estadio Mineirao',
#     'match_number': 40,
#     'number': 3,
#     'weather': {u'apparentTemperature': 76.16,
#      u'cloudCover': 0.41,
#      u'dewPoint': 54.04,
#      u'humidity': 0.46,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 264.8,
#      u'precipIntensity': 0.0001,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1019.44,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 76.16,
#      u'time': 1403625600,
#      u'visibility': 6.21,
#      u'windBearing': 70,
#      u'windSpeed': 6.17}}],
#   'temps': [79.76, 61.03, 76.16]},
#  u'ESP': {'average_humidities': 0.79333333333333333,
#   'average_temps': 73.673333333333332,
#   'code': u'ESP',
#   'country': u'Spain',
#   'goal_difference': -3,
#   'goals for': 4,
#   'goals_against': 7,
#   'group': 'B',
#   'group_position': 3,
#   'humidities': [0.79, 0.83, 0.76],
#   'matches': [{'away_team': {u'code': u'NED',
#      u'country': u'Netherlands',
#      u'goals': 5},
#     'code': u'ESP',
#     'datetime': u'2014-06-13T16:00:00.000-03:00',
#     'home_team': {u'code': u'ESP', u'country': u'Spain', u'goals': 1},
#     'lat': -12.97883,
#     'lng': -38.504371,
#     'location': u'Arena Fonte Nova',
#     'match_number': 3,
#     'number': 1,
#     'weather': {u'apparentTemperature': 79,
#      u'dewPoint': 71.91,
#      u'humidity': 0.79,
#      u'icon': u'clear-day',
#      u'precipType': u'rain',
#      u'summary': u'Clear',
#      u'temperature': 79,
#      u'time': 1402686000,
#      u'visibility': 6.2,
#      u'windBearing': 150,
#      u'windSpeed': 8}},
#    {'away_team': {u'code': u'CHI', u'country': u'Chile', u'goals': 2},
#     'code': u'ESP',
#     'datetime': u'2014-06-18T16:00:00.000-03:00',
#     'home_team': {u'code': u'ESP', u'country': u'Spain', u'goals': 0},
#     'lat': -22.912109,
#     'lng': -43.230156,
#     'location': u'Estadio do Maracana',
#     'match_number': 19,
#     'number': 2,
#     'weather': {u'apparentTemperature': 73.6,
#      u'cloudCover': 0.25,
#      u'dewPoint': 67.93,
#      u'humidity': 0.83,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 263.01,
#      u'precipIntensity': 0.0006,
#      u'precipProbability': 0.88,
#      u'precipType': u'rain',
#      u'pressure': 1019.46,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 73.6,
#      u'time': 1403118000,
#      u'visibility': 3.53,
#      u'windBearing': 202,
#      u'windSpeed': 9.2}},
#    {'away_team': {u'code': u'ESP', u'country': u'Spain', u'goals': 3},
#     'code': u'ESP',
#     'datetime': u'2014-06-23T13:00:00.000-03:00',
#     'home_team': {u'code': u'AUS', u'country': u'Australia', u'goals': 0},
#     'lat': -25.4482121,
#     'lng': -49.276987,
#     'location': u'Arena da Baixada',
#     'match_number': 35,
#     'number': 3,
#     'weather': {u'apparentTemperature': 68.42,
#      u'cloudCover': 0.84,
#      u'dewPoint': 60.71,
#      u'humidity': 0.76,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 275.51,
#      u'precipIntensity': 0.0003,
#      u'precipProbability': 1,
#      u'precipType': u'rain',
#      u'pressure': 1019.55,
#      u'summary': u'Mostly Cloudy',
#      u'temperature': 68.42,
#      u'time': 1403539200,
#      u'windBearing': 346,
#      u'windSpeed': 3.5}}],
#   'temps': [79, 73.6, 68.42]},
#  u'FRA': {'average_humidities': 0.74333333333333329,
#   'average_temps': 74.086666666666659,
#   'code': u'FRA',
#   'country': u'France',
#   'goal_difference': 6,
#   'goals for': 8,
#   'goals_against': 2,
#   'group': 'E',
#   'group_position': 1,
#   'humidities': [0.81, 0.73, 0.69],
#   'matches': [{'away_team': {u'code': u'HON',
#      u'country': u'Honduras',
#      u'goals': 0},
#     'code': u'FRA',
#     'datetime': u'2014-06-15T16:00:00.000-03:00',
#     'home_team': {u'code': u'FRA', u'country': u'France', u'goals': 3},
#     'lat': -30.065384,
#     'lng': -51.235822,
#     'location': u'Estadio Beira-Rio',
#     'match_number': 10,
#     'number': 1,
#     'weather': {u'apparentTemperature': 66.1,
#      u'cloudCover': 0.13,
#      u'dewPoint': 60.19,
#      u'humidity': 0.81,
#      u'icon': u'clear-day',
#      u'ozone': 265.66,
#      u'precipIntensity': 0.0002,
#      u'precipProbability': 0.83,
#      u'precipType': u'rain',
#      u'pressure': 1022.29,
#      u'summary': u'Clear',
#      u'temperature': 66.1,
#      u'time': 1402858800,
#      u'visibility': 6.1,
#      u'windBearing': 97,
#      u'windSpeed': 12}},
#    {'away_team': {u'code': u'FRA', u'country': u'France', u'goals': 5},
#     'code': u'FRA',
#     'datetime': u'2014-06-20T16:00:00.000-03:00',
#     'home_team': {u'code': u'SUI', u'country': u'Switzerland', u'goals': 2},
#     'lat': -12.97883,
#     'lng': -38.504371,
#     'location': u'Arena Fonte Nova',
#     'match_number': 25,
#     'number': 2,
#     'weather': {u'apparentTemperature': 83.45,
#      u'cloudCover': 0.94,
#      u'dewPoint': 70.53,
#      u'humidity': 0.73,
#      u'icon': u'rain',
#      u'ozone': 254.07,
#      u'precipIntensity': 0.0092,
#      u'precipProbability': 0.42,
#      u'precipType': u'rain',
#      u'pressure': 1016.83,
#      u'summary': u'Drizzle',
#      u'temperature': 80.09,
#      u'time': 1403290800,
#      u'visibility': 6.2,
#      u'windBearing': 134,
#      u'windSpeed': 7.72}},
#    {'away_team': {u'code': u'FRA', u'country': u'France', u'goals': 0},
#     'code': u'FRA',
#     'datetime': u'2014-06-25T17:00:00.000-03:00',
#     'home_team': {u'code': u'ECU', u'country': u'Ecuador', u'goals': 0},
#     'lat': -22.912109,
#     'lng': -43.230156,
#     'location': u'Estadio do Maracana',
#     'match_number': 42,
#     'number': 3,
#     'weather': {u'apparentTemperature': 76.07,
#      u'cloudCover': 0.17,
#      u'dewPoint': 65.35,
#      u'humidity': 0.69,
#      u'icon': u'clear-day',
#      u'ozone': 262.48,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1015.99,
#      u'summary': u'Clear',
#      u'temperature': 76.07,
#      u'time': 1403726400,
#      u'visibility': 4.35,
#      u'windBearing': 166,
#      u'windSpeed': 7.81}}],
#   'temps': [66.1, 80.09, 76.07]},
#  u'GER': {'average_humidities': 0.69666666666666666,
#   'average_temps': 81.326666666666668,
#   'code': u'GER',
#   'country': u'Germany',
#   'goal_difference': 5,
#   'goals for': 7,
#   'goals_against': 2,
#   'group': 'G',
#   'group_position': 1,
#   'humidities': [0.73, 0.5, 0.86],
#   'matches': [{'away_team': {u'code': u'POR',
#      u'country': u'Portugal',
#      u'goals': 0},
#     'code': u'GER',
#     'datetime': u'2014-06-16T13:00:00.000-03:00',
#     'home_team': {u'code': u'GER', u'country': u'Germany', u'goals': 4},
#     'lat': -12.97883,
#     'lng': -38.504371,
#     'location': u'Arena Fonte Nova',
#     'match_number': 13,
#     'number': 1,
#     'weather': {u'apparentTemperature': 79.86,
#      u'cloudCover': 0.17,
#      u'dewPoint': 70.52,
#      u'humidity': 0.73,
#      u'icon': u'clear-day',
#      u'ozone': 255.43,
#      u'precipIntensity': 0.0127,
#      u'precipProbability': 0.24,
#      u'precipType': u'rain',
#      u'pressure': 1017.5,
#      u'summary': u'Clear',
#      u'temperature': 79.86,
#      u'time': 1402934400,
#      u'visibility': 6.2,
#      u'windBearing': 130,
#      u'windSpeed': 11.61}},
#    {'away_team': {u'code': u'GHA', u'country': u'Ghana', u'goals': 2},
#     'code': u'GER',
#     'datetime': u'2014-06-21T16:00:00.000-03:00',
#     'home_team': {u'code': u'GER', u'country': u'Germany', u'goals': 2},
#     'lat': -3.807231,
#     'lng': -38.522434,
#     'location': u'Estadio Castelao',
#     'match_number': 29,
#     'number': 2,
#     'weather': {u'apparentTemperature': 86.49,
#      u'cloudCover': 0.24,
#      u'dewPoint': 64.4,
#      u'humidity': 0.5,
#      u'icon': u'clear-day',
#      u'ozone': 255.14,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1011.81,
#      u'summary': u'Clear',
#      u'temperature': 84.97,
#      u'time': 1403377200,
#      u'windBearing': 96,
#      u'windSpeed': 10.58}},
#    {'away_team': {u'code': u'GER', u'country': u'Germany', u'goals': 1},
#     'code': u'GER',
#     'datetime': u'2014-06-26T13:00:00.000-03:00',
#     'home_team': {u'code': u'USA', u'country': u'USA', u'goals': 0},
#     'lat': -8.04065,
#     'lng': -35.008205,
#     'location': u'Arena Pernambuco',
#     'match_number': 45,
#     'number': 3,
#     'weather': {u'apparentTemperature': 79.15,
#      u'cloudCover': 0.76,
#      u'dewPoint': 74.67,
#      u'humidity': 0.86,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 249.56,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1014.18,
#      u'summary': u'Humid and Mostly Cloudy',
#      u'temperature': 79.15,
#      u'time': 1403798400,
#      u'windBearing': 102,
#      u'windSpeed': 7.37}}],
#   'temps': [79.86, 84.97, 79.15]},
#  u'GHA': {'average_humidities': 0.56333333333333335,
#   'average_temps': 80.416666666666671,
#   'code': u'GHA',
#   'country': u'Ghana',
#   'goal_difference': -2,
#   'goals for': 4,
#   'goals_against': 6,
#   'group': 'G',
#   'group_position': 4,
#   'humidities': [0.77, 0.5, 0.42],
#   'matches': [{'away_team': {u'code': u'USA', u'country': u'USA', u'goals': 2},
#     'code': u'GHA',
#     'datetime': u'2014-06-16T19:00:00.000-03:00',
#     'home_team': {u'code': u'GHA', u'country': u'Ghana', u'goals': 1},
#     'lat': -5.826827,
#     'lng': -35.21243,
#     'location': u'Estadio das Dunas',
#     'match_number': 14,
#     'number': 1,
#     'weather': {u'apparentTemperature': 79.27,
#      u'cloudCover': 0.22,
#      u'dewPoint': 71.3,
#      u'humidity': 0.77,
#      u'icon': u'rain',
#      u'ozone': 252.42,
#      u'precipIntensity': 0.0101,
#      u'precipProbability': 0.49,
#      u'precipType': u'rain',
#      u'pressure': 1014.88,
#      u'summary': u'Drizzle',
#      u'temperature': 79.27,
#      u'time': 1402956000,
#      u'visibility': 6.2,
#      u'windBearing': 144,
#      u'windSpeed': 14.24}},
#    {'away_team': {u'code': u'GHA', u'country': u'Ghana', u'goals': 2},
#     'code': u'GHA',
#     'datetime': u'2014-06-21T16:00:00.000-03:00',
#     'home_team': {u'code': u'GER', u'country': u'Germany', u'goals': 2},
#     'lat': -3.807231,
#     'lng': -38.522434,
#     'location': u'Estadio Castelao',
#     'match_number': 29,
#     'number': 2,
#     'weather': {u'apparentTemperature': 86.49,
#      u'cloudCover': 0.24,
#      u'dewPoint': 64.4,
#      u'humidity': 0.5,
#      u'icon': u'clear-day',
#      u'ozone': 255.14,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1011.81,
#      u'summary': u'Clear',
#      u'temperature': 84.97,
#      u'time': 1403377200,
#      u'windBearing': 96,
#      u'windSpeed': 10.58}},
#    {'away_team': {u'code': u'GHA', u'country': u'Ghana', u'goals': 1},
#     'code': u'GHA',
#     'datetime': u'2014-06-26T13:00:00.000-03:00',
#     'home_team': {u'code': u'POR', u'country': u'Portugal', u'goals': 2},
#     'lat': -15.783519,
#     'lng': -47.899211,
#     'location': u'Estadio Nacional',
#     'match_number': 46,
#     'number': 3,
#     'weather': {u'apparentTemperature': 77.01,
#      u'cloudCover': 0.49,
#      u'dewPoint': 52.37,
#      u'humidity': 0.42,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 252.3,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1015.16,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 77.01,
#      u'time': 1403798400,
#      u'windBearing': 71,
#      u'windSpeed': 6.56}}],
#   'temps': [79.27, 84.97, 77.01]},
#  u'GRE': {'average_humidities': 0.68333333333333346,
#   'average_temps': 78.293333333333337,
#   'code': u'GRE',
#   'country': u'Greece',
#   'goal_difference': -2,
#   'goals for': 2,
#   'goals_against': 4,
#   'group': 'C',
#   'group_position': 2,
#   'humidities': [0.55, 0.84, 0.66],
#   'matches': [{'away_team': {u'code': u'GRE',
#      u'country': u'Greece',
#      u'goals': 0},
#     'code': u'GRE',
#     'datetime': u'2014-06-14T13:00:00.000-03:00',
#     'home_team': {u'code': u'COL', u'country': u'Colombia', u'goals': 3},
#     'lat': -19.865867,
#     'lng': -43.971132,
# ...
#   'code': u'NGA',
#   'country': u'Nigeria',
#   'goal_difference': 0,
#   'goals for': 3,
#   'goals_against': 3,
#   'group': 'F',
#   'group_position': 2,
#   'humidities': [0.76, 0.75, 0.83],
#   'matches': [{'away_team': {u'code': u'NGA',
#      u'country': u'Nigeria',
#      u'goals': 0},
#     'code': u'NGA',
#     'datetime': u'2014-06-16T16:00:00.000-03:00',
#     'home_team': {u'code': u'IRN', u'country': u'Iran', u'goals': 0},
#     'lat': -25.4482121,
#     'lng': -49.276987,
#     'location': u'Arena da Baixada',
#     'match_number': 12,
#     'number': 1,
#     'weather': {u'apparentTemperature': 70.21,
#      u'cloudCover': 0.51,
#      u'dewPoint': 62.3,
#      u'humidity': 0.76,
#      u'icon': u'rain',
#      u'ozone': 253.94,
#      u'precipIntensity': 0.0032,
#      u'precipProbability': 0.7,
#      u'precipType': u'rain',
#      u'pressure': 1019.68,
#      u'summary': u'Drizzle',
#      u'temperature': 70.21,
#      u'time': 1402945200,
#      u'visibility': 6.2,
#      u'windBearing': 259,
#      u'windSpeed': 5.21}},
#    {'away_team': {u'code': u'BIH',
#      u'country': u'Bosnia and Herzegovina',
#      u'goals': 0},
#     'code': u'NGA',
#     'datetime': u'2014-06-21T19:00:00.000-03:00',
#     'home_team': {u'code': u'NGA', u'country': u'Nigeria', u'goals': 1},
#     'lat': -15.604017,
#     'lng': -56.121632,
#     'location': u'Arena Pantanal',
#     'match_number': 28,
#     'number': 2,
#     'weather': {u'apparentTemperature': 76.62,
#      u'cloudCover': 0.32,
#      u'dewPoint': 68.24,
#      u'humidity': 0.75,
#      u'icon': u'partly-cloudy-night',
#      u'ozone': 254.45,
#      u'precipIntensity': 0.0001,
#      u'precipProbability': 0.98,
#      u'precipType': u'rain',
#      u'pressure': 1013.16,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 76.62,
#      u'time': 1403391600,
#      u'windBearing': 144,
#      u'windSpeed': 0.95}},
#    {'away_team': {u'code': u'ARG', u'country': u'Argentina', u'goals': 3},
#     'code': u'NGA',
#     'datetime': u'2014-06-25T13:00:00.000-03:00',
#     'home_team': {u'code': u'NGA', u'country': u'Nigeria', u'goals': 2},
#     'lat': -30.065384,
#     'lng': -51.235822,
#     'location': u'Estadio Beira-Rio',
#     'match_number': 43,
#     'number': 3,
#     'weather': {u'apparentTemperature': 69.82,
#      u'cloudCover': 0.75,
#      u'dewPoint': 64.27,
#      u'humidity': 0.83,
#      u'icon': u'rain',
#      u'ozone': 274.12,
#      u'precipIntensity': 0.018,
#      u'precipProbability': 0.66,
#      u'precipType': u'rain',
#      u'pressure': 1011.94,
#      u'summary': u'Light Rain',
#      u'temperature': 69.82,
#      u'time': 1403712000,
#      u'visibility': 3.82,
#      u'windBearing': 280,
#      u'windSpeed': 1.35}}],
#   'temps': [70.21, 76.62, 69.82]},
#  u'POR': {'average_humidities': 0.65333333333333332,
#   'average_temps': 79.323333333333323,
#   'code': u'POR',
#   'country': u'Portugal',
#   'goal_difference': -3,
#   'goals for': 4,
#   'goals_against': 7,
#   'group': 'G',
#   'group_position': 3,
#   'humidities': [0.73, 0.81, 0.42],
#   'matches': [{'away_team': {u'code': u'POR',
#      u'country': u'Portugal',
#      u'goals': 0},
#     'code': u'POR',
#     'datetime': u'2014-06-16T13:00:00.000-03:00',
#     'home_team': {u'code': u'GER', u'country': u'Germany', u'goals': 4},
#     'lat': -12.97883,
#     'lng': -38.504371,
#     'location': u'Arena Fonte Nova',
#     'match_number': 13,
#     'number': 1,
#     'weather': {u'apparentTemperature': 79.86,
#      u'cloudCover': 0.17,
#      u'dewPoint': 70.52,
#      u'humidity': 0.73,
#      u'icon': u'clear-day',
#      u'ozone': 255.43,
#      u'precipIntensity': 0.0127,
#      u'precipProbability': 0.24,
#      u'precipType': u'rain',
#      u'pressure': 1017.5,
#      u'summary': u'Clear',
#      u'temperature': 79.86,
#      u'time': 1402934400,
#      u'visibility': 6.2,
#      u'windBearing': 130,
#      u'windSpeed': 11.61}},
#    {'away_team': {u'code': u'POR', u'country': u'Portugal', u'goals': 2},
#     'code': u'POR',
#     'datetime': u'2014-06-22T19:00:00.000-03:00',
#     'home_team': {u'code': u'USA', u'country': u'USA', u'goals': 2},
#     'lat': -3.083142,
#     'lng': -60.028108,
#     'location': u'Arena Amazonia',
#     'match_number': 30,
#     'number': 2,
#     'weather': {u'apparentTemperature': 86.94,
#      u'cloudCover': 0.96,
#      u'dewPoint': 74.86,
#      u'humidity': 0.81,
#      u'icon': u'rain',
#      u'ozone': 255.76,
#      u'precipIntensity': 0.0055,
#      u'precipProbability': 0.63,
#      u'precipType': u'rain',
#      u'pressure': 1011.72,
#      u'summary': u'Drizzle',
#      u'temperature': 81.1,
#      u'time': 1403478000,
#      u'windBearing': 85,
#      u'windSpeed': 1.58}},
#    {'away_team': {u'code': u'GHA', u'country': u'Ghana', u'goals': 1},
#     'code': u'POR',
#     'datetime': u'2014-06-26T13:00:00.000-03:00',
#     'home_team': {u'code': u'POR', u'country': u'Portugal', u'goals': 2},
#     'lat': -15.783519,
#     'lng': -47.899211,
#     'location': u'Estadio Nacional',
#     'match_number': 46,
#     'number': 3,
#     'weather': {u'apparentTemperature': 77.01,
#      u'cloudCover': 0.49,
#      u'dewPoint': 52.37,
#      u'humidity': 0.42,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 252.3,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1015.16,
#      u'summary': u'Partly Cloudy',
#      u'temperature': 77.01,
#      u'time': 1403798400,
#      u'windBearing': 71,
#      u'windSpeed': 6.56}}],
#   'temps': [79.86, 81.1, 77.01]},
#  u'RUS': {'average_humidities': 0.70666666666666667,
#   'average_temps': 73.649999999999991,
#   'code': u'RUS',
#   'country': u'Russia',
#   'goal_difference': -1,
#   'goals for': 2,
#   'goals_against': 3,
#   'group': 'H',
#   'group_position': 3,
#   'humidities': [0.74, 0.74, 0.64],
#   'matches': [{'away_team': {u'code': u'KOR',
#      u'country': u'Korea Republic',
#      u'goals': 1},
#     'code': u'RUS',
#     'datetime': u'2014-06-17T19:00:00.000-03:00',
#     'home_team': {u'code': u'RUS', u'country': u'Russia', u'goals': 1},
#     'lat': -15.604017,
#     'lng': -56.121632,
#     'location': u'Arena Pantanal',
#     'match_number': 16,
#     'number': 1,
#     'weather': {u'apparentTemperature': 74.51,
#      u'cloudCover': 0.96,
#      u'dewPoint': 65.67,
#      u'humidity': 0.74,
#      u'icon': u'cloudy',
#      u'ozone': 260.83,
#      u'precipIntensity': 0.0001,
#      u'precipProbability': 0.88,
#      u'precipType': u'rain',
#      u'pressure': 1015.31,
#      u'summary': u'Overcast',
#      u'temperature': 74.51,
#      u'time': 1403046000,
#      u'visibility': 6.2,
#      u'windBearing': 168,
#      u'windSpeed': 3.05}},
#    {'away_team': {u'code': u'RUS', u'country': u'Russia', u'goals': 0},
#     'code': u'RUS',
#     'datetime': u'2014-06-22T13:00:00.000-03:00',
#     'home_team': {u'code': u'BEL', u'country': u'Belgium', u'goals': 1},
#     'lat': -22.912109,
#     'lng': -43.230156,
#     'location': u'Estadio do Maracana',
#     'match_number': 31,
#     'number': 2,
#     'weather': {u'apparentTemperature': 76.48,
#      u'cloudCover': 0.05,
#      u'dewPoint': 67.53,
#      u'humidity': 0.74,
#      u'icon': u'rain',
#      u'ozone': 270.16,
#      u'precipIntensity': 0.0031,
#      u'precipProbability': 0.81,
#      u'precipType': u'rain',
#      u'pressure': 1023.39,
#      u'summary': u'Drizzle',
#      u'temperature': 76.48,
#      u'time': 1403452800,
#      u'windBearing': 84,
#      u'windSpeed': 10.35}},
#    {'away_team': {u'code': u'RUS', u'country': u'Russia', u'goals': 1},
#     'code': u'RUS',
#     'datetime': u'2014-06-26T17:00:00.000-03:00',
#     'home_team': {u'code': u'ALG', u'country': u'Algeria', u'goals': 1},
#     'lat': -25.4482121,
#     'lng': -49.276987,
#     'location': u'Arena da Baixada',
#     'match_number': 48,
#     'number': 3,
#     'weather': {u'apparentTemperature': 69.96,
#      u'cloudCover': 0.34,
#      u'dewPoint': 57.35,
#      u'humidity': 0.64,
#      u'icon': u'rain',
#      u'ozone': 272.45,
#      u'precipIntensity': 0.0027,
#      u'precipProbability': 0.74,
#      u'precipType': u'rain',
#      u'pressure': 1013.16,
#      u'summary': u'Drizzle',
#      u'temperature': 69.96,
#      u'time': 1403812800,
#      u'visibility': 6.21,
#      u'windBearing': 17,
#      u'windSpeed': 3.36}}],
#   'temps': [74.51, 76.48, 69.96]},
#  u'SUI': {'average_humidities': 0.75,
#   'average_temps': 79.616666666666674,
#   'code': u'SUI',
#   'country': u'Switzerland',
#   'goal_difference': 1,
#   'goals for': 7,
#   'goals_against': 6,
#   'group': 'E',
#   'group_position': 2,
#   'humidities': [0.61, 0.73, 0.91],
#   'matches': [{'away_team': {u'code': u'ECU',
#      u'country': u'Ecuador',
#      u'goals': 1},
#     'code': u'SUI',
#     'datetime': u'2014-06-15T13:00:00.000-03:00',
#     'home_team': {u'code': u'SUI', u'country': u'Switzerland', u'goals': 2},
#     'lat': -15.783519,
#     'lng': -47.899211,
#     'location': u'Estadio Nacional',
#     'match_number': 9,
#     'number': 1,
#     'weather': {u'apparentTemperature': 73.4,
#      u'cloudCover': 0.97,
#      u'dewPoint': 59.17,
#      u'humidity': 0.61,
#      u'icon': u'cloudy',
#      u'ozone': 254.22,
#      u'precipIntensity': 0.0009,
#      u'precipProbability': 0.8,
#      u'precipType': u'rain',
#      u'pressure': 1017.56,
#      u'summary': u'Overcast',
#      u'temperature': 73.4,
#      u'time': 1402848000,
#      u'visibility': 6.2,
#      u'windBearing': 92,
#      u'windSpeed': 9.32}},
#    {'away_team': {u'code': u'FRA', u'country': u'France', u'goals': 5},
#     'code': u'SUI',
#     'datetime': u'2014-06-20T16:00:00.000-03:00',
#     'home_team': {u'code': u'SUI', u'country': u'Switzerland', u'goals': 2},
#     'lat': -12.97883,
#     'lng': -38.504371,
#     'location': u'Arena Fonte Nova',
#     'match_number': 25,
#     'number': 2,
#     'weather': {u'apparentTemperature': 83.45,
#      u'cloudCover': 0.94,
#      u'dewPoint': 70.53,
#      u'humidity': 0.73,
#      u'icon': u'rain',
#      u'ozone': 254.07,
#      u'precipIntensity': 0.0092,
#      u'precipProbability': 0.42,
#      u'precipType': u'rain',
#      u'pressure': 1016.83,
#      u'summary': u'Drizzle',
#      u'temperature': 80.09,
#      u'time': 1403290800,
#      u'visibility': 6.2,
#      u'windBearing': 134,
#      u'windSpeed': 7.72}},
#    {'away_team': {u'code': u'SUI', u'country': u'Switzerland', u'goals': 3},
#     'code': u'SUI',
#     'datetime': u'2014-06-25T17:00:00.000-03:00',
#     'home_team': {u'code': u'HON', u'country': u'Honduras', u'goals': 0},
#     'lat': -3.083142,
#     'lng': -60.028108,
#     'location': u'Arena Amazonia',
#     'match_number': 41,
#     'number': 3,
#     'weather': {u'apparentTemperature': 103.39,
#      u'cloudCover': 0.25,
#      u'dewPoint': 82.28,
#      u'humidity': 0.91,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 252.9,
#      u'precipIntensity': 0.0077,
#      u'precipProbability': 0.26,
#      u'precipType': u'rain',
#      u'pressure': 1010.19,
#      u'summary': u'Humid and Partly Cloudy',
#      u'temperature': 85.36,
#      u'time': 1403730000,
#      u'visibility': 6.21,
#      u'windBearing': 7,
#      u'windSpeed': 1.88}}],
#   'temps': [73.4, 80.09, 85.36]},
#  u'URU': {'average_humidities': 0.73666666666666669,
#   'average_temps': 75.826666666666668,
#   'code': u'URU',
#   'country': u'Uruguay',
#   'goal_difference': 0,
#   'goals for': 4,
#   'goals_against': 4,
#   'group': 'D',
#   'group_position': 2,
#   'humidities': [0.57, 0.86, 0.78],
#   'matches': [{'away_team': {u'code': u'CRC',
#      u'country': u'Costa Rica',
#      u'goals': 3},
#     'code': u'URU',
#     'datetime': u'2014-06-14T16:00:00.000-03:00',
#     'home_team': {u'code': u'URU', u'country': u'Uruguay', u'goals': 1},
#     'lat': -3.807231,
#     'lng': -38.522434,
#     'location': u'Estadio Castelao',
#     'match_number': 7,
#     'number': 1,
#     'weather': {u'apparentTemperature': 87.58,
#      u'cloudCover': 0.22,
#      u'dewPoint': 67.53,
#      u'humidity': 0.57,
#      u'icon': u'rain',
#      u'ozone': 247.92,
#      u'precipIntensity': 0.0046,
#      u'precipProbability': 0.61,
#      u'precipType': u'rain',
#      u'pressure': 1011.52,
#      u'summary': u'Drizzle',
#      u'temperature': 84.56,
#      u'time': 1402772400,
#      u'visibility': 6.2,
#      u'windBearing': 94,
#      u'windSpeed': 10.27}},
#    {'away_team': {u'code': u'ENG', u'country': u'England', u'goals': 1},
#     'code': u'URU',
#     'datetime': u'2014-06-19T16:00:00.000-03:00',
#     'home_team': {u'code': u'URU', u'country': u'Uruguay', u'goals': 2},
#     'lat': -23.545333,
#     'lng': -46.473702,
#     'location': u'Arena de Sao Paulo',
#     'match_number': 23,
#     'number': 2,
#     'weather': {u'apparentTemperature': 61.03,
#      u'cloudCover': 0.91,
#      u'dewPoint': 56.8,
#      u'humidity': 0.86,
#      u'icon': u'rain',
#      u'ozone': 286.33,
#      u'precipIntensity': 0.0081,
#      u'precipProbability': 0.42,
#      u'precipType': u'rain',
#      u'pressure': 1024.34,
#      u'summary': u'Drizzle',
#      u'temperature': 61.03,
#      u'time': 1403204400,
#      u'visibility': 5.84,
#      u'windBearing': 166,
#      u'windSpeed': 9.02}},
#    {'away_team': {u'code': u'URU', u'country': u'Uruguay', u'goals': 1},
#     'code': u'URU',
#     'datetime': u'2014-06-24T13:00:00.000-03:00',
#     'home_team': {u'code': u'ITA', u'country': u'Italy', u'goals': 0},
#     'lat': -5.826827,
#     'lng': -35.21243,
#     'location': u'Estadio das Dunas',
#     'match_number': 39,
#     'number': 3,
#     'weather': {u'apparentTemperature': 88.05,
#      u'cloudCover': 0.74,
#      u'dewPoint': 74.34,
#      u'humidity': 0.78,
#      u'icon': u'rain',
#      u'ozone': 251.98,
#      u'precipIntensity': 0.0144,
#      u'precipProbability': 0.25,
#      u'precipType': u'rain',
#      u'pressure': 1014.64,
#      u'summary': u'Drizzle',
#      u'temperature': 81.89,
#      u'time': 1403625600,
#      u'visibility': 6.21,
#      u'windBearing': 133,
#      u'windSpeed': 17.81}}],
#   'temps': [84.56, 61.03, 81.89]},
#  u'USA': {'average_humidities': 0.81333333333333335,
#   'average_temps': 79.840000000000003,
#   'code': u'USA',
#   'country': u'USA',
#   'goal_difference': 0,
#   'goals for': 4,
#   'goals_against': 4,
#   'group': 'G',
#   'group_position': 2,
#   'humidities': [0.77, 0.81, 0.86],
#   'matches': [{'away_team': {u'code': u'USA', u'country': u'USA', u'goals': 2},
#     'code': u'USA',
#     'datetime': u'2014-06-16T19:00:00.000-03:00',
#     'home_team': {u'code': u'GHA', u'country': u'Ghana', u'goals': 1},
#     'lat': -5.826827,
#     'lng': -35.21243,
#     'location': u'Estadio das Dunas',
#     'match_number': 14,
#     'number': 1,
#     'weather': {u'apparentTemperature': 79.27,
#      u'cloudCover': 0.22,
#      u'dewPoint': 71.3,
#      u'humidity': 0.77,
#      u'icon': u'rain',
#      u'ozone': 252.42,
#      u'precipIntensity': 0.0101,
#      u'precipProbability': 0.49,
#      u'precipType': u'rain',
#      u'pressure': 1014.88,
#      u'summary': u'Drizzle',
#      u'temperature': 79.27,
#      u'time': 1402956000,
#      u'visibility': 6.2,
#      u'windBearing': 144,
#      u'windSpeed': 14.24}},
#    {'away_team': {u'code': u'POR', u'country': u'Portugal', u'goals': 2},
#     'code': u'USA',
#     'datetime': u'2014-06-22T19:00:00.000-03:00',
#     'home_team': {u'code': u'USA', u'country': u'USA', u'goals': 2},
#     'lat': -3.083142,
#     'lng': -60.028108,
#     'location': u'Arena Amazonia',
#     'match_number': 30,
#     'number': 2,
#     'weather': {u'apparentTemperature': 86.94,
#      u'cloudCover': 0.96,
#      u'dewPoint': 74.86,
#      u'humidity': 0.81,
#      u'icon': u'rain',
#      u'ozone': 255.76,
#      u'precipIntensity': 0.0055,
#      u'precipProbability': 0.63,
#      u'precipType': u'rain',
#      u'pressure': 1011.72,
#      u'summary': u'Drizzle',
#      u'temperature': 81.1,
#      u'time': 1403478000,
#      u'windBearing': 85,
#      u'windSpeed': 1.58}},
#    {'away_team': {u'code': u'GER', u'country': u'Germany', u'goals': 1},
#     'code': u'USA',
#     'datetime': u'2014-06-26T13:00:00.000-03:00',
#     'home_team': {u'code': u'USA', u'country': u'USA', u'goals': 0},
#     'lat': -8.04065,
#     'lng': -35.008205,
#     'location': u'Arena Pernambuco',
#     'match_number': 45,
#     'number': 3,
#     'weather': {u'apparentTemperature': 79.15,
#      u'cloudCover': 0.76,
#      u'dewPoint': 74.67,
#      u'humidity': 0.86,
#      u'icon': u'partly-cloudy-day',
#      u'ozone': 249.56,
#      u'precipIntensity': 0,
#      u'precipProbability': 0,
#      u'pressure': 1014.18,
#      u'summary': u'Humid and Mostly Cloudy',
#      u'temperature': 79.15,
#      u'time': 1403798400,
#      u'windBearing': 102,
#      u'windSpeed': 7.37}}],
#   'temps': [79.27, 81.1, 79.15]}}

# %%
with open('data/teams.json', 'w+') as f:
    f.write(json.dumps(teams_data, sort_keys=True, indent=4))
